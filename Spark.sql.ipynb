# %%
from pyspark.sql import SQLContext, Row
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql import SparkSession,Row
import collections
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark = SparkSession.builder.config("spark.sql.warehouse.dir").appName("SparkSQL").getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def mapper(line):
    fields = line.split(',')
    return Row(ID=int(fields[0]), name=str(fields[1].encode("utf-8")), age=int(fields[2]), numFriends=int(fields[3]))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
lines = spark.sparkContext.textFile("dbfs:/FileStore/tables/fakefriends.csv")
people = lines.map(mapper)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
schemaPeople = spark.createDataFrame(people).cache()
schemaPeople.createOrReplaceTempView("people")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
teenagers = spark.sql("SELECT * FROM people WHERE age >= 13 AND age <= 19")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
for teen in teenagers.collect():
  print(teen)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Row(ID=21, age=19, name=&#34;b&#39;Miles&#39;&#34;, numFriends=268)
# Row(ID=52, age=19, name=&#34;b&#39;Beverly&#39;&#34;, numFriends=269)
# Row(ID=54, age=19, name=&#34;b&#39;Brunt&#39;&#34;, numFriends=5)
# Row(ID=106, age=18, name=&#34;b&#39;Beverly&#39;&#34;, numFriends=499)
# Row(ID=115, age=18, name=&#34;b&#39;Dukat&#39;&#34;, numFriends=397)
# Row(ID=133, age=19, name=&#34;b&#39;Quark&#39;&#34;, numFriends=265)
# Row(ID=136, age=19, name=&#34;b&#39;Will&#39;&#34;, numFriends=335)
# Row(ID=225, age=19, name=&#34;b&#39;Elim&#39;&#34;, numFriends=106)
# Row(ID=304, age=19, name=&#34;b&#39;Will&#39;&#34;, numFriends=404)
# Row(ID=341, age=18, name=&#34;b&#39;Data&#39;&#34;, numFriends=326)
# Row(ID=366, age=19, name=&#34;b&#39;Keiko&#39;&#34;, numFriends=119)
# Row(ID=373, age=19, name=&#34;b&#39;Quark&#39;&#34;, numFriends=272)
# Row(ID=377, age=18, name=&#34;b&#39;Beverly&#39;&#34;, numFriends=418)
# Row(ID=404, age=18, name=&#34;b&#39;Kasidy&#39;&#34;, numFriends=24)
# Row(ID=409, age=19, name=&#34;b&#39;Nog&#39;&#34;, numFriends=267)
# Row(ID=439, age=18, name=&#34;b&#39;Data&#39;&#34;, numFriends=417)
# Row(ID=444, age=18, name=&#34;b&#39;Keiko&#39;&#34;, numFriends=472)
# Row(ID=492, age=19, name=&#34;b&#39;Dukat&#39;&#34;, numFriends=36)
# Row(ID=494, age=18, name=&#34;b&#39;Kasidy&#39;&#34;, numFriends=194)
# </div>

# %%
schemaPeople.groupBy("age").count().orderBy("count").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+-----+
# age|count|
# +---+-----+
#  63|    4|
#  50|    5|
#  20|    5|
#  65|    5|
#  24|    5|
#  42|    6|
#  34|    6|
#  56|    6|
#  49|    6|
#  60|    7|
#  51|    7|
#  53|    7|
#  39|    7|
#  43|    7|
#  22|    7|
#  27|    8|
#  21|    8|
#  18|    8|
#  31|    8|
#  35|    8|
# +---+-----+
# only showing top 20 rows
#
# </div>

# %%
teenagers.groupBy("age").count().max("count").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+--------+
# age|max(age)|
# +---+--------+
#  19|      19|
#  18|      18|
# +---+--------+
#
# </div>

# %%
# %fs ls /FileStore/tables/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/Book.txt</td><td>Book.txt</td><td>264875</td></tr><tr><td>dbfs:/FileStore/tables/README</td><td>README</td><td>6750</td></tr><tr><td>dbfs:/FileStore/tables/allbut.pl</td><td>allbut.pl</td><td>716</td></tr><tr><td>dbfs:/FileStore/tables/countofsessions.csv</td><td>countofsessions.csv</td><td>127520</td></tr><tr><td>dbfs:/FileStore/tables/exportboothtypes.csv</td><td>exportboothtypes.csv</td><td>373291</td></tr><tr><td>dbfs:/FileStore/tables/fakefriends.csv</td><td>fakefriends.csv</td><td>8754</td></tr><tr><td>dbfs:/FileStore/tables/mku.sh</td><td>mku.sh</td><td>643</td></tr><tr><td>dbfs:/FileStore/tables/u.data</td><td>u.data</td><td>1979173</td></tr><tr><td>dbfs:/FileStore/tables/u.genre</td><td>u.genre</td><td>202</td></tr><tr><td>dbfs:/FileStore/tables/u.info</td><td>u.info</td><td>36</td></tr><tr><td>dbfs:/FileStore/tables/u.item</td><td>u.item</td><td>236344</td></tr><tr><td>dbfs:/FileStore/tables/u.user</td><td>u.user</td><td>22628</td></tr><tr><td>dbfs:/FileStore/tables/u1.base</td><td>u1.base</td><td>1586544</td></tr><tr><td>dbfs:/FileStore/tables/u1.test</td><td>u1.test</td><td>392629</td></tr><tr><td>dbfs:/FileStore/tables/u2.base</td><td>u2.base</td><td>1583948</td></tr><tr><td>dbfs:/FileStore/tables/u2.test</td><td>u2.test</td><td>395225</td></tr><tr><td>dbfs:/FileStore/tables/u3.base</td><td>u3.base</td><td>1582546</td></tr><tr><td>dbfs:/FileStore/tables/u3.test</td><td>u3.test</td><td>396627</td></tr><tr><td>dbfs:/FileStore/tables/u4.base</td><td>u4.base</td><td>1581878</td></tr><tr><td>dbfs:/FileStore/tables/u4.test</td><td>u4.test</td><td>397295</td></tr><tr><td>dbfs:/FileStore/tables/u5.base</td><td>u5.base</td><td>1581776</td></tr><tr><td>dbfs:/FileStore/tables/u5.test</td><td>u5.test</td><td>397397</td></tr><tr><td>dbfs:/FileStore/tables/u_occupation-f60a8</td><td>u_occupation-f60a8</td><td>193</td></tr><tr><td>dbfs:/FileStore/tables/ua.base</td><td>ua.base</td><td>1792501</td></tr><tr><td>dbfs:/FileStore/tables/ua.test</td><td>ua.test</td><td>186672</td></tr><tr><td>dbfs:/FileStore/tables/ub.base</td><td>ub.base</td><td>1792476</td></tr><tr><td>dbfs:/FileStore/tables/ub.test</td><td>ub.test</td><td>186697</td></tr></tbody></table></div>

# %%
#creating datframe from list of tuples 
from pyspark.sql import Row
from pyspark.sql.types import *
l = [('Ankit',25),('Jalfaizy',22),('saurabh',20),('Bala',26)]
rdd = sc.parallelize(l)
persons = rdd.map(lambda x: Row(name = x[0], age = int(x[1])))
schemapersons = sqlContext.createDataFrame(persons)
schemapersons.registerTempTable('schemapersons_table')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sqlContext.sql("select * from schemapersons_table where age > 22").show()
#type(rdd)
#type(schemapersons)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+-----+
# age| name|
# +---+-----+
#  25|Ankit|
#  26| Bala|
# +---+-----+
#
# </div>

# %%
rdd.take(4).foreach()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AttributeError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3075625681545445&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>rdd<span class="ansi-blue-fg">.</span>take<span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">4</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>foreach<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">AttributeError</span>: &#39;list&#39; object has no attribute &#39;foreach&#39;</div>

# %%
counter = 0
rdd = sc.parallelize(data)

# Wrong: Don't do this!!
def increment_counter(x):
    global counter
    counter += x
rdd.foreach(increment_counter)

print("Counter value: ", counter)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3075625681545444&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> counter <span class="ansi-blue-fg">=</span> <span class="ansi-cyan-fg">0</span>
# <span class="ansi-green-fg">----&gt; 2</span><span class="ansi-red-fg"> </span>rdd <span class="ansi-blue-fg">=</span> sc<span class="ansi-blue-fg">.</span>parallelize<span class="ansi-blue-fg">(</span>data<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span> <span class="ansi-red-fg"># Wrong: Don&#39;t do this!!</span>
# <span class="ansi-green-intense-fg ansi-bold">      5</span> <span class="ansi-green-fg">def</span> increment_counter<span class="ansi-blue-fg">(</span>x<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;data&#39; is not defined</div>

# %%
#  creating datframe from CSV
import pandas as pd
from pyspark.sql.types import *
csvdataframe = sqlContext.read.format("csv").options(header = True ,inferSchema = True)
display(csvdataframe)

#schema = StructType([StructField("ID", IntegerType(), True),StructField("name", StringType(), True),StructField("age", IntegerType(), True), StructField("numfriends", IntegerType(), True)])
#csvdatframe2 = sqlContext.createDataFrame(pd_df, schema = schema)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">Exception</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3075625681545441&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span> <span class="ansi-green-fg">from</span> pyspark<span class="ansi-blue-fg">.</span>sql<span class="ansi-blue-fg">.</span>types <span class="ansi-green-fg">import</span> <span class="ansi-blue-fg">*</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span> csvdataframe <span class="ansi-blue-fg">=</span> sqlContext<span class="ansi-blue-fg">.</span>read<span class="ansi-blue-fg">.</span>format<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;dbfs:/FileStore/tables/fakefriends.csv&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>options<span class="ansi-blue-fg">(</span>header <span class="ansi-blue-fg">=</span> <span class="ansi-green-fg">True</span> <span class="ansi-blue-fg">,</span>inferSchema <span class="ansi-blue-fg">=</span> <span class="ansi-green-fg">True</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">----&gt; 5</span><span class="ansi-red-fg"> </span>display<span class="ansi-blue-fg">(</span>csvdataframe<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      6</span>
# <span class="ansi-green-intense-fg ansi-bold">      7</span> <span class="ansi-red-fg">#schema = StructType([StructField(&#34;ID&#34;, IntegerType(), True),StructField(&#34;name&#34;, StringType(), True),StructField(&#34;age&#34;, IntegerType(), True), StructField(&#34;numfriends&#34;, IntegerType(), True)])</span>
#
# <span class="ansi-green-fg">/local_disk0/tmp/1575484419055-0/PythonShell.py</span> in <span class="ansi-cyan-fg">display</span><span class="ansi-blue-fg">(self, input, *args, **kwargs)</span>
# <span class="ansi-green-intense-fg ansi-bold">    964</span>             self<span class="ansi-blue-fg">.</span>displayHTML<span class="ansi-blue-fg">(</span>input<span class="ansi-blue-fg">.</span>_repr_html_<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    965</span>         <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">--&gt; 966</span><span class="ansi-red-fg">             </span><span class="ansi-green-fg">raise</span> Exception<span class="ansi-blue-fg">(</span>genericErrorMsg<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    967</span>
# <span class="ansi-green-intense-fg ansi-bold">    968</span>     <span class="ansi-green-fg">def</span> displayHTML<span class="ansi-blue-fg">(</span>self<span class="ansi-blue-fg">,</span> html<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
#
# <span class="ansi-red-fg">Exception</span>: Cannot call display(&lt;class &#39;pyspark.sql.readwriter.DataFrameReader&#39;&gt;)
#  Call help(display) for more info.</div>

# %%
CREATE TABLE fakefriends
  USING csv
  OPTIONS (path "dbfs:/FileStore/tables/fakefriends.csv", header "true", mode "FAILFAST")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-cyan-fg">  File </span><span class="ansi-green-fg">&#34;&lt;command-3075625681545442&gt;&#34;</span><span class="ansi-cyan-fg">, line </span><span class="ansi-green-fg">1</span>
# <span class="ansi-red-fg">    CREATE TABLE fakefriends</span>
#                ^
# <span class="ansi-red-fg">SyntaxError</span><span class="ansi-red-fg">:</span> invalid syntax
# </div>

# %%
train = sqlContext.load(source="com.databricks.spark.csv", path = 'PATH/train.csv', header = True,inferSchema = True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AttributeError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3075625681545443&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>train <span class="ansi-blue-fg">=</span> sqlContext<span class="ansi-blue-fg">.</span>load<span class="ansi-blue-fg">(</span>source<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#34;com.databricks.spark.csv&#34;</span><span class="ansi-blue-fg">,</span> path <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#39;PATH/train.csv&#39;</span><span class="ansi-blue-fg">,</span> header <span class="ansi-blue-fg">=</span> <span class="ansi-green-fg">True</span><span class="ansi-blue-fg">,</span>inferSchema <span class="ansi-blue-fg">=</span> <span class="ansi-green-fg">True</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">AttributeError</span>: &#39;HiveContext&#39; object has no attribute &#39;load&#39;</div>

# %%
#reading the extrenal text file into the rdd performng the basic transformations

lines = sc.textFile("dbfs:/FileStore/tables/Book.txt")
def clean(l):
  fields = l.split(' ')
  return(fields)
  
pairs = lines.flatMap(lambda x : x.split(" ")).filter(lambda x: len(x) > 3).map(lambda  s : (s, 1))

pairs2 = pairs.reduceByKey(lambda x,y: x+y).collect()


for i in pairs2:
  print(i)
#pairs2 = pairs.mapValues(lambda s: (s, 1))
#pairs2.reduceByKey(lambda x,y: x+y).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">(&#39;Self-Employment:&#39;, 1)
# (&#39;Building&#39;, 5)
# (&#39;Personal&#39;, 3)
# (&#39;Freedom&#39;, 7)
# (&#39;2015&#39;, 3)
# (&#39;worldwide.&#39;, 2)
# (&#39;Disclaimer&#39;, 1)
# (&#39;Making&#39;, 5)
# (&#39;Decision&#39;, 1)
# (&#39;Career&#39;, 1)
# (&#39;Indoctrination&#39;, 2)
# (&#39;Employer&#39;, 2)
# (&#39;Security&#39;, 2)
# (&#39;it�s&#39;, 28)
# (&#39;Worth&#39;, 1)
# (&#39;Unlimited&#39;, 2)
# (&#39;Investing&#39;, 3)
# (&#39;Commute&#39;, 1)
# (&#39;Want&#39;, 5)
# (&#39;When&#39;, 31)
# (&#39;Self-Employment&#39;, 1)
# (&#39;You?&#39;, 1)
# (&#39;Flowchart:&#39;, 1)
# (&#39;Should&#39;, 3)
# (&#39;Consider&#39;, 5)
# (&#39;Care&#39;, 2)
# (&#39;Self-Assessment&#39;, 1)
# (&#39;Quiz&#39;, 1)
# (&#39;PART&#39;, 5)
# (&#39;Happen&#39;, 1)
# (&#39;Designing&#39;, 1)
# (&#39;Sundog&#39;, 20)
# (&#39;Ideas&#39;, 2)
# (&#39;Evaluating&#39;, 1)
# (&#39;Plan&#39;, 4)
# (&#39;Product&#39;, 2)
# (&#39;Sales&#39;, 2)
# (&#39;Strategy&#39;, 1)
# (&#39;Employment&#39;, 1)
# (&#39;Developing&#39;, 1)
# (&#39;Side&#39;, 1)
# (&#39;Obtaining&#39;, 1)
# (&#39;Licenses&#39;, 1)
# (&#39;Launching&#39;, 2)
# (&#39;Product,&#39;, 1)
# (&#39;Risk&#39;, 1)
# (&#39;Mitigation&#39;, 1)
# (&#34;Don&#39;t&#34;, 22)
# (&#39;Alone&#39;, 1)
# (&#39;Pulling&#39;, 1)
# (&#39;Final&#39;, 1)
# (&#39;Telling&#39;, 1)
# (&#39;Boss&#39;, 1)
# (&#39;III:&#39;, 2)
# (&#39;Last&#39;, 1)
# (&#39;Public&#39;, 1)
# (&#39;Advertising&#39;, 3)
# (&#39;Engine&#39;, 2)
# (&#39;Landing&#39;, 4)
# (&#39;Importance&#39;, 1)
# (&#39;Email&#39;, 5)
# (&#39;Campaigns&#39;, 1)
# (&#39;Metrics&#39;, 2)
# (&#39;Pitfalls&#39;, 1)
# (&#39;Beware&#39;, 5)
# (&#39;Leeches&#39;, 1)
# (&#39;Well-Meaning&#39;, 1)
# (&#39;Hiring&#39;, 3)
# (&#39;Salespeople&#39;, 1)
# (&#39;Misleading&#39;, 1)
# (&#39;Statistics&#39;, 4)
# (&#39;Compounding&#39;, 1)
# (&#39;Adapting&#39;, 1)
# (&#39;Life&#39;, 2)
# (&#39;Guilt&#39;, 1)
# (&#39;Letting&#39;, 1)
# (&#39;Fixed&#39;, 1)
# (&#39;Schedules&#39;, 1)
# (&#39;Reading&#39;, 1)
# (&#39;About&#39;, 4)
# (&#39;What&#39;, 38)
# (&#39;career&#39;, 18)
# (&#39;decision.&#39;, 1)
# (&#39;book&#39;, 31)
# (&#39;tells&#39;, 4)
# (&#39;improved&#39;, 2)
# (&#39;quitting&#39;, 8)
# (&#39;creating&#39;, 14)
# (&#39;sustainable&#39;, 3)
# (&#39;income&#39;, 17)
# (&#39;help&#39;, 42)
# (&#39;matter&#39;, 10)
# (&#39;give&#39;, 31)
# (&#39;success&#39;, 12)
# (&#39;preparation,&#39;, 1)
# (&#39;luck.&#39;, 1)
# (&#39;this&#39;, 208)
# (&#39;that�s&#39;, 6)
# (&#39;very&#39;, 55)
# (&#39;possibility&#39;, 3)
# (&#39;must&#39;, 28)
# (&#39;plan&#39;, 43)
# (&#39;for.&#39;, 9)
# (&#39;blame&#39;, 1)
# (&#39;ultimately&#39;, 7)
# (&#39;own.&#39;, 14)
# (&#39;adventure.&#39;, 1)
# (&#39;PREFACE&#39;, 1)
# (&#39;Three&#39;, 2)
# (&#39;years&#39;, 23)
# (&#39;ago,&#39;, 3)
# (&#39;worked&#39;, 16)
# (&#39;company.&#39;, 11)
# (&#39;everything&#39;, 8)
# (&#39;good&#39;, 67)
# (&#39;American&#39;, 4)
# (&#39;hard.&#39;, 3)
# (&#39;devoted&#39;, 1)
# (&#39;making&#39;, 14)
# (&#39;even&#39;, 68)
# (&#39;more&#39;, 187)
# (&#39;successful.&#39;, 3)
# (&#39;commuted&#39;, 1)
# (&#39;hours&#39;, 33)
# (&#39;week&#39;, 17)
# (&#39;minimum.&#39;, 3)
# (&#39;when&#39;, 69)
# (&#39;them&#39;, 108)
# (&#39;page&#39;, 30)
# (&#39;something&#39;, 50)
# (&#39;needed&#39;, 7)
# (&#39;happened&#39;, 3)
# (&#39;pretty&#39;, 18)
# (&#39;often.&#39;, 2)
# (&#39;Over&#39;, 2)
# (&#39;years,&#39;, 4)
# (&#39;rewarded&#39;, 1)
# (&#39;responsibility,&#39;, 2)
# (&#39;money&#39;, 62)
# (&#39;although&#39;, 5)
# (&#39;never&#39;, 26)
# (&#39;seemed&#39;, 2)
# (&#39;quite&#39;, 5)
# (&#39;considered&#39;, 4)
# (&#39;role-model&#39;, 1)
# (&#39;development&#39;, 15)
# (&#39;manager,&#39;, 2)
# (&#39;felt&#39;, 4)
# (&#39;home&#39;, 14)
# (&#39;however,&#39;, 10)
# (&#39;marriage&#39;, 1)
# (&#39;stress,&#39;, 1)
# (&#39;prescription&#39;, 2)
# (&#39;aids&#39;, 2)
# (&#39;extreme&#39;, 2)
# (&#39;stress&#39;, 8)
# (&#39;family&#39;, 19)
# (&#34;wasn&#39;t&#34;, 5)
# (&#39;living&#39;, 17)
# (&#39;country&#39;, 4)
# (&#39;lived&#39;, 2)
# (&#39;duty&#39;, 2)
# (&#39;employer,&#39;, 6)
# (&#39;thought&#39;, 4)
# (&#39;faced&#39;, 4)
# (&#39;ultimatum&#39;, 1)
# (&#39;them.&#39;, 35)
# (&#39;weeks&#39;, 1)
# (&#39;quit&#39;, 19)
# (&#39;job.&#39;, 19)
# (&#39;walked&#39;, 1)
# (&#39;away&#39;, 12)
# (&#39;dollars�&#39;, 1)
# (&#39;worth&#39;, 32)
# (&#39;grants&#39;, 2)
# (&#39;decision&#39;, 7)
# (&#39;working&#39;, 52)
# (&#39;myself&#39;, 9)
# (&#39;before&#39;, 66)
# (&#39;traditional&#39;, 9)
# (&#39;home.&#39;, 4)
# (&#39;have&#39;, 299)
# (&#39;worry&#39;, 8)
# (&#39;about,&#39;, 5)
# (&#39;revenue&#39;, 33)
# (&#39;anything&#39;, 18)
# (&#39;ever&#39;, 9)
# (&#39;senior&#39;, 3)
# (&#39;manager&#39;, 7)
# (&#39;live&#39;, 17)
# (&#39;lower&#39;, 12)
# (&#39;commuting&#39;, 4)
# (&#39;deal&#39;, 6)
# (&#39;money.&#39;, 12)
# (&#39;entire&#39;, 15)
# (&#39;happy,&#39;, 1)
# (&#39;than&#39;, 92)
# (&#39;been.&#39;, 1)
# (&#39;growth,&#39;, 3)
# (&#39;saying&#39;, 4)
# (&#39;executive.&#39;, 1)
# (&#39;commute&#39;, 7)
# (&#39;meetings.&#39;, 2)
# (&#39;artificial&#39;, 2)
# (&#39;work&#39;, 114)
# (&#39;performance&#39;, 9)
# (&#39;fire&#39;, 4)
# (&#39;anyone.&#39;, 2)
# (&#39;nobody&#39;, 7)
# (&#39;off.&#39;, 3)
# (&#39;take&#39;, 52)
# (&#39;longer,&#39;, 2)
# (&#39;basically&#39;, 11)
# (&#39;old,&#39;, 1)
# (&#39;sure&#39;, 65)
# (&#39;retirement&#39;, 2)
# (&#39;feel&#39;, 23)
# (&#39;like&#39;, 66)
# (&#39;broke.&#39;, 1)
# (&#39;gloat.&#39;, 1)
# (&#39;maybe&#39;, 6)
# (&#34;you&#39;re&#34;, 159)
# (&#39;three&#39;, 6)
# (&#39;Maybe&#39;, 13)
# (&#39;only&#39;, 77)
# (&#39;reward&#39;, 5)
# (&#39;heart&#39;, 1)
# (&#39;responsibilities.&#39;, 2)
# (&#39;accepted&#39;, 3)
# (&#34;society&#39;s&#34;, 1)
# (&#39;expectations&#39;, 4)
# (&#39;focusing&#39;, 5)
# (&#39;until&#39;, 15)
# (&#39;point&#39;, 20)
# (&#34;you&#39;ll&#34;, 67)
# (&#39;tell&#39;, 13)
# (&#39;there&#39;, 82)
# (&#39;path.&#39;, 3)
# (&#39;easy,&#39;, 4)
# (&#39;means&#39;, 27)
# (&#39;financial&#39;, 12)
# (&#39;possible.&#39;, 12)
# (&#39;minimizing&#39;, 2)
# (&#39;risks&#39;, 3)
# (&#39;shares&#39;, 5)
# (&#34;I&#39;ve&#34;, 23)
# (&#39;way.&#39;, 3)
# (&#39;this,&#39;, 10)
# (&#39;developer.&#39;, 1)
# (&#39;smarts&#39;, 1)
# (&#39;self-sufficient,&#39;, 1)
# (&#39;read&#39;, 12)
# (&#39;just&#39;, 131)
# (&#39;save&#39;, 5)
# (&#39;life,&#39;, 3)
# (&#39;MAKING&#39;, 4)
# (&#39;DECISION&#39;, 1)
# (&#39;step&#39;, 3)
# (&#39;toward&#39;, 11)
# (&#39;self-employment&#39;, 38)
# (&#39;professional&#39;, 13)
# (&#39;scary&#39;, 4)
# (&#39;proposition.&#39;, 1)
# (&#39;comfortable,&#39;, 1)
# (&#39;current&#39;, 18)
# (&#39;Discarding&#39;, 1)
# (&#39;rebel&#39;, 1)
# (&#39;against&#39;, 12)
# (&#39;change&#39;, 17)
# (&#39;magnitude,&#39;, 1)
# (&#39;justify&#39;, 1)
# (&#39;trying&#39;, 24)
# (&#34;It&#39;s&#34;, 46)
# (&#39;surprising&#39;, 1)
# (&#39;individuals&#39;, 3)
# (&#39;forced&#39;, 6)
# (&#39;into&#39;, 75)
# (&#39;situation.&#39;, 5)
# (&#39;become&#39;, 13)
# (&#39;motivated&#39;, 3)
# (&#39;According&#39;, 5)
# (&#39;2012&#39;, 7)
# (&#39;Freelance&#39;, 4)
# (&#39;Industry&#39;, 4)
# (&#39;after&#39;, 29)
# (&#39;start&#39;, 39)
# (&#39;planning&#39;, 8)
# (&#39;business&#39;, 261)
# (&#39;ensure&#39;, 13)
# (&#39;details&#39;, 3)
# (&#39;make&#39;, 88)
# (&#39;understand&#39;, 30)
# (&#39;forces&#39;, 3)
# (&#39;them,&#39;, 15)
# (&#34;That&#39;s&#34;, 18)
# (&#39;barriers&#39;, 3)
# (&#39;self-employment,&#39;, 3)
# (&#39;both&#39;, 11)
# (&#39;imagined,&#39;, 1)
# (&#39;goal&#39;, 14)
# (&#39;pursuing.&#39;, 1)
# (&#39;done,&#39;, 3)
# (&#39;self-assessment&#39;, 2)
# (&#39;really&#39;, 39)
# (&#39;position&#39;, 9)
# (&#39;FAILURE&#39;, 1)
# (&#39;paycheck&#39;, 7)
# (&#39;head&#39;, 2)
# (&#39;reliably.&#39;, 1)
# (&#39;idea&#39;, 44)
# (&#39;quickly&#39;, 12)
# (&#39;brings&#39;, 3)
# (&#39;starving&#39;, 1)
# (&#39;house&#39;, 7)
# (&#39;getting&#39;, 28)
# (&#39;foreclosed.&#39;, 1)
# (&#39;risk,&#39;, 1)
# (&#39;proper&#39;, 3)
# (&#39;making,&#39;, 1)
# (&#39;risk&#39;, 12)
# (&#39;minimize.&#39;, 1)
# (&#39;until:&#39;, 1)
# (&#39;place,&#39;, 2)
# (&#39;rules&#39;, 4)
# (&#39;willing&#39;, 11)
# (&#39;already&#39;, 20)
# (&#39;lose&#39;, 8)
# (&#39;case,&#39;, 10)
# (&#39;things&#39;, 34)
# (&#39;risky&#39

# %%
ds.flatMap(x => x.split(" "))

# %%
from pyspark.sql.types import *
schema = StructType([StructField('Id',IntegerType(),True),
                     StructField('Name',StringType(),True),
                     StructField('Age',IntegerType(), True),
                     StructField('Friends',IntegerType(),True)])

df = spark.read.format('csv').option('header','false').schema(schema).load('dbfs:/FileStore/tables/fakefriends.csv')
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Id</th><th>Name</th><th>Age</th><th>Friends</th></tr></thead><tbody><tr><td>0</td><td>Will</td><td>33</td><td>385</td></tr><tr><td>1</td><td>Jean-Luc</td><td>26</td><td>2</td></tr><tr><td>2</td><td>Hugh</td><td>55</td><td>221</td></tr><tr><td>3</td><td>Deanna</td><td>40</td><td>465</td></tr><tr><td>4</td><td>Quark</td><td>68</td><td>21</td></tr><tr><td>5</td><td>Weyoun</td><td>59</td><td>318</td></tr><tr><td>6</td><td>Gowron</td><td>37</td><td>220</td></tr><tr><td>7</td><td>Will</td><td>54</td><td>307</td></tr><tr><td>8</td><td>Jadzia</td><td>38</td><td>380</td></tr><tr><td>9</td><td>Hugh</td><td>27</td><td>181</td></tr><tr><td>10</td><td>Odo</td><td>53</td><td>191</td></tr><tr><td>11</td><td>Ben</td><td>57</td><td>372</td></tr><tr><td>12</td><td>Keiko</td><td>54</td><td>253</td></tr><tr><td>13</td><td>Jean-Luc</td><td>56</td><td>444</td></tr><tr><td>14</td><td>Hugh</td><td>43</td><td>49</td></tr><tr><td>15</td><td>Rom</td><td>36</td><td>49</td></tr><tr><td>16</td><td>Weyoun</td><td>22</td><td>323</td></tr><tr><td>17</td><td>Odo</td><td>35</td><td>13</td></tr><tr><td>18</td><td>Jean-Luc</td><td>45</td><td>455</td></tr><tr><td>19</td><td>Geordi</td><td>60</td><td>246</td></tr><tr><td>20</td><td>Odo</td><td>67</td><td>220</td></tr><tr><td>21</td><td>Miles</td><td>19</td><td>268</td></tr><tr><td>22</td><td>Quark</td><td>30</td><td>72</td></tr><tr><td>23</td><td>Keiko</td><td>51</td><td>271</td></tr><tr><td>24</td><td>Julian</td><td>25</td><td>1</td></tr><tr><td>25</td><td>Ben</td><td>21</td><td>445</td></tr><tr><td>26</td><td>Julian</td><td>22</td><td>100</td></tr><tr><td>27</td><td>Leeta</td><td>42</td><td>363</td></tr><tr><td>28</td><td>Martok</td><td>49</td><td>476</td></tr><tr><td>29</td><td>Nog</td><td>48</td><td>364</td></tr><tr><td>30</td><td>Keiko</td><td>50</td><td>175</td></tr><tr><td>31</td><td>Miles</td><td>39</td><td>161</td></tr><tr><td>32</td><td>Nog</td><td>26</td><td>281</td></tr><tr><td>33</td><td>Dukat</td><td>53</td><td>197</td></tr><tr><td>34</td><td>Jean-Luc</td><td>43</td><td>249</td></tr><tr><td>35</td><td>Beverly</td><td>27</td><td>305</td></tr><tr><td>36</td><td>Kasidy</td><td>32</td><td>81</td></tr><tr><td>37</td><td>Geordi</td><td>58</td><td>21</td></tr><tr><td>38</td><td>Deanna</td><td>64</td><td>65</td></tr><tr><td>39</td><td>Morn</td><td>31</td><td>192</td></tr><tr><td>40</td><td>Odo</td><td>52</td><td>413</td></tr><tr><td>41</td><td>Hugh</td><td>67</td><td>167</td></tr><tr><td>42</td><td>Brunt</td><td>54</td><td>75</td></tr><tr><td>43</td><td>Guinan</td><td>58</td><td>345</td></tr><tr><td>44</td><td>Nerys</td><td>35</td><td>244</td></tr><tr><td>45</td><td>Dukat</td><td>52</td><td>77</td></tr><tr><td>46</td><td>Morn</td><td>25</td><td>96</td></tr><tr><td>47</td><td>Brunt</td><td>24</td><td>49</td></tr><tr><td>48</td><td>Nog</td><td>20</td><td>1</td></tr><tr><td>49</td><td>Ezri</td><td>40</td><td>254</td></tr><tr><td>50</td><td>Quark</td><td>51</td><td>283</td></tr><tr><td>51</td><td>Lwaxana</td><td>36</td><td>212</td></tr><tr><td>52</td><td>Beverly</td><td>19</td><td>269</td></tr><tr><td>53</td><td>Geordi</td><td>62</td><td>31</td></tr><tr><td>54</td><td>Brunt</td><td>19</td><td>5</td></tr><tr><td>55</td><td>Keiko</td><td>41</td><td>278</td></tr><tr><td>56</td><td>Gowron</td><td>44</td><td>194</td></tr><tr><td>57</td><td>Odo</td><td>57</td><td>294</td></tr><tr><td>58</td><td>Hugh</td><td>59</td><td>158</td></tr><tr><td>59</td><td>Morn</td><td>59</td><td>284</td></tr><tr><td>60</td><td>Geordi</td><td>20</td><td>100</td></tr><tr><td>61</td><td>Kasidy</td><td>62</td><td>442</td></tr><tr><td>62</td><td>Keiko</td><td>69</td><td>9</td></tr><tr><td>63</td><td>Jean-Luc</td><td>58</td><td>54</td></tr><tr><td>64</td><td>Elim</td><td>31</td><td>15</td></tr><tr><td>65</td><td>Guinan</td><td>52</td><td>169</td></tr><tr><td>66</td><td>Geordi</td><td>21</td><td>477</td></tr><tr><td>67</td><td>Jadz ...

# %%
temptable = ''
df.createOrReplaceTempView('temptable')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df5 = spark.sql("select * from temptable")
df5.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: [Row(_c0=&#39;0&#39;, _c1=&#39;Will&#39;, _c2=&#39;33&#39;, _c3=&#39;385&#39;),
#  Row(_c0=&#39;1&#39;, _c1=&#39;Jean-Luc&#39;, _c2=&#39;26&#39;, _c3=&#39;2&#39;),
#  Row(_c0=&#39;2&#39;, _c1=&#39;Hugh&#39;, _c2=&#39;55&#39;, _c3=&#39;221&#39;),
#  Row(_c0=&#39;3&#39;, _c1=&#39;Deanna&#39;, _c2=&#39;40&#39;, _c3=&#39;465&#39;),
#  Row(_c0=&#39;4&#39;, _c1=&#39;Quark&#39;, _c2=&#39;68&#39;, _c3=&#39;21&#39;),
#  Row(_c0=&#39;5&#39;, _c1=&#39;Weyoun&#39;, _c2=&#39;59&#39;, _c3=&#39;318&#39;),
#  Row(_c0=&#39;6&#39;, _c1=&#39;Gowron&#39;, _c2=&#39;37&#39;, _c3=&#39;220&#39;),
#  Row(_c0=&#39;7&#39;, _c1=&#39;Will&#39;, _c2=&#39;54&#39;, _c3=&#39;307&#39;),
#  Row(_c0=&#39;8&#39;, _c1=&#39;Jadzia&#39;, _c2=&#39;38&#39;, _c3=&#39;380&#39;),
#  Row(_c0=&#39;9&#39;, _c1=&#39;Hugh&#39;, _c2=&#39;27&#39;, _c3=&#39;181&#39;),
#  Row(_c0=&#39;10&#39;, _c1=&#39;Odo&#39;, _c2=&#39;53&#39;, _c3=&#39;191&#39;),
#  Row(_c0=&#39;11&#39;, _c1=&#39;Ben&#39;, _c2=&#39;57&#39;, _c3=&#39;372&#39;),
#  Row(_c0=&#39;12&#39;, _c1=&#39;Keiko&#39;, _c2=&#39;54&#39;, _c3=&#39;253&#39;),
#  Row(_c0=&#39;13&#39;, _c1=&#39;Jean-Luc&#39;, _c2=&#39;56&#39;, _c3=&#39;444&#39;),
#  Row(_c0=&#39;14&#39;, _c1=&#39;Hugh&#39;, _c2=&#39;43&#39;, _c3=&#39;49&#39;),
#  Row(_c0=&#39;15&#39;, _c1=&#39;Rom&#39;, _c2=&#39;36&#39;, _c3=&#39;49&#39;),
#  Row(_c0=&#39;16&#39;, _c1=&#39;Weyoun&#39;, _c2=&#39;22&#39;, _c3=&#39;323&#39;),
#  Row(_c0=&#39;17&#39;, _c1=&#39;Odo&#39;, _c2=&#39;35&#39;, _c3=&#39;13&#39;),
#  Row(_c0=&#39;18&#39;, _c1=&#39;Jean-Luc&#39;, _c2=&#39;45&#39;, _c3=&#39;455&#39;),
#  Row(_c0=&#39;19&#39;, _c1=&#39;Geordi&#39;, _c2=&#39;60&#39;, _c3=&#39;246&#39;),
#  Row(_c0=&#39;20&#39;, _c1=&#39;Odo&#39;, _c2=&#39;67&#39;, _c3=&#39;220&#39;),
#  Row(_c0=&#39;21&#39;, _c1=&#39;Miles&#39;, _c2=&#39;19&#39;, _c3=&#39;268&#39;),
#  Row(_c0=&#39;22&#39;, _c1=&#39;Quark&#39;, _c2=&#39;30&#39;, _c3=&#39;72&#39;),
#  Row(_c0=&#39;23&#39;, _c1=&#39;Keiko&#39;, _c2=&#39;51&#39;, _c3=&#39;271&#39;),
#  Row(_c0=&#39;24&#39;, _c1=&#39;Julian&#39;, _c2=&#39;25&#39;, _c3=&#39;1&#39;),
#  Row(_c0=&#39;25&#39;, _c1=&#39;Ben&#39;, _c2=&#39;21&#39;, _c3=&#39;445&#39;),
#  Row(_c0=&#39;26&#39;, _c1=&#39;Julian&#39;, _c2=&#39;22&#39;, _c3=&#39;100&#39;),
#  Row(_c0=&#39;27&#39;, _c1=&#39;Leeta&#39;, _c2=&#39;42&#39;, _c3=&#39;363&#39;),
#  Row(_c0=&#39;28&#39;, _c1=&#39;Martok&#39;, _c2=&#39;49&#39;, _c3=&#39;476&#39;),
#  Row(_c0=&#39;29&#39;, _c1=&#39;Nog&#39;, _c2=&#39;48&#39;, _c3=&#39;364&#39;),
#  Row(_c0=&#39;30&#39;, _c1=&#39;Keiko&#39;, _c2=&#39;50&#39;, _c3=&#39;175&#39;),
#  Row(_c0=&#39;31&#39;, _c1=&#39;Miles&#39;, _c2=&#39;39&#39;, _c3=&#39;161&#39;),
#  Row(_c0=&#39;32&#39;, _c1=&#39;Nog&#39;, _c2=&#39;26&#39;, _c3=&#39;281&#39;),
#  Row(_c0=&#39;33&#39;, _c1=&#39;Dukat&#39;, _c2=&#39;53&#39;, _c3=&#39;197&#39;),
#  Row(_c0=&#39;34&#39;, _c1=&#39;Jean-Luc&#39;, _c2=&#39;43&#39;, _c3=&#39;249&#39;),
#  Row(_c0=&#39;35&#39;, _c1=&#39;Beverly&#39;, _c2=&#39;27&#39;, _c3=&#39;305&#39;),
#  Row(_c0=&#39;36&#39;, _c1=&#39;Kasidy&#39;, _c2=&#39;32&#39;, _c3=&#39;81&#39;),
#  Row(_c0=&#39;37&#39;, _c1=&#39;Geordi&#39;, _c2=&#39;58&#39;, _c3=&#39;21&#39;),
#  Row(_c0=&#39;38&#39;, _c1=&#39;Deanna&#39;, _c2=&#39;64&#39;, _c3=&#39;65&#39;),
#  Row(_c0=&#39;39&#39;, _c1=&#39;Morn&#39;, _c2=&#39;31&#39;, _c3=&#39;192&#39;),
#  Row(_c0=&#39;40&#39;, _c1=&#39;Odo&#39;, _c2=&#39;52&#39;, _c3=&#39;413&#39;),
#  Row(_c0=&#39;41&#39;, _c1=&#39;Hugh&#39;, _c2=&#39;67&#39;, _c3=&#39;167&#39;),
#  Row(_c0=&#39;42&#39;, _c1=&#39;Brunt&#39;, _c2=&#39;54&#39;, _c3=&#39;75&#39;),
#  Row(_c0=&#39;43&#39;, _c1=&#39;Guinan&#39;, _c2=&#39;58&#39;, _c3=&#39;345&#39;),
#  Row(_c0=&#39;44&#39;, _c1=&#39;Nerys&#39;, _c2=&#39;35&#39;, _c3=&#39;244&#39;),
#  Row(_c0=&#39;45&#39;, _c1=&#39;Dukat&#39;, _c2=&#39;52&#39;, _c3=&#39;77&#39;),
#  Row(_c0=&#39;46&#39;, _c1=&#39;Morn&#39;, _c2=&#39;25&#39;, _c3=&#39;96&#39;),
#  Row(_c0=&#39;47&#39;, _c1=&#39;Brunt&#39;, _c2=&#39;24&#39;, _c3=&#39;49&#39;),
#  Row(_c0=&#39;48&#39;, _c1=&#39;Nog&#39;, _c2=&#39;20&#39;, _c3=&#39;1&#39;),
#  Row(_c0=&#39;49&#39;, _c1=&#39;Ezri&#39;, _c2=&#39;40&#39;, _c3=&#39;254&#39;),
#  Row(_c0=&#39;50&#39;, _c1=&#39;Quark&#39;, _c2=&#39;51&#39;, _c3=&#39;283&#39;),
#  Row(_c0=&#39;51&#39;, _c1=&#39;Lwaxana&#39;, _c2=&#39;36&#39;, _c3=&#39;212&#39;),
#  Row(_c0=&#39;52&#39;, _c1=&#39;Beverly&#39;, _c2=&#39;19&#39;, _c3=&#39;269&#39;),
#  Row(_c0=&#39;53&#39;, _c1=&#39;Geordi&#39;, _c2=&#39;62&#39;, _c3=&#39;31&#39;),
#  Row(_c0=&#39;54&#39;, _c1=&#39;Brunt&#39;, _c2=&#39;19&#39;, _c3=&#39;5&#39;),
#  Row(_c0=&#39;55&#39;, _c1=&#39;Keiko&#39;, _c2=&#39;41&#39;, _c3=&#39;278&#39;),
#  Row(_c0=&#39;56&#39;, _c1=&#39;Gowron&#39;, _c2=&#39;44&#39;, _c3=&#39;194&#39;),
#  Row(_c0=&#39;57&#39;, _c1=&#39;Odo&#39;, _c2=&#39;57&#39;, _c3=&#39;294&#39;),
#  Row(_c0=&#39;58&#39;, _c1=&#39;Hugh&#39;, _c2=&#39;59&#39;, _c3=&#39;158&#39;),
#  Row(_c0=&#39;59&#39;, _c1=&#39;Morn&#39;, _c2=&#39;59&#39;, _c3=&#39;284&#39;),
#  Row(_c0=&#39;60&#39;, _c1=&#39;Geordi&#39;, _c2=&#39;20&#39;, _c3=&#39;100&#39;),
#  Row(_c0=&#39;61&#39;, _c1=&#39;Kasidy&#39;, _c2=&#39;62&#39;, _c3=&#39;442&#39;),
#  Row(_c0=&#39;62&#39;, _c1=&#39;Keiko&#39;, _c2=&#39;69&#39;, _c3=&#39;9&#39;),
#  Row(_c0=&#39;63&#39;, _c1=&#39;Jean-Luc&#39;, _c2=&#39;58&#39;, _c3=&#39;54&#39;),
#  Row(_c0=&#39;64&#39;, _c1=&#39;Elim&#39;, _c2=&#39;31&#39;, _c3=&#39;15&#39;),
#  Row(_c0=&#39;65&#39;, _c1=&#39;Guinan&#39;, _c2=&#39;52&#39;, _c3=&#39;169&#39;),
#  Row(_c0=&#39;66&#39;, _c1=&#39;Geordi&#39;, _c2=&#39;21&#39;, _c3=&#39;477&#39;),
#  Row(_c0=&#39;67&#39;, _c1=&#39;Jadzia&#39;, _c2=&#39;48&#39;, _c3=&#39;135&#39;),
#  Row(_c0=&#39;68&#39;, _c1=&#39;Guinan&#39;, _c2=&#39;33&#39;, _c3=&#39;74&#39;),
#  Row(_c0=&#39;69&#39;, _c1=&#39;Jean-Luc&#39;, _c2=&#39;30&#39;, _c3=&#39;204&#39;),
#  Row(_c0=&#39;70&#39;, _c1=&#39;Brunt&#39;, _c2=&#39;52&#39;, _c3=&#39;393&#39;),
#  Row(_c0=&#39;71&#39;, _c1=&#39;Geordi&#39;, _c2=&#39;45&#39;, _c3=&#39;184&#39;),
#  Row(_c0=&#39;72&#39;, _c1=&#39;Kasidy&#39;, _c2=&#39;22&#39;, _c3=&#39;179&#39;),
#  Row(_c0=&#39;73&#39;, _c1=&#39;Brunt&#39;, _c2=&#39;20&#39;, _c3=&#39;384&#39;),
#  Row(_c0=&#39;74&#39;, _c1=&#39;Leeta&#39;, _c2=&#39;65&#39;, _c3=&#39;208&#39;),
#  Row(_c0=&#39;75&#39;, _c1=&#39;Morn&#39;, _c2=&#39;40&#39;, _c3=&#39;459&#39;),
#  Row(_c0=&#39;76&#39;, _c1=&#39;Will&#39;, _c2=&#39;62&#39;, _c3=&#39;201&#39;),
#  Row(_c0=&#39;77&#39;, _c1=&#39;Weyoun&#39;, _c2=&#39;40&#39;, _c3=&#39;407&#39;),
#  Row(_c0=&#39;78&#39;, _c1=&#39;Data&#39;, _c2=&#39;61&#39;, _c3=&#39;337&#39;),
#  Row(_c0=&#39;79&#39;, _c1=&#39;Leeta&#39;, _c2=&#39;58&#39;, _c3=&#39;348&#39;),
#  Row(_c0=&#39;80&#39;, _c1=&#39;Dukat&#39;, _c2=&#39;67&#39;, _c3=&#39;445&#39;),
#  Row(_c0=&#39;81&#39;, _c1=&#39;Jadzia&#39;, _c2=&#39;54&#39;, _c3=&#39;440&#39;),
#  Row(_c0=&#39;82&#39;, _c1=&#39;Hugh&#39;, _c2=&#39;57&#39;, _c3=&#39;465&#39;),
#  Row(_c0=&#39;83&#39;, _c1=&#39;Geordi&#39;, _c2=&#39;32&#39;, _c3=&#39;308&#39;),
#  Row(_c0=&#39;84&#39;, _c1=&#39;Ben&#39;, _c2=&#39;28&#39;, _c3=&#39;311&#39;),
#  Row(_c0=&#39;85&#39;, _c1=&#39;Quark&#39;, _c2=&#39;66&#39;, _c3=&#39;383&#39;),
#  Row(_c0=&#39;86&#39;, _c1=&#39;Hugh&#39;, _c2=&#39;55&#39;, _c3=&#39;257&#39;),
#  Row(_c0=&#39;87&#39;, _c1=&#39;Ezri&#39;, _c2=&#39;31&#39;, _c3=&#39;481&#39;),
#  Row(_c0=&#39;88&#39;, _c1=&#39;Ben&#39;, _c2=&#39;66&#39;, _c3=&#39;188&#39;),
#  Row(_c0=&#39;89&#39;, _c1=&#39;Worf&#39;, _c2=&#39;24&#39;, _c3=&#39;492&#39;),
#  Row(_c0=&#39;90&#39;, _c1=&#39;Kasidy&#39;, _c2=&#39;33&#39;, _c3=&#39;471&#39;),
#  Row(_c0=&#39;91&#39;, _c1=&#39;Rom&#39;, _c2=&#39;46&#39;, _c3=&#39;88&#39;),
#  Row(_c0=&#39;92&#39;, _c1=&#39;Gowron&#39;, _c2=&#39;54&#39;, _c3=&#39;7&#39;),
#  Row(_c0=&#39;93&#39;, _c1=&#39;Elim&#39;, _c2=&#39;46&#39;, _c3=&#39;63

# %%
df4 = spark.table("temptable")
sorted(df4.collect()) == sorted(df5.collect())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: True</div>

# %%
#udf
spark.udf.register('countoffriends',lambda x: len(x))
spark.sql('select countoffriends(_c2) from temptable').collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: [Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends(_c2)=&#39;2&#39;),
#  Row(countoffriends

# %%
from pyspark.sql.types import * 
from pyspark.sql.functions import udf
slen = udf(lambda s: len(s), IntegerType())
_ = spark.udf.register("slen",slen)
spark.sql('select slen(_c2) from temptable').collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: [Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(slen(_c2)=2),
#  Row(s

# %%
from pyspark.sql.functions import pandas_udf,PandasUDFType
pandas_udf('integer',PandasUDFType.GROUPED_AGG)
def sum_udf(v):
  return v.sum()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
_= spark.udf.register("sum_udf", sum_udf)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
q = 'select sum_udf(_c3),_c1 from temptable group by _c1'
  spark.sql(q).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">Py4JJavaError</span>                             Traceback (most recent call last)
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">     62</span>         <span class="ansi-green-fg">try</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">---&gt; 63</span><span class="ansi-red-fg">             </span><span class="ansi-green-fg">return</span> f<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">*</span>a<span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">**</span>kw<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">     64</span>         <span class="ansi-green-fg">except</span> py4j<span class="ansi-blue-fg">.</span>protocol<span class="ansi-blue-fg">.</span>Py4JJavaError <span class="ansi-green-fg">as</span> e<span class="ansi-blue-fg">:</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/lib/py4j-0.10.7-src.zip/py4j/protocol.py</span> in <span class="ansi-cyan-fg">get_return_value</span><span class="ansi-blue-fg">(answer, gateway_client, target_id, name)</span>
# <span class="ansi-green-intense-fg ansi-bold">    327</span>                     <span class="ansi-blue-fg">&#34;An error occurred while calling {0}{1}{2}.\n&#34;</span><span class="ansi-blue-fg">.</span>
# <span class="ansi-green-fg">--&gt; 328</span><span class="ansi-red-fg">                     format(target_id, &#34;.&#34;, name), value)
# </span><span class="ansi-green-intense-fg ansi-bold">    329</span>             <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
#
# <span class="ansi-red-fg">Py4JJavaError</span>: An error occurred while calling o197.sql.
# : org.apache.spark.sql.AnalysisException: expression &#39;temptable.`_c3`&#39; is neither present in the group by, nor is it an aggregate function. Add to group by or wrap in first() (or first_value) if you don&#39;t care which value you get.;;
# Aggregate [_c1#31], [sum_udf(_c3#33) AS sum_udf(_c3)#74, _c1#31]
# +- SubqueryAlias `temptable`
#    +- Relation[_c0#30,_c1#31,_c2#32,_c3#33] csv
#
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis$class.failAnalysis(CheckAnalysis.scala:46)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.failAnalysis(Analyzer.scala:103)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis$$anonfun$checkAnalysis$1.org$apache$spark$sql$catalyst$analysis$CheckAnalysis$class$$anonfun$$checkValidAggregateExpression$1(CheckAnalysis.scala:235)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis$$anonfun$checkAnalysis$1$$anonfun$org$apache$spark$sql$catalyst$analysis$CheckAnalysis$class$$anonfun$$checkValidAggregateExpression$1$5.apply(CheckAnalysis.scala:241)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis$$anonfun$checkAnalysis$1$$anonfun$org$apache$spark$sql$catalyst$analysis$CheckAnalysis$class$$anonfun$$checkValidAggregateExpression$1$5.apply(CheckAnalysis.scala:241)
# 	at scala.collection.mutable.ResizableArray$class.foreach(ResizableArray.scala:59)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:48)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis$$anonfun$checkAnalysis$1.org$apache$spark$sql$catalyst$analysis$CheckAnalysis$class$$anonfun$$checkValidAggregateExpression$1(CheckAnalysis.scala:241)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis$$anonfun$checkAnalysis$1$$anonfun$org$apache$spark$sql$catalyst$analysis$CheckAnalysis$class$$anonfun$$checkValidAggregateExpression$1$5.apply(CheckAnalysis.scala:241)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis$$anonfun$checkAnalysis$1$$anonfun$org$apache$spark$sql$catalyst$analysis$CheckAnalysis$class$$anonfun$$checkValidAggregateExpression$1$5.apply(CheckAnalysis.scala:241)
# 	at scala.collection.immutable.List.foreach(List.scala:392)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis$$anonfun$checkAnalysis$1.org$apache$spark$sql$catalyst$analysis$CheckAnalysis$class$$anonfun$$checkValidAggregateExpression$1(CheckAnalysis.scala:241)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis$$anonfun$checkAnalysis$1$$anonfun$apply$10.apply(CheckAnalysis.scala:268)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis$$anonfun$checkAnalysis$1$$anonfun$apply$10.apply(CheckAnalysis.scala:268)
# 	at scala.collection.immutable.List.foreach(List.scala:392)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis$$anonfun$checkAnalysis$1.apply(CheckAnalysis.scala:268)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis$$anonfun$checkAnalysis$1.apply(CheckAnalysis.scala:89)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.foreachUp(TreeNode.scala:148)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis$class.checkAnalysis(CheckAnalysis.scala:89)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.checkAnalysis(Analyzer.scala:103)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer$$anonfun$executeAndCheck$1.apply(Analyzer.scala:117)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer$$anonfun$executeAndCheck$1.apply(Analyzer.scala:114)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper$.markInAnalyzer(AnalysisHelper.scala:201)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.executeAndCheck(Analyzer.scala:114)
# 	at org.apache.spark.sql.execution.QueryExecution$$anonfun$analyzed$1.apply(QueryExecution.scala:85)
# 	at org.apache.spark.sql.execution.QueryExecution$$anonfun$analyzed$1.apply(QueryExecution.scala:82)
# 	at org.apache.spark.sql.catalyst.QueryPlanningTracker.measurePhase(QueryPlanningTracker.scala:111)
# 	at org.apache.spark.sql.execution.QueryExecution.analyzed$lzycompute(QueryExecution.scala:82)
# 	at org.apache.spark.sql.execution.QueryExecution.analyzed(QueryExecution.scala:82)
# 	at org.apache.spark.sql.execution.QueryExecution.assertAnalyzed(QueryExecution.scala:74)
# 	at org.apache.spark.sql.Dataset$.ofRows(Dataset.scala:88)
# 	at org.apache.spark.sql.SparkSession.sql(SparkSession.scala:696)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:380)
# 	at py4j.Gateway.invoke(Gateway.java:295)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:251)
# 	at java.lang.Thread.run(Thread.java:748)
#
#
# During handling of the above exception, another exception occurred:
#
# <span class="ansi-red-fg">AnalysisException</span>                         Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1501490288572993&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> q <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#39;select sum_udf(_c3),_c1 from temptable group by _c1&#39;</span>
# <span class="ansi-green-fg">----&gt; 2</span><span class="ansi-red-fg"> </span>spark<span class="ansi-blue-fg">.</span>sql<span class="ansi-blue-fg">(</span>q<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>collect<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
#
# <sp

# %%
# %sql
select * from temptable
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th><th>_c2</th><th>_c3</th></tr></thead><tbody><tr><td>0</td><td>Will</td><td>33</td><td>385</td></tr><tr><td>1</td><td>Jean-Luc</td><td>26</td><td>2</td></tr><tr><td>2</td><td>Hugh</td><td>55</td><td>221</td></tr><tr><td>3</td><td>Deanna</td><td>40</td><td>465</td></tr><tr><td>4</td><td>Quark</td><td>68</td><td>21</td></tr><tr><td>5</td><td>Weyoun</td><td>59</td><td>318</td></tr><tr><td>6</td><td>Gowron</td><td>37</td><td>220</td></tr><tr><td>7</td><td>Will</td><td>54</td><td>307</td></tr><tr><td>8</td><td>Jadzia</td><td>38</td><td>380</td></tr><tr><td>9</td><td>Hugh</td><td>27</td><td>181</td></tr><tr><td>10</td><td>Odo</td><td>53</td><td>191</td></tr><tr><td>11</td><td>Ben</td><td>57</td><td>372</td></tr><tr><td>12</td><td>Keiko</td><td>54</td><td>253</td></tr><tr><td>13</td><td>Jean-Luc</td><td>56</td><td>444</td></tr><tr><td>14</td><td>Hugh</td><td>43</td><td>49</td></tr><tr><td>15</td><td>Rom</td><td>36</td><td>49</td></tr><tr><td>16</td><td>Weyoun</td><td>22</td><td>323</td></tr><tr><td>17</td><td>Odo</td><td>35</td><td>13</td></tr><tr><td>18</td><td>Jean-Luc</td><td>45</td><td>455</td></tr><tr><td>19</td><td>Geordi</td><td>60</td><td>246</td></tr><tr><td>20</td><td>Odo</td><td>67</td><td>220</td></tr><tr><td>21</td><td>Miles</td><td>19</td><td>268</td></tr><tr><td>22</td><td>Quark</td><td>30</td><td>72</td></tr><tr><td>23</td><td>Keiko</td><td>51</td><td>271</td></tr><tr><td>24</td><td>Julian</td><td>25</td><td>1</td></tr><tr><td>25</td><td>Ben</td><td>21</td><td>445</td></tr><tr><td>26</td><td>Julian</td><td>22</td><td>100</td></tr><tr><td>27</td><td>Leeta</td><td>42</td><td>363</td></tr><tr><td>28</td><td>Martok</td><td>49</td><td>476</td></tr><tr><td>29</td><td>Nog</td><td>48</td><td>364</td></tr><tr><td>30</td><td>Keiko</td><td>50</td><td>175</td></tr><tr><td>31</td><td>Miles</td><td>39</td><td>161</td></tr><tr><td>32</td><td>Nog</td><td>26</td><td>281</td></tr><tr><td>33</td><td>Dukat</td><td>53</td><td>197</td></tr><tr><td>34</td><td>Jean-Luc</td><td>43</td><td>249</td></tr><tr><td>35</td><td>Beverly</td><td>27</td><td>305</td></tr><tr><td>36</td><td>Kasidy</td><td>32</td><td>81</td></tr><tr><td>37</td><td>Geordi</td><td>58</td><td>21</td></tr><tr><td>38</td><td>Deanna</td><td>64</td><td>65</td></tr><tr><td>39</td><td>Morn</td><td>31</td><td>192</td></tr><tr><td>40</td><td>Odo</td><td>52</td><td>413</td></tr><tr><td>41</td><td>Hugh</td><td>67</td><td>167</td></tr><tr><td>42</td><td>Brunt</td><td>54</td><td>75</td></tr><tr><td>43</td><td>Guinan</td><td>58</td><td>345</td></tr><tr><td>44</td><td>Nerys</td><td>35</td><td>244</td></tr><tr><td>45</td><td>Dukat</td><td>52</td><td>77</td></tr><tr><td>46</td><td>Morn</td><td>25</td><td>96</td></tr><tr><td>47</td><td>Brunt</td><td>24</td><td>49</td></tr><tr><td>48</td><td>Nog</td><td>20</td><td>1</td></tr><tr><td>49</td><td>Ezri</td><td>40</td><td>254</td></tr><tr><td>50</td><td>Quark</td><td>51</td><td>283</td></tr><tr><td>51</td><td>Lwaxana</td><td>36</td><td>212</td></tr><tr><td>52</td><td>Beverly</td><td>19</td><td>269</td></tr><tr><td>53</td><td>Geordi</td><td>62</td><td>31</td></tr><tr><td>54</td><td>Brunt</td><td>19</td><td>5</td></tr><tr><td>55</td><td>Keiko</td><td>41</td><td>278</td></tr><tr><td>56</td><td>Gowron</td><td>44</td><td>194</td></tr><tr><td>57</td><td>Odo</td><td>57</td><td>294</td></tr><tr><td>58</td><td>Hugh</td><td>59</td><td>158</td></tr><tr><td>59</td><td>Morn</td><td>59</td><td>284</td></tr><tr><td>60</td><td>Geordi</td><td>20</td><td>100</td></tr><tr><td>61</td><td>Kasidy</td><td>62</td><td>442</td></tr><tr><td>62</td><td>Keiko</td><td>69</td><td>9</td></tr><tr><td>63</td><td>Jean-Luc</td><td>58</td><td>54</td></tr><tr><td>64</td><td>Elim</td><td>31</td><td>15</td></tr><tr><td>65</td><td>Guinan</td><td>52</td><td>169</td></tr><tr><td>66</td><td>Geordi</td><td>21</td><td>477</td></tr><tr><td>67</td><td>Jadzia</ ...

# %%
PermTable = ''
df.write.format("parquet").saveAsTable('PermTable')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">Py4JJavaError</span>                             Traceback (most recent call last)
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">     62</span>         <span class="ansi-green-fg">try</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">---&gt; 63</span><span class="ansi-red-fg">             </span><span class="ansi-green-fg">return</span> f<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">*</span>a<span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">**</span>kw<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">     64</span>         <span class="ansi-green-fg">except</span> py4j<span class="ansi-blue-fg">.</span>protocol<span class="ansi-blue-fg">.</span>Py4JJavaError <span class="ansi-green-fg">as</span> e<span class="ansi-blue-fg">:</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/lib/py4j-0.10.7-src.zip/py4j/protocol.py</span> in <span class="ansi-cyan-fg">get_return_value</span><span class="ansi-blue-fg">(answer, gateway_client, target_id, name)</span>
# <span class="ansi-green-intense-fg ansi-bold">    327</span>                     <span class="ansi-blue-fg">&#34;An error occurred while calling {0}{1}{2}.\n&#34;</span><span class="ansi-blue-fg">.</span>
# <span class="ansi-green-fg">--&gt; 328</span><span class="ansi-red-fg">                     format(target_id, &#34;.&#34;, name), value)
# </span><span class="ansi-green-intense-fg ansi-bold">    329</span>             <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
#
# <span class="ansi-red-fg">Py4JJavaError</span>: An error occurred while calling o622.saveAsTable.
# : org.apache.spark.sql.AnalysisException: Table `PermTable` already exists.;
# 	at org.apache.spark.sql.DataFrameWriter.saveAsTable(DataFrameWriter.scala:450)
# 	at org.apache.spark.sql.DataFrameWriter.saveAsTable(DataFrameWriter.scala:430)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:380)
# 	at py4j.Gateway.invoke(Gateway.java:295)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:251)
# 	at java.lang.Thread.run(Thread.java:748)
#
#
# During handling of the above exception, another exception occurred:
#
# <span class="ansi-red-fg">AnalysisException</span>                         Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1501490288572982&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> PermTable <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#39;&#39;</span>
# <span class="ansi-green-fg">----&gt; 2</span><span class="ansi-red-fg"> </span>df<span class="ansi-blue-fg">.</span>write<span class="ansi-blue-fg">.</span>format<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;parquet&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>saveAsTable<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;PermTable&#39;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span> display<span class="ansi-blue-fg">(</span>permTable<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/readwriter.py</span> in <span class="ansi-cyan-fg">saveAsTable</span><span class="ansi-blue-fg">(self, name, format, mode, partitionBy, **options)</span>
# <span class="ansi-green-intense-fg ansi-bold">    776</span>         <span class="ansi-green-fg">if</span> format <span class="ansi-green-fg">is</span> <span class="ansi-green-fg">not</span> <span class="ansi-green-fg">None</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    777</span>             self<span class="ansi-blue-fg">.</span>format<span class="ansi-blue-fg">(</span>format<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">--&gt; 778</span><span class="ansi-red-fg">         </span>self<span class="ansi-blue-fg">.</span>_jwrite<span class="ansi-blue-fg">.</span>saveAsTable<span class="ansi-blue-fg">(</span>name<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    779</span>
# <span class="ansi-green-intense-fg ansi-bold">    780</span>     <span class="ansi-blue-fg">@</span>since<span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">1.4</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py</span> in <span class="ansi-cyan-fg">__call__</span><span class="ansi-blue-fg">(self, *args)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1255</span>         answer <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>gateway_client<span class="ansi-blue-fg">.</span>send_command<span class="ansi-blue-fg">(</span>command<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1256</span>         return_value = get_return_value(
# <span class="ansi-green-fg">-&gt; 1257</span><span class="ansi-red-fg">             answer, self.gateway_client, self.target_id, self.name)
# </span><span class="ansi-green-intense-fg ansi-bold">   1258</span>
# <span class="ansi-green-intense-fg ansi-bold">   1259</span>         <span class="ansi-green-fg">for</span> temp_arg <span class="ansi-green-fg">in</span> temp_args<span class="ansi-blue-fg">:</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">     67</span>                                              e.java_exception.getStackTrace()))
# <span class="ansi-green-intense-fg ansi-bold">     68</span>             <span class="ansi-green-fg">if</span> s<span class="ansi-blue-fg">.</span>startswith<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;org.apache.spark.sql.AnalysisException: &#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">---&gt; 69</span><span class="ansi-red-fg">                 </span><span class="ansi-green-fg">raise</span> AnalysisException<span class="ansi-blue-fg">(</span>s<span class="ansi-blue-fg">.</span>split<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;: &#39;</span><span class="ansi-blue-fg">,</span> <span class="ansi-cyan-fg">1</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">[</span><span class="ansi-cyan-fg">1</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">,</span> stackTrace<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">     70</span>             <span class="ansi-green-fg">if</span> s<span class="ansi-blue-fg">.</span>startswith<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;org.apache.spark.sql.catalyst.analysi

# %%
l = [('Alice','Ram')]

spark.createDataFrame(l,['name','age']).collect()
type(l)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: list</div>

# %%
rdd = sc.parallelize(l)
spark.createDataFrame(rdd,['name','age']).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[17]: [Row(name=&#39;Alice&#39;, age=&#39;Ram&#39;)]</div>

# %%
from pyspark.sql import Row
Person = Row('name','age')
person = rdd.map(lambda r: Person(*r))
spark.createDataFrame(person).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[18]: [Row(name=&#39;Alice&#39;, age=&#39;Ram&#39;)]</div>

# %%
from pyspark.sql.types import * 
schema = StructType([
  StructField('name', StringType(),True),
  StructField('age', StringType(),True)
])

df3 = spark.createDataFrame(rdd,schema)
df3.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: [Row(name=&#39;Alice&#39;, age=&#39;Ram&#39;)]</div>

# %%
df = spark.createDataFrame([("a", 1), ("b", 2), ("c",  3)], ["Col1", "Col2"])
df.select(df.colRegex("`(Col1)?+.+`")).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: [Row(Col2=1), Row(Col2=2), Row(Col2=3)]</div>

# %%
df.createGlobalTempView("friends")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">Py4JJavaError</span>                             Traceback (most recent call last)
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">     62</span>         <span class="ansi-green-fg">try</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">---&gt; 63</span><span class="ansi-red-fg">             </span><span class="ansi-green-fg">return</span> f<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">*</span>a<span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">**</span>kw<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">     64</span>         <span class="ansi-green-fg">except</span> py4j<span class="ansi-blue-fg">.</span>protocol<span class="ansi-blue-fg">.</span>Py4JJavaError <span class="ansi-green-fg">as</span> e<span class="ansi-blue-fg">:</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/lib/py4j-0.10.7-src.zip/py4j/protocol.py</span> in <span class="ansi-cyan-fg">get_return_value</span><span class="ansi-blue-fg">(answer, gateway_client, target_id, name)</span>
# <span class="ansi-green-intense-fg ansi-bold">    327</span>                     <span class="ansi-blue-fg">&#34;An error occurred while calling {0}{1}{2}.\n&#34;</span><span class="ansi-blue-fg">.</span>
# <span class="ansi-green-fg">--&gt; 328</span><span class="ansi-red-fg">                     format(target_id, &#34;.&#34;, name), value)
# </span><span class="ansi-green-intense-fg ansi-bold">    329</span>             <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
#
# <span class="ansi-red-fg">Py4JJavaError</span>: An error occurred while calling o1098.createGlobalTempView.
# : org.apache.spark.sql.catalyst.analysis.TempTableAlreadyExistsException: Temporary view &#39;friends&#39; already exists;
# 	at org.apache.spark.sql.catalyst.catalog.GlobalTempViewManager.create(GlobalTempViewManager.scala:61)
# 	at org.apache.spark.sql.catalyst.catalog.SessionCatalog.createGlobalTempView(SessionCatalog.scala:532)
# 	at org.apache.spark.sql.execution.command.CreateViewCommand.run(views.scala:150)
# 	at org.apache.spark.sql.execution.command.ExecutedCommandExec.sideEffectResult$lzycompute(commands.scala:70)
# 	at org.apache.spark.sql.execution.command.ExecutedCommandExec.sideEffectResult(commands.scala:68)
# 	at org.apache.spark.sql.execution.command.ExecutedCommandExec.executeCollect(commands.scala:79)
# 	at org.apache.spark.sql.Dataset$$anonfun$6.apply(Dataset.scala:205)
# 	at org.apache.spark.sql.Dataset$$anonfun$6.apply(Dataset.scala:205)
# 	at org.apache.spark.sql.Dataset$$anonfun$54.apply(Dataset.scala:3485)
# 	at org.apache.spark.sql.Dataset$$anonfun$54.apply(Dataset.scala:3480)
# 	at org.apache.spark.sql.execution.SQLExecution$$anonfun$withCustomExecutionEnv$1.apply(SQLExecution.scala:111)
# 	at org.apache.spark.sql.execution.SQLExecution$.withSQLConfPropagated(SQLExecution.scala:240)
# 	at org.apache.spark.sql.execution.SQLExecution$.withCustomExecutionEnv(SQLExecution.scala:97)
# 	at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId(SQLExecution.scala:170)
# 	at org.apache.spark.sql.Dataset.org$apache$spark$sql$Dataset$$withAction(Dataset.scala:3480)
# 	at org.apache.spark.sql.Dataset.&lt;init&gt;(Dataset.scala:205)
# 	at org.apache.spark.sql.Dataset$.ofRows(Dataset.scala:81)
# 	at org.apache.spark.sql.Dataset.org$apache$spark$sql$Dataset$$withPlan(Dataset.scala:3527)
# 	at org.apache.spark.sql.Dataset.createGlobalTempView(Dataset.scala:3208)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:380)
# 	at py4j.Gateway.invoke(Gateway.java:295)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:251)
# 	at java.lang.Thread.run(Thread.java:748)
#
#
# During handling of the above exception, another exception occurred:
#
# <span class="ansi-red-fg">AnalysisException</span>                         Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1501490288572997&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>df<span class="ansi-blue-fg">.</span>createGlobalTempView<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;friends&#34;</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/dataframe.py</span> in <span class="ansi-cyan-fg">createGlobalTempView</span><span class="ansi-blue-fg">(self, name)</span>
# <span class="ansi-green-intense-fg ansi-bold">    201</span>
# <span class="ansi-green-intense-fg ansi-bold">    202</span>         &#34;&#34;&#34;
# <span class="ansi-green-fg">--&gt; 203</span><span class="ansi-red-fg">         </span>self<span class="ansi-blue-fg">.</span>_jdf<span class="ansi-blue-fg">.</span>createGlobalTempView<span class="ansi-blue-fg">(</span>name<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    204</span>
# <span class="ansi-green-intense-fg ansi-bold">    205</span>     <span class="ansi-blue-fg">@</span>since<span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">2.2</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py</span> in <span class="ansi-cyan-fg">__call__</span><span class="ansi-blue-fg">(self, *args)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1255</span>         answer <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>gateway_client<span class="ansi-blue-fg">.</span>send_command<span class="ansi-blue-fg">(</span>command<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1256</span>         return_value = get_return_value(
# <span class="ansi-green-fg">-&gt; 1257</span><span class="ansi-red-fg">             answer, self.gateway_client, self.target_id, self.name)
# </span><span class="ansi-green-intense-fg ansi-bold">   1258</span>
# <span class="ansi-green-intense-fg ansi-bold">   1259</span>         <span class="ansi-green-fg">for</span> temp_arg <span class="ansi-green-fg">in</span> temp_args<span class="ansi-blue-fg">:</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">     69</span>                 <span class="ansi-green-fg">raise</span> AnalysisException<span class="ansi-blue-fg">(</span>s<span class="ansi-blue-fg">.</span>split<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;: &#39;</span><span class="ansi-blue-fg">,</span> <span class="ansi-cyan-fg">1</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">[</span><span class="ansi-cyan-fg">1</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">,</span> stackTrace<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">

# %%
df2 = spark.sql('select * from global_temp.friends')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sorted(df.collect()) == sorted(df2.collect())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[25]: True</div>

# %%
spark.catalog.dropGlobalTempView("friends")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.cube('Name',df.Age).count().orderBy("Name", "Age").collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[51]: [Row(Name=None, Age=None, count=500),
#  Row(Name=None, Age=18, count=8),
#  Row(Name=None, Age=19, count=11),
#  Row(Name=None, Age=20, count=5),
#  Row(Name=None, Age=21, count=8),
#  Row(Name=None, Age=22, count=7),
#  Row(Name=None, Age=23, count=10),
#  Row(Name=None, Age=24, count=5),
#  Row(Name=None, Age=25, count=11),
#  Row(Name=None, Age=26, count=17),
#  Row(Name=None, Age=27, count=8),
#  Row(Name=None, Age=28, count=10),
#  Row(Name=None, Age=29, count=12),
#  Row(Name=None, Age=30, count=11),
#  Row(Name=None, Age=31, count=8),
#  Row(Name=None, Age=32, count=11),
#  Row(Name=None, Age=33, count=12),
#  Row(Name=None, Age=34, count=6),
#  Row(Name=None, Age=35, count=8),
#  Row(Name=None, Age=36, count=10),
#  Row(Name=None, Age=37, count=9),
#  Row(Name=None, Age=38, count=15),
#  Row(Name=None, Age=39, count=7),
#  Row(Name=None, Age=40, count=17),
#  Row(Name=None, Age=41, count=9),
#  Row(Name=None, Age=42, count=6),
#  Row(Name=None, Age=43, count=7),
#  Row(Name=None, Age=44, count=12),
#  Row(Name=None, Age=45, count=13),
#  Row(Name=None, Age=46, count=13),
#  Row(Name=None, Age=47, count=9),
#  Row(Name=None, Age=48, count=10),
#  Row(Name=None, Age=49, count=6),
#  Row(Name=None, Age=50, count=5),
#  Row(Name=None, Age=51, count=7),
#  Row(Name=None, Age=52, count=11),
#  Row(Name=None, Age=53, count=7),
#  Row(Name=None, Age=54, count=13),
#  Row(Name=None, Age=55, count=13),
#  Row(Name=None, Age=56, count=6),
#  Row(Name=None, Age=57, count=12),
#  Row(Name=None, Age=58, count=11),
#  Row(Name=None, Age=59, count=9),
#  Row(Name=None, Age=60, count=7),
#  Row(Name=None, Age=61, count=9),
#  Row(Name=None, Age=62, count=13),
#  Row(Name=None, Age=63, count=4),
#  Row(Name=None, Age=64, count=12),
#  Row(Name=None, Age=65, count=5),
#  Row(Name=None, Age=66, count=9),
#  Row(Name=None, Age=67, count=16),
#  Row(Name=None, Age=68, count=10),
#  Row(Name=None, Age=69, count=10),
#  Row(Name=&#39;Ben&#39;, Age=None, count=17),
#  Row(Name=&#39;Ben&#39;, Age=21, count=1),
#  Row(Name=&#39;Ben&#39;, Age=28, count=2),
#  Row(Name=&#39;Ben&#39;, Age=29, count=1),
#  Row(Name=&#39;Ben&#39;, Age=30, count=1),
#  Row(Name=&#39;Ben&#39;, Age=45, count=2),
#  Row(Name=&#39;Ben&#39;, Age=47, count=1),
#  Row(Name=&#39;Ben&#39;, Age=48, count=1),
#  Row(Name=&#39;Ben&#39;, Age=52, count=1),
#  Row(Name=&#39;Ben&#39;, Age=57, count=2),
#  Row(Name=&#39;Ben&#39;, Age=61, count=1),
#  Row(Name=&#39;Ben&#39;, Age=64, count=1),
#  Row(Name=&#39;Ben&#39;, Age=66, count=1),
#  Row(Name=&#39;Ben&#39;, Age=67, count=1),
#  Row(Name=&#39;Ben&#39;, Age=69, count=1),
#  Row(Name=&#39;Beverly&#39;, Age=None, count=20),
#  Row(Name=&#39;Beverly&#39;, Age=18, count=2),
#  Row(Name=&#39;Beverly&#39;, Age=19, count=1),
#  Row(Name=&#39;Beverly&#39;, Age=23, count=2),
#  Row(Name=&#39;Beverly&#39;, Age=24, count=1),
#  Row(Name=&#39;Beverly&#39;, Age=25, count=1),
#  Row(Name=&#39;Beverly&#39;, Age=27, count=1),
#  Row(Name=&#39;Beverly&#39;, Age=37, count=1),
#  Row(Name=&#39;Beverly&#39;, Age=46, count=1),
#  Row(Name=&#39;Beverly&#39;, Age=49, count=2),
#  Row(Name=&#39;Beverly&#39;, Age=50, count=1),
#  Row(Name=&#39;Beverly&#39;, Age=53, count=1),
#  Row(Name=&#39;Beverly&#39;, Age=54, count=1),
#  Row(Name=&#39;Beverly&#39;, Age=55, count=1),
#  Row(Name=&#39;Beverly&#39;, Age=57, count=1),
#  Row(Name=&#39;Beverly&#39;, Age=58, count=1),
#  Row(Name=&#39;Beverly&#39;, Age=62, count=1),
#  Row(Name=&#39;Beverly&#39;, Age=64, count=1),
#  Row(Name=&#39;Brunt&#39;, Age=None, count=22),
#  Row(Name=&#39;Brunt&#39;, Age=19, count=1),
#  Row(Name=&#39;Brunt&#39;, Age=20, count=1),
#  Row(Name=&#39;Brunt&#39;, Age=24, count=1),
#  Row(Name=&#39;Brunt&#39;, Age=26, count=2),
#  Row(Name=&#39;Brunt&#39;, Age=27, count=1),
#  Row(Name=&#39;Brunt&#39;, Age=28, count=1),
#  Row(Name=&#39;Brunt&#39;, Age=33, count=1),
#  Row(Name=&#39;Brunt&#39;, Age=34, count=1),
#  Row(Name=&#39;Brunt&#39;, Age=35, count=1),
#  Row(Name=&#39;Brunt&#39;, Age=38, count=1),
#  Row(Name=&#39;Brunt&#39;, Age=45, count=1),
#  Row(Name=&#39;Brunt&#39;, Age=48, count=1),
#  Row(Name=&#39;Brunt&#39;, Age=52, count=2),
#  Row(Name=&#39;Brunt&#39;, Age=54, count=1),
#  Row(Name=&#39;Brunt&#39;, Age=55, count=1),
#  Row(Name=&#39;Brunt&#39;, Age=62, count=2),
#  Row(Name=&#39;Brunt&#39;, Age=65, count=1),
#  Row(Name=&#39;Brunt&#39;, Age=67, count=1),
#  Row(Name=&#39;Brunt&#39;, Age=69, count=1),
#  Row(Name=&#39;Data&#39;, Age=None, count=25),
#  Row(Name=&#39;Data&#39;, Age=18, count=2),
#  Row(Name=&#39;Data&#39;, Age=25, count=1),
#  Row(Name=&#39;Data&#39;, Age=29, count=1),
#  Row(Name=&#39;Data&#39;, Age=30, count=1),
#  Row(Name=&#39;Data&#39;, Age=33, count=1),
#  Row(Name=&#39;Data&#39;, Age=35, count=1),
#  Row(Name=&#39;Data&#39;, Age=38, count=2),
#  Row(Name=&#39;Data&#39;, Age=39, count=1),
#  Row(Name=&#39;Data&#39;, Age=43, count=1),
#  Row(Name=&#39;Data&#39;, Age=44, count=3),
#  Row(Name=&#39;Data&#39;, Age=45, count=1),
#  Row(Name=&#39;Data&#39;, Age=46, count=1),
#  Row(Name=&#39;Data&#39;, Age=47, count=1),
#  Row(Name=&#39;Data&#39;, Age=51, count=2),
#  Row(Name=&#39;Data&#39;, Age=52, count=1),
#  Row(Name=&#39;Data&#39;, Age=60, count=2),
#  Row(Name=&#39;Data&#39;, Age=61, count=1),
#  Row(Name=&#39;Data&#39;, Age=64, count=1),
#  Row(Name=&#39;Data&#39;, Age=69, count=1),
#  Row(Name=&#39;Deanna&#39;, Age=None, count=17),
#  Row(Name=&#39;Deanna&#39;, Age=23, count=1),
#  Row(Name=&#39;Deanna&#39;, Age=25, count=1),
#  Row(Name=&#39;Deanna&#39;, Age=27, count=1),
#  Row(Name=&#39;Deanna&#39;, Age=35, count=2),
#  Row(Name=&#39;Deanna&#39;, Age=38, count=1),
#  Row(Name=&#39;Deanna&#39;, Age=40, count=1),
#  Row(Name=&#39;Deanna&#39;, Age=44, count=1),
#  Row(Name=&#39;Deanna&#39;, Age=46, count=2),
#  Row(Name=&#39;Deanna&#39;, Age=47, count=1),
#  Row(Name=&#39;Deanna&#39;, Age=49, count=1),
#  Row(Name=&#39;Deanna&#39;, Age=57, count=1),
#  Row(Name=&#39;Deanna&#39;, Age=60, count=1),
#  Row(Name=&#39;Deanna&#39;, Age=62, count=1),
#  Row(Name=&#39;Deanna&#39;, Age=64, count=2),
#  Row(Name=&#39;Dukat&#39;, Age=None, count=21),
#  Row(Name=&#39;Dukat&#39;, Age=18, count=1),
#  Row(Name=&#39;Dukat&#39;, Age=19, count=1),
#  Row(Name=&#39;Dukat&#39;, Age=21, count=2),
#  Row(Name=&#39;Dukat&#39;, Age=23, count=1),
#  Row(Name=&#39;Dukat&#39;, Age=27, count=1),
#  Row(Name=&#39;Dukat&#39;, Age=32, count=2),
#  Row(Name=&#39;Dukat&#39;, Age=34, count=1),
#  Row(Name=&#39;Dukat&#39;, Age=40, count=1),
#  Row(Name=&#39;Dukat&#39;, Age=41, count=2),
#  Row(Name=&#39;Dukat&#39;, Age=49, count=1),
#  Row(Name=&#39;Dukat&#39;, Age=52, count=1),
#  Row(Name=&#39;Dukat&#39;, Age=53, count=1),
#  Row(Name=&#39;Dukat&#39;, Age=54, count=1),
#  Row(Name=&#39;Dukat&#39;, Age=59, count=1),
#  Row(Name=&#39;Dukat&#39;, Age=62, count=1),
#  Row(Name=&#39;Dukat&#39;, Age=65, count=1),
#  Row(Name=&#39;Dukat&#39;, Age=67, count=2),
#  Row(Name=&#39;Elim&#39;, Age=None, count=12),
#  Row(Name=&#39;Elim&#39;, Age=19, count=1),
#  Row(Name=&#39;Elim&#39;, Age=26, count=1),
#  Row(Name=&#39;Elim&#39;, Age=31, count=1),
#  Row(Name=&#39;Elim&#39;, Age=32, count=1),
#  Row(Name=&#39;Elim&#39;, Age=33, count=1),
#  Row(Name=&#39;Elim&#39;, Age=37, count=1),
#  Row(Name=&#39;Elim&#39;, Age=44, count=1),
#  Row(Name=&#39;Elim&#39;, Age=46, count=1),
#  Row(Name=&#39;Elim&#39;, Age=48, count=1),
#  Row(Name=&#39;Elim&#39;, Age=49, count=1),
#  Row(Name=&#39;Elim&#39;, Age=57, count=1),
#  Row(Name=&#39;Elim&#39;, Age=64, count=1),
#  Row(Name=&#39;Ezri&#39;, Age=None, count=20),
#  Row(Name=&#39;Ezri&#39;, Age=23, count=1),
#  Row(Name=&#39;Ezri&#39;, Age=25, count=1),
#  Row(Name=&#39;Ezri&#39;, Age=26, count=1),
#  Row(Name=&#39;Ezri&#39;, Age=30, count=1),
#  Row(Name=&#39;Ezri&#39;, Age=31, count=2),
#  Row(Name=&#39;Ezri&#39;, Age=33, count=1),
#  Row(Name=&#39;Ezri&#39;, Age=37, count=1),
#  Row(Name=&#39;Ezri&#39;, Age=38, count=1),
#  Row(Name=&#39;Ezri&#39;, Age=39, count=1),
#  Row(Name=&#39;Ezri&#39;

# %%
df.select('Name').distinct().count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[53]: 30</div>

# %%
df.distinct(df.Name).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">TypeError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1501490288573004&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>df<span class="ansi-blue-fg">.</span>distinct<span class="ansi-blue-fg">(</span>df<span class="ansi-blue-fg">.</span>Name<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>count<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">TypeError</span>: distinct() takes 1 positional argument but 2 were given</div>

# %%
df.na.drop().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+--------+---+-------+
#  Id|    Name|Age|Friends|
# +---+--------+---+-------+
#   0|    Will| 33|    385|
#   1|Jean-Luc| 26|      2|
#   2|    Hugh| 55|    221|
#   3|  Deanna| 40|    465|
#   4|   Quark| 68|     21|
#   5|  Weyoun| 59|    318|
#   6|  Gowron| 37|    220|
#   7|    Will| 54|    307|
#   8|  Jadzia| 38|    380|
#   9|    Hugh| 27|    181|
#  10|     Odo| 53|    191|
#  11|     Ben| 57|    372|
#  12|   Keiko| 54|    253|
#  13|Jean-Luc| 56|    444|
#  14|    Hugh| 43|     49|
#  15|     Rom| 36|     49|
#  16|  Weyoun| 22|    323|
#  17|     Odo| 35|     13|
#  18|Jean-Luc| 45|    455|
#  19|  Geordi| 60|    246|
# +---+--------+---+-------+
# only showing top 20 rows
#
# </div>

# %%
df.filter(df.Age>18).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[60]: [Row(Id=0, Name=&#39;Will&#39;, Age=33, Friends=385),
#  Row(Id=1, Name=&#39;Jean-Luc&#39;, Age=26, Friends=2),
#  Row(Id=2, Name=&#39;Hugh&#39;, Age=55, Friends=221),
#  Row(Id=3, Name=&#39;Deanna&#39;, Age=40, Friends=465),
#  Row(Id=4, Name=&#39;Quark&#39;, Age=68, Friends=21),
#  Row(Id=5, Name=&#39;Weyoun&#39;, Age=59, Friends=318),
#  Row(Id=6, Name=&#39;Gowron&#39;, Age=37, Friends=220),
#  Row(Id=7, Name=&#39;Will&#39;, Age=54, Friends=307),
#  Row(Id=8, Name=&#39;Jadzia&#39;, Age=38, Friends=380),
#  Row(Id=9, Name=&#39;Hugh&#39;, Age=27, Friends=181),
#  Row(Id=10, Name=&#39;Odo&#39;, Age=53, Friends=191),
#  Row(Id=11, Name=&#39;Ben&#39;, Age=57, Friends=372),
#  Row(Id=12, Name=&#39;Keiko&#39;, Age=54, Friends=253),
#  Row(Id=13, Name=&#39;Jean-Luc&#39;, Age=56, Friends=444),
#  Row(Id=14, Name=&#39;Hugh&#39;, Age=43, Friends=49),
#  Row(Id=15, Name=&#39;Rom&#39;, Age=36, Friends=49),
#  Row(Id=16, Name=&#39;Weyoun&#39;, Age=22, Friends=323),
#  Row(Id=17, Name=&#39;Odo&#39;, Age=35, Friends=13),
#  Row(Id=18, Name=&#39;Jean-Luc&#39;, Age=45, Friends=455),
#  Row(Id=19, Name=&#39;Geordi&#39;, Age=60, Friends=246),
#  Row(Id=20, Name=&#39;Odo&#39;, Age=67, Friends=220),
#  Row(Id=21, Name=&#39;Miles&#39;, Age=19, Friends=268),
#  Row(Id=22, Name=&#39;Quark&#39;, Age=30, Friends=72),
#  Row(Id=23, Name=&#39;Keiko&#39;, Age=51, Friends=271),
#  Row(Id=24, Name=&#39;Julian&#39;, Age=25, Friends=1),
#  Row(Id=25, Name=&#39;Ben&#39;, Age=21, Friends=445),
#  Row(Id=26, Name=&#39;Julian&#39;, Age=22, Friends=100),
#  Row(Id=27, Name=&#39;Leeta&#39;, Age=42, Friends=363),
#  Row(Id=28, Name=&#39;Martok&#39;, Age=49, Friends=476),
#  Row(Id=29, Name=&#39;Nog&#39;, Age=48, Friends=364),
#  Row(Id=30, Name=&#39;Keiko&#39;, Age=50, Friends=175),
#  Row(Id=31, Name=&#39;Miles&#39;, Age=39, Friends=161),
#  Row(Id=32, Name=&#39;Nog&#39;, Age=26, Friends=281),
#  Row(Id=33, Name=&#39;Dukat&#39;, Age=53, Friends=197),
#  Row(Id=34, Name=&#39;Jean-Luc&#39;, Age=43, Friends=249),
#  Row(Id=35, Name=&#39;Beverly&#39;, Age=27, Friends=305),
#  Row(Id=36, Name=&#39;Kasidy&#39;, Age=32, Friends=81),
#  Row(Id=37, Name=&#39;Geordi&#39;, Age=58, Friends=21),
#  Row(Id=38, Name=&#39;Deanna&#39;, Age=64, Friends=65),
#  Row(Id=39, Name=&#39;Morn&#39;, Age=31, Friends=192),
#  Row(Id=40, Name=&#39;Odo&#39;, Age=52, Friends=413),
#  Row(Id=41, Name=&#39;Hugh&#39;, Age=67, Friends=167),
#  Row(Id=42, Name=&#39;Brunt&#39;, Age=54, Friends=75),
#  Row(Id=43, Name=&#39;Guinan&#39;, Age=58, Friends=345),
#  Row(Id=44, Name=&#39;Nerys&#39;, Age=35, Friends=244),
#  Row(Id=45, Name=&#39;Dukat&#39;, Age=52, Friends=77),
#  Row(Id=46, Name=&#39;Morn&#39;, Age=25, Friends=96),
#  Row(Id=47, Name=&#39;Brunt&#39;, Age=24, Friends=49),
#  Row(Id=48, Name=&#39;Nog&#39;, Age=20, Friends=1),
#  Row(Id=49, Name=&#39;Ezri&#39;, Age=40, Friends=254),
#  Row(Id=50, Name=&#39;Quark&#39;, Age=51, Friends=283),
#  Row(Id=51, Name=&#39;Lwaxana&#39;, Age=36, Friends=212),
#  Row(Id=52, Name=&#39;Beverly&#39;, Age=19, Friends=269),
#  Row(Id=53, Name=&#39;Geordi&#39;, Age=62, Friends=31),
#  Row(Id=54, Name=&#39;Brunt&#39;, Age=19, Friends=5),
#  Row(Id=55, Name=&#39;Keiko&#39;, Age=41, Friends=278),
#  Row(Id=56, Name=&#39;Gowron&#39;, Age=44, Friends=194),
#  Row(Id=57, Name=&#39;Odo&#39;, Age=57, Friends=294),
#  Row(Id=58, Name=&#39;Hugh&#39;, Age=59, Friends=158),
#  Row(Id=59, Name=&#39;Morn&#39;, Age=59, Friends=284),
#  Row(Id=60, Name=&#39;Geordi&#39;, Age=20, Friends=100),
#  Row(Id=61, Name=&#39;Kasidy&#39;, Age=62, Friends=442),
#  Row(Id=62, Name=&#39;Keiko&#39;, Age=69, Friends=9),
#  Row(Id=63, Name=&#39;Jean-Luc&#39;, Age=58, Friends=54),
#  Row(Id=64, Name=&#39;Elim&#39;, Age=31, Friends=15),
#  Row(Id=65, Name=&#39;Guinan&#39;, Age=52, Friends=169),
#  Row(Id=66, Name=&#39;Geordi&#39;, Age=21, Friends=477),
#  Row(Id=67, Name=&#39;Jadzia&#39;, Age=48, Friends=135),
#  Row(Id=68, Name=&#39;Guinan&#39;, Age=33, Friends=74),
#  Row(Id=69, Name=&#39;Jean-Luc&#39;, Age=30, Friends=204),
#  Row(Id=70, Name=&#39;Brunt&#39;, Age=52, Friends=393),
#  Row(Id=71, Name=&#39;Geordi&#39;, Age=45, Friends=184),
#  Row(Id=72, Name=&#39;Kasidy&#39;, Age=22, Friends=179),
#  Row(Id=73, Name=&#39;Brunt&#39;, Age=20, Friends=384),
#  Row(Id=74, Name=&#39;Leeta&#39;, Age=65, Friends=208),
#  Row(Id=75, Name=&#39;Morn&#39;, Age=40, Friends=459),
#  Row(Id=76, Name=&#39;Will&#39;, Age=62, Friends=201),
#  Row(Id=77, Name=&#39;Weyoun&#39;, Age=40, Friends=407),
#  Row(Id=78, Name=&#39;Data&#39;, Age=61, Friends=337),
#  Row(Id=79, Name=&#39;Leeta&#39;, Age=58, Friends=348),
#  Row(Id=80, Name=&#39;Dukat&#39;, Age=67, Friends=445),
#  Row(Id=81, Name=&#39;Jadzia&#39;, Age=54, Friends=440),
#  Row(Id=82, Name=&#39;Hugh&#39;, Age=57, Friends=465),
#  Row(Id=83, Name=&#39;Geordi&#39;, Age=32, Friends=308),
#  Row(Id=84, Name=&#39;Ben&#39;, Age=28, Friends=311),
#  Row(Id=85, Name=&#39;Quark&#39;, Age=66, Friends=383),
#  Row(Id=86, Name=&#39;Hugh&#39;, Age=55, Friends=257),
#  Row(Id=87, Name=&#39;Ezri&#39;, Age=31, Friends=481),
#  Row(Id=88, Name=&#39;Ben&#39;, Age=66, Friends=188),
#  Row(Id=89, Name=&#39;Worf&#39;, Age=24, Friends=492),
#  Row(Id=90, Name=&#39;Kasidy&#39;, Age=33, Friends=471),
#  Row(Id=91, Name=&#39;Rom&#39;, Age=46, Friends=88),
#  Row(Id=92, Name=&#39;Gowron&#39;, Age=54, Friends=7),
#  Row(Id=93, Name=&#39;Elim&#39;, Age=46, Friends=63),
#  Row(Id=94, Name=&#39;Morn&#39;, Age=62, Friends=133),
#  Row(Id=95, Name=&#39;Odo&#39;, Age=29, Friends=173),
#  Row(Id=96, Name=&#39;Ezri&#39;, Age=25, Friends=233),
#  Row(Id=97, Name=&#39;Nerys&#39;, Age=69, Friends=361),
#  Row(Id=98, Name=&#39;Will&#39;, Age=44, Friends=178),
#  Row(Id=99, Name=&#39;Keiko&#39;, Age=69, Friends=491),
#  Row(Id=100, Name=&#39;Jean-Luc&#39;, Age=61, Friends=460),
#  Row(Id=101, Name=&#39;Morn&#39;, Age=67, Friends=123),
#  Row(Id=102, Name=&#39;Dukat&#39;, Age=40, Friends=18),
#  Row(Id=103, Name=&#39;Ezri&#39;, Age=61, Friends=2),
#  Row(Id=104, Name=&#39;Dukat&#39;, Age=32, Friends=142),
#  Row(Id=105, Name=&#39;Morn&#39;, Age=50, Friends=417),
#  Row(Id=107, Name=&#39;Will&#39;, Age=64, Friends=419),
#  Row(Id=108, Name=&#39;Leeta&#39;, Age=25, Friends=274),
#  Row(Id=109, Name=&#39;Quark&#39;, Age=53, Friends=417),
#  Row(Id=110, Name=&#39;Nog&#39;, Age=64, Friends=137),
#  Row(Id=111, Name=&#39;Nerys&#39;, Age=37, Friends=46),
#  Row(Id=112, Name=&#39;Morn&#39;, Age=25, Friends=13),
#  Row(Id=113, Name=&#39;Quark&#39;, Age=41, Friends=244),
#  Row(Id=114, Name=&#39;Worf&#39;, Age=33, Friends=275),
#  Row(Id=116, Name=&#39;Ben&#39;, Age=69, Friends=75),
#  Row(Id=117, Name=&#39;Rom&#39;, Age=52, Friends=487),
#  Row(Id=118, Name=&#39;Ben&#39;, Age=28, Friends=304),
#  Row(Id=119, Name=&#39;Worf&#39;, Age=29, Friends=344),
#  Row(Id=120, Name=&#39;Jean-Luc&#39;, Age=68, Friends=264),
#  Row(Id=121, Name=&#39;Deanna&#39;, Age=35, Friends=355),
#  Row(Id=122, Name=&#39;Data&#39;, Age=45, Friends=400),
#  Row(Id=123, Name=&#39;Jadzia&#39;, Age=45, Friends=439),
#  Row(Id=124, Name=&#39;Data&#39;, Age=47, Friends=429),
#  Row(Id=125, Name=&#39;Rom&#39;, Age=66, Friends=284),
#  Row(Id=126, Name=&#39;Brunt&#39;, Age=26, Friends=84),
#  Row(Id=127, Name=&#39;Miles&#39;, Age=40, Friends=284),
#  Row(Id=128, Name=&#39;Julian&#39;, Age=34, Friends=221),
#  Row(Id=129, Name=&#39;Kasidy&#39;, Age=45, Friends=252),
#  Row(Id=130, Name=&#39;Gowron&#39;, Age=67, Friends=350),
#  Row(Id=131, Name=&#39;Hugh&#39;, Age=65, Friends=309),
#  Row(Id=132, Name=&#39;Odo&#39;, Age=46, Friends=462),
#  Row(Id=133, Name=&#39;Quark&#39;, Age=19, Friends=265),
#  Row(Id=134, Name=&#39;Ben&#39;, Age=45, Friends=340),
#  Row(Id=135, Name=&#39;Rom&#39;, Age=42, Friends=427),
#  Row(Id=136, Name=&#39;Will&#39;, Age=19, Friends=335),
#  Row(Id=137, Name=&#39;Martok&#39;, Age=28, Friends=32),
#  Row(Id=138, Name=&#39;Dukat&#39;, Age=32, Friends=384),
#  Row(Id=139, Name=

# %%
df.where(df.Age >18).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[61]: [Row(Id=0, Name=&#39;Will&#39;, Age=33, Friends=385),
#  Row(Id=1, Name=&#39;Jean-Luc&#39;, Age=26, Friends=2),
#  Row(Id=2, Name=&#39;Hugh&#39;, Age=55, Friends=221),
#  Row(Id=3, Name=&#39;Deanna&#39;, Age=40, Friends=465),
#  Row(Id=4, Name=&#39;Quark&#39;, Age=68, Friends=21),
#  Row(Id=5, Name=&#39;Weyoun&#39;, Age=59, Friends=318),
#  Row(Id=6, Name=&#39;Gowron&#39;, Age=37, Friends=220),
#  Row(Id=7, Name=&#39;Will&#39;, Age=54, Friends=307),
#  Row(Id=8, Name=&#39;Jadzia&#39;, Age=38, Friends=380),
#  Row(Id=9, Name=&#39;Hugh&#39;, Age=27, Friends=181),
#  Row(Id=10, Name=&#39;Odo&#39;, Age=53, Friends=191),
#  Row(Id=11, Name=&#39;Ben&#39;, Age=57, Friends=372),
#  Row(Id=12, Name=&#39;Keiko&#39;, Age=54, Friends=253),
#  Row(Id=13, Name=&#39;Jean-Luc&#39;, Age=56, Friends=444),
#  Row(Id=14, Name=&#39;Hugh&#39;, Age=43, Friends=49),
#  Row(Id=15, Name=&#39;Rom&#39;, Age=36, Friends=49),
#  Row(Id=16, Name=&#39;Weyoun&#39;, Age=22, Friends=323),
#  Row(Id=17, Name=&#39;Odo&#39;, Age=35, Friends=13),
#  Row(Id=18, Name=&#39;Jean-Luc&#39;, Age=45, Friends=455),
#  Row(Id=19, Name=&#39;Geordi&#39;, Age=60, Friends=246),
#  Row(Id=20, Name=&#39;Odo&#39;, Age=67, Friends=220),
#  Row(Id=21, Name=&#39;Miles&#39;, Age=19, Friends=268),
#  Row(Id=22, Name=&#39;Quark&#39;, Age=30, Friends=72),
#  Row(Id=23, Name=&#39;Keiko&#39;, Age=51, Friends=271),
#  Row(Id=24, Name=&#39;Julian&#39;, Age=25, Friends=1),
#  Row(Id=25, Name=&#39;Ben&#39;, Age=21, Friends=445),
#  Row(Id=26, Name=&#39;Julian&#39;, Age=22, Friends=100),
#  Row(Id=27, Name=&#39;Leeta&#39;, Age=42, Friends=363),
#  Row(Id=28, Name=&#39;Martok&#39;, Age=49, Friends=476),
#  Row(Id=29, Name=&#39;Nog&#39;, Age=48, Friends=364),
#  Row(Id=30, Name=&#39;Keiko&#39;, Age=50, Friends=175),
#  Row(Id=31, Name=&#39;Miles&#39;, Age=39, Friends=161),
#  Row(Id=32, Name=&#39;Nog&#39;, Age=26, Friends=281),
#  Row(Id=33, Name=&#39;Dukat&#39;, Age=53, Friends=197),
#  Row(Id=34, Name=&#39;Jean-Luc&#39;, Age=43, Friends=249),
#  Row(Id=35, Name=&#39;Beverly&#39;, Age=27, Friends=305),
#  Row(Id=36, Name=&#39;Kasidy&#39;, Age=32, Friends=81),
#  Row(Id=37, Name=&#39;Geordi&#39;, Age=58, Friends=21),
#  Row(Id=38, Name=&#39;Deanna&#39;, Age=64, Friends=65),
#  Row(Id=39, Name=&#39;Morn&#39;, Age=31, Friends=192),
#  Row(Id=40, Name=&#39;Odo&#39;, Age=52, Friends=413),
#  Row(Id=41, Name=&#39;Hugh&#39;, Age=67, Friends=167),
#  Row(Id=42, Name=&#39;Brunt&#39;, Age=54, Friends=75),
#  Row(Id=43, Name=&#39;Guinan&#39;, Age=58, Friends=345),
#  Row(Id=44, Name=&#39;Nerys&#39;, Age=35, Friends=244),
#  Row(Id=45, Name=&#39;Dukat&#39;, Age=52, Friends=77),
#  Row(Id=46, Name=&#39;Morn&#39;, Age=25, Friends=96),
#  Row(Id=47, Name=&#39;Brunt&#39;, Age=24, Friends=49),
#  Row(Id=48, Name=&#39;Nog&#39;, Age=20, Friends=1),
#  Row(Id=49, Name=&#39;Ezri&#39;, Age=40, Friends=254),
#  Row(Id=50, Name=&#39;Quark&#39;, Age=51, Friends=283),
#  Row(Id=51, Name=&#39;Lwaxana&#39;, Age=36, Friends=212),
#  Row(Id=52, Name=&#39;Beverly&#39;, Age=19, Friends=269),
#  Row(Id=53, Name=&#39;Geordi&#39;, Age=62, Friends=31),
#  Row(Id=54, Name=&#39;Brunt&#39;, Age=19, Friends=5),
#  Row(Id=55, Name=&#39;Keiko&#39;, Age=41, Friends=278),
#  Row(Id=56, Name=&#39;Gowron&#39;, Age=44, Friends=194),
#  Row(Id=57, Name=&#39;Odo&#39;, Age=57, Friends=294),
#  Row(Id=58, Name=&#39;Hugh&#39;, Age=59, Friends=158),
#  Row(Id=59, Name=&#39;Morn&#39;, Age=59, Friends=284),
#  Row(Id=60, Name=&#39;Geordi&#39;, Age=20, Friends=100),
#  Row(Id=61, Name=&#39;Kasidy&#39;, Age=62, Friends=442),
#  Row(Id=62, Name=&#39;Keiko&#39;, Age=69, Friends=9),
#  Row(Id=63, Name=&#39;Jean-Luc&#39;, Age=58, Friends=54),
#  Row(Id=64, Name=&#39;Elim&#39;, Age=31, Friends=15),
#  Row(Id=65, Name=&#39;Guinan&#39;, Age=52, Friends=169),
#  Row(Id=66, Name=&#39;Geordi&#39;, Age=21, Friends=477),
#  Row(Id=67, Name=&#39;Jadzia&#39;, Age=48, Friends=135),
#  Row(Id=68, Name=&#39;Guinan&#39;, Age=33, Friends=74),
#  Row(Id=69, Name=&#39;Jean-Luc&#39;, Age=30, Friends=204),
#  Row(Id=70, Name=&#39;Brunt&#39;, Age=52, Friends=393),
#  Row(Id=71, Name=&#39;Geordi&#39;, Age=45, Friends=184),
#  Row(Id=72, Name=&#39;Kasidy&#39;, Age=22, Friends=179),
#  Row(Id=73, Name=&#39;Brunt&#39;, Age=20, Friends=384),
#  Row(Id=74, Name=&#39;Leeta&#39;, Age=65, Friends=208),
#  Row(Id=75, Name=&#39;Morn&#39;, Age=40, Friends=459),
#  Row(Id=76, Name=&#39;Will&#39;, Age=62, Friends=201),
#  Row(Id=77, Name=&#39;Weyoun&#39;, Age=40, Friends=407),
#  Row(Id=78, Name=&#39;Data&#39;, Age=61, Friends=337),
#  Row(Id=79, Name=&#39;Leeta&#39;, Age=58, Friends=348),
#  Row(Id=80, Name=&#39;Dukat&#39;, Age=67, Friends=445),
#  Row(Id=81, Name=&#39;Jadzia&#39;, Age=54, Friends=440),
#  Row(Id=82, Name=&#39;Hugh&#39;, Age=57, Friends=465),
#  Row(Id=83, Name=&#39;Geordi&#39;, Age=32, Friends=308),
#  Row(Id=84, Name=&#39;Ben&#39;, Age=28, Friends=311),
#  Row(Id=85, Name=&#39;Quark&#39;, Age=66, Friends=383),
#  Row(Id=86, Name=&#39;Hugh&#39;, Age=55, Friends=257),
#  Row(Id=87, Name=&#39;Ezri&#39;, Age=31, Friends=481),
#  Row(Id=88, Name=&#39;Ben&#39;, Age=66, Friends=188),
#  Row(Id=89, Name=&#39;Worf&#39;, Age=24, Friends=492),
#  Row(Id=90, Name=&#39;Kasidy&#39;, Age=33, Friends=471),
#  Row(Id=91, Name=&#39;Rom&#39;, Age=46, Friends=88),
#  Row(Id=92, Name=&#39;Gowron&#39;, Age=54, Friends=7),
#  Row(Id=93, Name=&#39;Elim&#39;, Age=46, Friends=63),
#  Row(Id=94, Name=&#39;Morn&#39;, Age=62, Friends=133),
#  Row(Id=95, Name=&#39;Odo&#39;, Age=29, Friends=173),
#  Row(Id=96, Name=&#39;Ezri&#39;, Age=25, Friends=233),
#  Row(Id=97, Name=&#39;Nerys&#39;, Age=69, Friends=361),
#  Row(Id=98, Name=&#39;Will&#39;, Age=44, Friends=178),
#  Row(Id=99, Name=&#39;Keiko&#39;, Age=69, Friends=491),
#  Row(Id=100, Name=&#39;Jean-Luc&#39;, Age=61, Friends=460),
#  Row(Id=101, Name=&#39;Morn&#39;, Age=67, Friends=123),
#  Row(Id=102, Name=&#39;Dukat&#39;, Age=40, Friends=18),
#  Row(Id=103, Name=&#39;Ezri&#39;, Age=61, Friends=2),
#  Row(Id=104, Name=&#39;Dukat&#39;, Age=32, Friends=142),
#  Row(Id=105, Name=&#39;Morn&#39;, Age=50, Friends=417),
#  Row(Id=107, Name=&#39;Will&#39;, Age=64, Friends=419),
#  Row(Id=108, Name=&#39;Leeta&#39;, Age=25, Friends=274),
#  Row(Id=109, Name=&#39;Quark&#39;, Age=53, Friends=417),
#  Row(Id=110, Name=&#39;Nog&#39;, Age=64, Friends=137),
#  Row(Id=111, Name=&#39;Nerys&#39;, Age=37, Friends=46),
#  Row(Id=112, Name=&#39;Morn&#39;, Age=25, Friends=13),
#  Row(Id=113, Name=&#39;Quark&#39;, Age=41, Friends=244),
#  Row(Id=114, Name=&#39;Worf&#39;, Age=33, Friends=275),
#  Row(Id=116, Name=&#39;Ben&#39;, Age=69, Friends=75),
#  Row(Id=117, Name=&#39;Rom&#39;, Age=52, Friends=487),
#  Row(Id=118, Name=&#39;Ben&#39;, Age=28, Friends=304),
#  Row(Id=119, Name=&#39;Worf&#39;, Age=29, Friends=344),
#  Row(Id=120, Name=&#39;Jean-Luc&#39;, Age=68, Friends=264),
#  Row(Id=121, Name=&#39;Deanna&#39;, Age=35, Friends=355),
#  Row(Id=122, Name=&#39;Data&#39;, Age=45, Friends=400),
#  Row(Id=123, Name=&#39;Jadzia&#39;, Age=45, Friends=439),
#  Row(Id=124, Name=&#39;Data&#39;, Age=47, Friends=429),
#  Row(Id=125, Name=&#39;Rom&#39;, Age=66, Friends=284),
#  Row(Id=126, Name=&#39;Brunt&#39;, Age=26, Friends=84),
#  Row(Id=127, Name=&#39;Miles&#39;, Age=40, Friends=284),
#  Row(Id=128, Name=&#39;Julian&#39;, Age=34, Friends=221),
#  Row(Id=129, Name=&#39;Kasidy&#39;, Age=45, Friends=252),
#  Row(Id=130, Name=&#39;Gowron&#39;, Age=67, Friends=350),
#  Row(Id=131, Name=&#39;Hugh&#39;, Age=65, Friends=309),
#  Row(Id=132, Name=&#39;Odo&#39;, Age=46, Friends=462),
#  Row(Id=133, Name=&#39;Quark&#39;, Age=19, Friends=265),
#  Row(Id=134, Name=&#39;Ben&#39;, Age=45, Friends=340),
#  Row(Id=135, Name=&#39;Rom&#39;, Age=42, Friends=427),
#  Row(Id=136, Name=&#39;Will&#39;, Age=19, Friends=335),
#  Row(Id=137, Name=&#39;Martok&#39;, Age=28, Friends=32),
#  Row(Id=138, Name=&#39;Dukat&#39;, Age=32, Friends=384),
#  Row(Id=139, Name=

# %%
def f(p):
  print(p.Name)
df.foreach(f)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AttributeError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1501490288573007&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> <span class="ansi-green-fg">def</span> f<span class="ansi-blue-fg">(</span>p<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span>   print<span class="ansi-blue-fg">(</span>p<span class="ansi-blue-fg">.</span>Name<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">----&gt; 3</span><span class="ansi-red-fg"> </span>df<span class="ansi-blue-fg">.</span>foreach<span class="ansi-blue-fg">(</span>f<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>collect<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">AttributeError</span>: &#39;NoneType&#39; object has no attribute &#39;collect&#39;</div>

# %%
def f(people):
   for person in people:
      print(person.Name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.foreachPartition(f)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AttributeError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1501490288573009&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>df<span class="ansi-blue-fg">.</span>foreachPartition<span class="ansi-blue-fg">(</span>f<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>collect<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">AttributeError</span>: &#39;NoneType&#39; object has no attribute &#39;collect&#39;</div>

# %%
sorted(df.groupBy('Age').count().head())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[84]: [8, 31]</div>

# %%
df.isLocal()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[85]: False</div>

# %%
df.isStreaming
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[89]: False</div>

# %%
df2 = df.alias('df2')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.join(df2, df.Name == df2.Name, 'right_outer').select(df.Name).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[102]: 8812</div>

# %%
cond = [df.Name == df2.Name, df.Age == df2.Age]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.join(df2, cond, 'left_anti').select(df.Name).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[109]: 0</div>

# %%
df.limit(2).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+--------+---+-------+
#  Id|    Name|Age|Friends|
# +---+--------+---+-------+
#   0|    Will| 33|    385|
#   1|Jean-Luc| 26|      2|
# +---+--------+---+-------+
#
# </div>

# %%
df.sort('Age',ascending = False).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[114]: [Row(Id=62, Name=&#39;Keiko&#39;, Age=69, Friends=9),
#  Row(Id=97, Name=&#39;Nerys&#39;, Age=69, Friends=361),
#  Row(Id=99, Name=&#39;Keiko&#39;, Age=69, Friends=491),
#  Row(Id=116, Name=&#39;Ben&#39;, Age=69, Friends=75),
#  Row(Id=205, Name=&#39;Morn&#39;, Age=69, Friends=236),
#  Row(Id=253, Name=&#39;Leeta&#39;, Age=69, Friends=116),
#  Row(Id=354, Name=&#39;Kasidy&#39;, Age=69, Friends=15),
#  Row(Id=383, Name=&#39;Data&#39;, Age=69, Friends=148),
#  Row(Id=397, Name=&#39;Quark&#39;, Age=69, Friends=470),
#  Row(Id=487, Name=&#39;Brunt&#39;, Age=69, Friends=431),
#  Row(Id=4, Name=&#39;Quark&#39;, Age=68, Friends=21),
#  Row(Id=120, Name=&#39;Jean-Luc&#39;, Age=68, Friends=264),
#  Row(Id=168, Name=&#39;Martok&#39;, Age=68, Friends=112),
#  Row(Id=170, Name=&#39;Jean-Luc&#39;, Age=68, Friends=490),
#  Row(Id=232, Name=&#39;Worf&#39;, Age=68, Friends=481),
#  Row(Id=258, Name=&#39;Worf&#39;, Age=68, Friends=217),
#  Row(Id=310, Name=&#39;Odo&#39;, Age=68, Friends=189),
#  Row(Id=361, Name=&#39;Worf&#39;, Age=68, Friends=206),
#  Row(Id=374, Name=&#39;Nog&#39;, Age=68, Friends=293),
#  Row(Id=428, Name=&#39;Lwaxana&#39;, Age=68, Friends=423),
#  Row(Id=20, Name=&#39;Odo&#39;, Age=67, Friends=220),
#  Row(Id=41, Name=&#39;Hugh&#39;, Age=67, Friends=167),
#  Row(Id=80, Name=&#39;Dukat&#39;, Age=67, Friends=445),
#  Row(Id=101, Name=&#39;Morn&#39;, Age=67, Friends=123),
#  Row(Id=130, Name=&#39;Gowron&#39;, Age=67, Friends=350),
#  Row(Id=159, Name=&#39;Kasidy&#39;, Age=67, Friends=438),
#  Row(Id=163, Name=&#39;Nerys&#39;, Age=67, Friends=204),
#  Row(Id=177, Name=&#39;Brunt&#39;, Age=67, Friends=316),
#  Row(Id=233, Name=&#39;Gowron&#39;, Age=67, Friends=70),
#  Row(Id=254, Name=&#39;Ezri&#39;, Age=67, Friends=79),
#  Row(Id=309, Name=&#39;Geordi&#39;, Age=67, Friends=153),
#  Row(Id=329, Name=&#39;Dukat&#39;, Age=67, Friends=35),
#  Row(Id=356, Name=&#39;Weyoun&#39;, Age=67, Friends=149),
#  Row(Id=384, Name=&#39;Martok&#39;, Age=67, Friends=355),
#  Row(Id=396, Name=&#39;Keiko&#39;, Age=67, Friends=38),
#  Row(Id=422, Name=&#39;Ben&#39;, Age=67, Friends=292),
#  Row(Id=85, Name=&#39;Quark&#39;, Age=66, Friends=383),
#  Row(Id=88, Name=&#39;Ben&#39;, Age=66, Friends=188),
#  Row(Id=125, Name=&#39;Rom&#39;, Age=66, Friends=284),
#  Row(Id=218, Name=&#39;Gowron&#39;, Age=66, Friends=350),
#  Row(Id=249, Name=&#39;Nerys&#39;, Age=66, Friends=41),
#  Row(Id=266, Name=&#39;Jean-Luc&#39;, Age=66, Friends=496),
#  Row(Id=339, Name=&#39;Morn&#39;, Age=66, Friends=305),
#  Row(Id=375, Name=&#39;Hugh&#39;, Age=66, Friends=201),
#  Row(Id=382, Name=&#39;Worf&#39;, Age=66, Friends=240),
#  Row(Id=74, Name=&#39;Leeta&#39;, Age=65, Friends=208),
#  Row(Id=131, Name=&#39;Hugh&#39;, Age=65, Friends=309),
#  Row(Id=283, Name=&#39;Dukat&#39;, Age=65, Friends=443),
#  Row(Id=365, Name=&#39;Brunt&#39;, Age=65, Friends=430),
#  Row(Id=490, Name=&#39;Nerys&#39;, Age=65, Friends=101),
#  Row(Id=38, Name=&#39;Deanna&#39;, Age=64, Friends=65),
#  Row(Id=107, Name=&#39;Will&#39;, Age=64, Friends=419),
#  Row(Id=110, Name=&#39;Nog&#39;, Age=64, Friends=137),
#  Row(Id=140, Name=&#39;Elim&#39;, Age=64, Friends=234),
#  Row(Id=204, Name=&#39;Deanna&#39;, Age=64, Friends=164),
#  Row(Id=274, Name=&#39;Julian&#39;, Age=64, Friends=244),
#  Row(Id=287, Name=&#39;Beverly&#39;, Age=64, Friends=396),
#  Row(Id=316, Name=&#39;Hugh&#39;, Age=64, Friends=391),
#  Row(Id=353, Name=&#39;Julian&#39;, Age=64, Friends=499),
#  Row(Id=391, Name=&#39;Ben&#39;, Age=64, Friends=309),
#  Row(Id=392, Name=&#39;Data&#39;, Age=64, Friends=343),
#  Row(Id=443, Name=&#39;Geordi&#39;, Age=64, Friends=175),
#  Row(Id=153, Name=&#39;Morn&#39;, Age=63, Friends=342),
#  Row(Id=202, Name=&#39;Lwaxana&#39;, Age=63, Friends=469),
#  Row(Id=292, Name=&#39;Nog&#39;, Age=63, Friends=380),
#  Row(Id=429, Name=&#39;Jean-Luc&#39;, Age=63, Friends=345),
#  Row(Id=53, Name=&#39;Geordi&#39;, Age=62, Friends=31),
#  Row(Id=61, Name=&#39;Kasidy&#39;, Age=62, Friends=442),
#  Row(Id=76, Name=&#39;Will&#39;, Age=62, Friends=201),
#  Row(Id=94, Name=&#39;Morn&#39;, Age=62, Friends=133),
#  Row(Id=189, Name=&#39;Quark&#39;, Age=62, Friends=23),
#  Row(Id=236, Name=&#39;Brunt&#39;, Age=62, Friends=442),
#  Row(Id=290, Name=&#39;Beverly&#39;, Age=62, Friends=290),
#  Row(Id=320, Name=&#39;Worf&#39;, Age=62, Friends=450),
#  Row(Id=328, Name=&#39;Deanna&#39;, Age=62, Friends=41),
#  Row(Id=372, Name=&#39;Brunt&#39;, Age=62, Friends=273),
#  Row(Id=408, Name=&#39;Dukat&#39;, Age=62, Friends=496),
#  Row(Id=498, Name=&#39;Jadzia&#39;, Age=62, Friends=36),
#  Row(Id=499, Name=&#39;Leeta&#39;, Age=62, Friends=12),
#  Row(Id=78, Name=&#39;Data&#39;, Age=61, Friends=337),
#  Row(Id=100, Name=&#39;Jean-Luc&#39;, Age=61, Friends=460),
#  Row(Id=103, Name=&#39;Ezri&#39;, Age=61, Friends=2),
#  Row(Id=147, Name=&#39;Quark&#39;, Age=61, Friends=373),
#  Row(Id=211, Name=&#39;Ben&#39;, Age=61, Friends=73),
#  Row(Id=237, Name=&#39;Nerys&#39;, Age=61, Friends=469),
#  Row(Id=243, Name=&#39;Martok&#39;, Age=61, Friends=68),
#  Row(Id=312, Name=&#39;Jadzia&#39;, Age=61, Friends=421),
#  Row(Id=488, Name=&#39;Nog&#39;, Age=61, Friends=103),
#  Row(Id=19, Name=&#39;Geordi&#39;, Age=60, Friends=246),
#  Row(Id=143, Name=&#39;Data&#39;, Age=60, Friends=124),
#  Row(Id=190, Name=&#39;Geordi&#39;, Age=60, Friends=294),
#  Row(Id=193, Name=&#39;Nerys&#39;, Age=60, Friends=125),
#  Row(Id=255, Name=&#39;Deanna&#39;, Age=60, Friends=324),
#  Row(Id=379, Name=&#39;Data&#39;, Age=60, Friends=304),
#  Row(Id=491, Name=&#39;Rom&#39;, Age=60, Friends=2),
#  Row(Id=5, Name=&#39;Weyoun&#39;, Age=59, Friends=318),
#  Row(Id=58, Name=&#39;Hugh&#39;, Age=59, Friends=158),
#  Row(Id=59, Name=&#39;Morn&#39;, Age=59, Friends=284),
#  Row(Id=142, Name=&#39;Guinan&#39;, Age=59, Friends=335),
#  Row(Id=162, Name=&#39;Ezri&#39;, Age=59, Friends=14),
#  Row(Id=231, Name=&#39;Ezri&#39;, Age=59, Friends=42),
#  Row(Id=313, Name=&#39;Dukat&#39;, Age=59, Friends=169),
#  Row(Id=317, Name=&#39;Guinan&#39;, Age=59, Friends=439),
#  Row(Id=437, Name=&#39;Morn&#39;, Age=59, Friends=221),
#  Row(Id=37, Name=&#39;Geordi&#39;, Age=58, Friends=21),
#  Row(Id=43, Name=&#39;Guinan&#39;, Age=58, Friends=345),
#  Row(Id=63, Name=&#39;Jean-Luc&#39;, Age=58, Friends=54),
#  Row(Id=79, Name=&#39;Leeta&#39;, Age=58, Friends=348),
#  Row(Id=146, Name=&#39;Nerys&#39;, Age=58, Friends=174),
#  Row(Id=160, Name=&#39;Beverly&#39;, Age=58, Friends=112),
#  Row(Id=322, Name=&#39;Rom&#39;, Age=58, Friends=92),
#  Row(Id=337, Name=&#39;Miles&#39;, Age=58, Friends=10),
#  Row(Id=402, Name=&#39;Hugh&#39;, Age=58, Friends=98),
#  Row(Id=411, Name=&#39;Lwaxana&#39;, Age=58, Friends=22),
#  Row(Id=452, Name=&#39;Ezri&#39;, Age=58, Friends=6),
#  Row(Id=11, Name=&#39;Ben&#39;, Age=57, Friends=372),
#  Row(Id=57, Name=&#39;Odo&#39;, Age=57, Friends=294),
#  Row(Id=82, Name=&#39;Hugh&#39;, Age=57, Friends=465),
#  Row(Id=235, Name=&#39;Elim&#39;, Age=57, Friends=8),
#  Row(Id=298, Name=&#39;Guinan&#39;, Age=57, Friends=207),
#  Row(Id=299, Name=&#39;Rom&#39;, Age=57, Friends=311),
#  Row(Id=340, Name=&#39;Nerys&#39;, Age=57, Friends=275),
#  Row(Id=385, Name=&#39;Beverly&#39;, Age=57, Friends=436),
#  Row(Id=406, Name=&#39;Ben&#39;, Age=57, Friends=121),
#  Row(Id=434, Name=&#39;Deanna&#39;, Age=57, Friends=289),
#  Row(Id=436, Name=&#39;Geordi&#39;, Age=57, Friends=229),
#  Row(Id=483, Name=&#39;Hugh&#39;, Age=57, Friends=99),
#  Row(Id=13, Name=&#39;Jean-Luc&#39;, Age=56, Friends=444),
#  Row(Id=288, Name=&#39;Hugh&#39;, Age=56, Friends=354),
#  Row(Id=324, Name=&#39;Miles&#39;, Age=56, Friends=343),
#  Row(Id=395, Name=&#39;Jean-Luc&#39;, Age=56, Friends=15),
#  Row(Id=405, Name=&#39;Nog&#39;, Age=56, Friends=371),
#  Row(Id=414, Name=&#39;Martok&#39;, Age=56, Friends=313),
#  Row(Id=2, Name=&#39;Hugh&#39;, Age=55, Friends=221),
#  Row(Id=86, Name=&#39;Hugh&#39;, Age=55, Friends=257),
#  Row(Id=150, Name=&#39;Nerys&#39;, Age=55

# %%
df.orderBy(['Age','Friends'], ascending= [0,1] ).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[118]: [Row(Id=62, Name=&#39;Keiko&#39;, Age=69, Friends=9),
#  Row(Id=354, Name=&#39;Kasidy&#39;, Age=69, Friends=15),
#  Row(Id=116, Name=&#39;Ben&#39;, Age=69, Friends=75),
#  Row(Id=253, Name=&#39;Leeta&#39;, Age=69, Friends=116),
#  Row(Id=383, Name=&#39;Data&#39;, Age=69, Friends=148),
#  Row(Id=205, Name=&#39;Morn&#39;, Age=69, Friends=236),
#  Row(Id=97, Name=&#39;Nerys&#39;, Age=69, Friends=361),
#  Row(Id=487, Name=&#39;Brunt&#39;, Age=69, Friends=431),
#  Row(Id=397, Name=&#39;Quark&#39;, Age=69, Friends=470),
#  Row(Id=99, Name=&#39;Keiko&#39;, Age=69, Friends=491),
#  Row(Id=4, Name=&#39;Quark&#39;, Age=68, Friends=21),
#  Row(Id=168, Name=&#39;Martok&#39;, Age=68, Friends=112),
#  Row(Id=310, Name=&#39;Odo&#39;, Age=68, Friends=189),
#  Row(Id=361, Name=&#39;Worf&#39;, Age=68, Friends=206),
#  Row(Id=258, Name=&#39;Worf&#39;, Age=68, Friends=217),
#  Row(Id=120, Name=&#39;Jean-Luc&#39;, Age=68, Friends=264),
#  Row(Id=374, Name=&#39;Nog&#39;, Age=68, Friends=293),
#  Row(Id=428, Name=&#39;Lwaxana&#39;, Age=68, Friends=423),
#  Row(Id=232, Name=&#39;Worf&#39;, Age=68, Friends=481),
#  Row(Id=170, Name=&#39;Jean-Luc&#39;, Age=68, Friends=490),
#  Row(Id=329, Name=&#39;Dukat&#39;, Age=67, Friends=35),
#  Row(Id=396, Name=&#39;Keiko&#39;, Age=67, Friends=38),
#  Row(Id=233, Name=&#39;Gowron&#39;, Age=67, Friends=70),
#  Row(Id=254, Name=&#39;Ezri&#39;, Age=67, Friends=79),
#  Row(Id=101, Name=&#39;Morn&#39;, Age=67, Friends=123),
#  Row(Id=356, Name=&#39;Weyoun&#39;, Age=67, Friends=149),
#  Row(Id=309, Name=&#39;Geordi&#39;, Age=67, Friends=153),
#  Row(Id=41, Name=&#39;Hugh&#39;, Age=67, Friends=167),
#  Row(Id=163, Name=&#39;Nerys&#39;, Age=67, Friends=204),
#  Row(Id=20, Name=&#39;Odo&#39;, Age=67, Friends=220),
#  Row(Id=422, Name=&#39;Ben&#39;, Age=67, Friends=292),
#  Row(Id=177, Name=&#39;Brunt&#39;, Age=67, Friends=316),
#  Row(Id=130, Name=&#39;Gowron&#39;, Age=67, Friends=350),
#  Row(Id=384, Name=&#39;Martok&#39;, Age=67, Friends=355),
#  Row(Id=159, Name=&#39;Kasidy&#39;, Age=67, Friends=438),
#  Row(Id=80, Name=&#39;Dukat&#39;, Age=67, Friends=445),
#  Row(Id=249, Name=&#39;Nerys&#39;, Age=66, Friends=41),
#  Row(Id=88, Name=&#39;Ben&#39;, Age=66, Friends=188),
#  Row(Id=375, Name=&#39;Hugh&#39;, Age=66, Friends=201),
#  Row(Id=382, Name=&#39;Worf&#39;, Age=66, Friends=240),
#  Row(Id=125, Name=&#39;Rom&#39;, Age=66, Friends=284),
#  Row(Id=339, Name=&#39;Morn&#39;, Age=66, Friends=305),
#  Row(Id=218, Name=&#39;Gowron&#39;, Age=66, Friends=350),
#  Row(Id=85, Name=&#39;Quark&#39;, Age=66, Friends=383),
#  Row(Id=266, Name=&#39;Jean-Luc&#39;, Age=66, Friends=496),
#  Row(Id=490, Name=&#39;Nerys&#39;, Age=65, Friends=101),
#  Row(Id=74, Name=&#39;Leeta&#39;, Age=65, Friends=208),
#  Row(Id=131, Name=&#39;Hugh&#39;, Age=65, Friends=309),
#  Row(Id=365, Name=&#39;Brunt&#39;, Age=65, Friends=430),
#  Row(Id=283, Name=&#39;Dukat&#39;, Age=65, Friends=443),
#  Row(Id=38, Name=&#39;Deanna&#39;, Age=64, Friends=65),
#  Row(Id=110, Name=&#39;Nog&#39;, Age=64, Friends=137),
#  Row(Id=204, Name=&#39;Deanna&#39;, Age=64, Friends=164),
#  Row(Id=443, Name=&#39;Geordi&#39;, Age=64, Friends=175),
#  Row(Id=140, Name=&#39;Elim&#39;, Age=64, Friends=234),
#  Row(Id=274, Name=&#39;Julian&#39;, Age=64, Friends=244),
#  Row(Id=391, Name=&#39;Ben&#39;, Age=64, Friends=309),
#  Row(Id=392, Name=&#39;Data&#39;, Age=64, Friends=343),
#  Row(Id=316, Name=&#39;Hugh&#39;, Age=64, Friends=391),
#  Row(Id=287, Name=&#39;Beverly&#39;, Age=64, Friends=396),
#  Row(Id=107, Name=&#39;Will&#39;, Age=64, Friends=419),
#  Row(Id=353, Name=&#39;Julian&#39;, Age=64, Friends=499),
#  Row(Id=153, Name=&#39;Morn&#39;, Age=63, Friends=342),
#  Row(Id=429, Name=&#39;Jean-Luc&#39;, Age=63, Friends=345),
#  Row(Id=292, Name=&#39;Nog&#39;, Age=63, Friends=380),
#  Row(Id=202, Name=&#39;Lwaxana&#39;, Age=63, Friends=469),
#  Row(Id=499, Name=&#39;Leeta&#39;, Age=62, Friends=12),
#  Row(Id=189, Name=&#39;Quark&#39;, Age=62, Friends=23),
#  Row(Id=53, Name=&#39;Geordi&#39;, Age=62, Friends=31),
#  Row(Id=498, Name=&#39;Jadzia&#39;, Age=62, Friends=36),
#  Row(Id=328, Name=&#39;Deanna&#39;, Age=62, Friends=41),
#  Row(Id=94, Name=&#39;Morn&#39;, Age=62, Friends=133),
#  Row(Id=76, Name=&#39;Will&#39;, Age=62, Friends=201),
#  Row(Id=372, Name=&#39;Brunt&#39;, Age=62, Friends=273),
#  Row(Id=290, Name=&#39;Beverly&#39;, Age=62, Friends=290),
#  Row(Id=61, Name=&#39;Kasidy&#39;, Age=62, Friends=442),
#  Row(Id=236, Name=&#39;Brunt&#39;, Age=62, Friends=442),
#  Row(Id=320, Name=&#39;Worf&#39;, Age=62, Friends=450),
#  Row(Id=408, Name=&#39;Dukat&#39;, Age=62, Friends=496),
#  Row(Id=103, Name=&#39;Ezri&#39;, Age=61, Friends=2),
#  Row(Id=243, Name=&#39;Martok&#39;, Age=61, Friends=68),
#  Row(Id=211, Name=&#39;Ben&#39;, Age=61, Friends=73),
#  Row(Id=488, Name=&#39;Nog&#39;, Age=61, Friends=103),
#  Row(Id=78, Name=&#39;Data&#39;, Age=61, Friends=337),
#  Row(Id=147, Name=&#39;Quark&#39;, Age=61, Friends=373),
#  Row(Id=312, Name=&#39;Jadzia&#39;, Age=61, Friends=421),
#  Row(Id=100, Name=&#39;Jean-Luc&#39;, Age=61, Friends=460),
#  Row(Id=237, Name=&#39;Nerys&#39;, Age=61, Friends=469),
#  Row(Id=491, Name=&#39;Rom&#39;, Age=60, Friends=2),
#  Row(Id=143, Name=&#39;Data&#39;, Age=60, Friends=124),
#  Row(Id=193, Name=&#39;Nerys&#39;, Age=60, Friends=125),
#  Row(Id=19, Name=&#39;Geordi&#39;, Age=60, Friends=246),
#  Row(Id=190, Name=&#39;Geordi&#39;, Age=60, Friends=294),
#  Row(Id=379, Name=&#39;Data&#39;, Age=60, Friends=304),
#  Row(Id=255, Name=&#39;Deanna&#39;, Age=60, Friends=324),
#  Row(Id=162, Name=&#39;Ezri&#39;, Age=59, Friends=14),
#  Row(Id=231, Name=&#39;Ezri&#39;, Age=59, Friends=42),
#  Row(Id=58, Name=&#39;Hugh&#39;, Age=59, Friends=158),
#  Row(Id=313, Name=&#39;Dukat&#39;, Age=59, Friends=169),
#  Row(Id=437, Name=&#39;Morn&#39;, Age=59, Friends=221),
#  Row(Id=59, Name=&#39;Morn&#39;, Age=59, Friends=284),
#  Row(Id=5, Name=&#39;Weyoun&#39;, Age=59, Friends=318),
#  Row(Id=142, Name=&#39;Guinan&#39;, Age=59, Friends=335),
#  Row(Id=317, Name=&#39;Guinan&#39;, Age=59, Friends=439),
#  Row(Id=452, Name=&#39;Ezri&#39;, Age=58, Friends=6),
#  Row(Id=337, Name=&#39;Miles&#39;, Age=58, Friends=10),
#  Row(Id=37, Name=&#39;Geordi&#39;, Age=58, Friends=21),
#  Row(Id=411, Name=&#39;Lwaxana&#39;, Age=58, Friends=22),
#  Row(Id=63, Name=&#39;Jean-Luc&#39;, Age=58, Friends=54),
#  Row(Id=322, Name=&#39;Rom&#39;, Age=58, Friends=92),
#  Row(Id=402, Name=&#39;Hugh&#39;, Age=58, Friends=98),
#  Row(Id=160, Name=&#39;Beverly&#39;, Age=58, Friends=112),
#  Row(Id=146, Name=&#39;Nerys&#39;, Age=58, Friends=174),
#  Row(Id=43, Name=&#39;Guinan&#39;, Age=58, Friends=345),
#  Row(Id=79, Name=&#39;Leeta&#39;, Age=58, Friends=348),
#  Row(Id=235, Name=&#39;Elim&#39;, Age=57, Friends=8),
#  Row(Id=483, Name=&#39;Hugh&#39;, Age=57, Friends=99),
#  Row(Id=406, Name=&#39;Ben&#39;, Age=57, Friends=121),
#  Row(Id=298, Name=&#39;Guinan&#39;, Age=57, Friends=207),
#  Row(Id=436, Name=&#39;Geordi&#39;, Age=57, Friends=229),
#  Row(Id=340, Name=&#39;Nerys&#39;, Age=57, Friends=275),
#  Row(Id=434, Name=&#39;Deanna&#39;, Age=57, Friends=289),
#  Row(Id=57, Name=&#39;Odo&#39;, Age=57, Friends=294),
#  Row(Id=299, Name=&#39;Rom&#39;, Age=57, Friends=311),
#  Row(Id=11, Name=&#39;Ben&#39;, Age=57, Friends=372),
#  Row(Id=385, Name=&#39;Beverly&#39;, Age=57, Friends=436),
#  Row(Id=82, Name=&#39;Hugh&#39;, Age=57, Friends=465),
#  Row(Id=395, Name=&#39;Jean-Luc&#39;, Age=56, Friends=15),
#  Row(Id=414, Name=&#39;Martok&#39;, Age=56, Friends=313),
#  Row(Id=324, Name=&#39;Miles&#39;, Age=56, Friends=343),
#  Row(Id=288, Name=&#39;Hugh&#39;, Age=56, Friends=354),
#  Row(Id=405, Name=&#39;Nog&#39;, Age=56, Friends=371),
#  Row(Id=13, Name=&#39;Jean-Luc&#39;, Age=56, Friends=444),
#  Row(Id=251, Name=&#39;Rom&#39;, Age=55, Friends=57),
#  Row(Id=419, Name=&#39;Kasidy&#39;, Age=55, Friends=176),
#  Row(Id=172, Name=&#39;Kasidy&#39;, Ag

# %%
from pyspark.sql.functions import *

df.sort(asc("Age")).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[122]: [Row(Id=106, Name=&#39;Beverly&#39;, Age=18, Friends=499),
#  Row(Id=115, Name=&#39;Dukat&#39;, Age=18, Friends=397),
#  Row(Id=341, Name=&#39;Data&#39;, Age=18, Friends=326),
#  Row(Id=377, Name=&#39;Beverly&#39;, Age=18, Friends=418),
#  Row(Id=404, Name=&#39;Kasidy&#39;, Age=18, Friends=24),
#  Row(Id=439, Name=&#39;Data&#39;, Age=18, Friends=417),
#  Row(Id=444, Name=&#39;Keiko&#39;, Age=18, Friends=472),
#  Row(Id=494, Name=&#39;Kasidy&#39;, Age=18, Friends=194),
#  Row(Id=21, Name=&#39;Miles&#39;, Age=19, Friends=268),
#  Row(Id=52, Name=&#39;Beverly&#39;, Age=19, Friends=269),
#  Row(Id=54, Name=&#39;Brunt&#39;, Age=19, Friends=5),
#  Row(Id=133, Name=&#39;Quark&#39;, Age=19, Friends=265),
#  Row(Id=136, Name=&#39;Will&#39;, Age=19, Friends=335),
#  Row(Id=225, Name=&#39;Elim&#39;, Age=19, Friends=106),
#  Row(Id=304, Name=&#39;Will&#39;, Age=19, Friends=404),
#  Row(Id=366, Name=&#39;Keiko&#39;, Age=19, Friends=119),
#  Row(Id=373, Name=&#39;Quark&#39;, Age=19, Friends=272),
#  Row(Id=409, Name=&#39;Nog&#39;, Age=19, Friends=267),
#  Row(Id=492, Name=&#39;Dukat&#39;, Age=19, Friends=36),
#  Row(Id=48, Name=&#39;Nog&#39;, Age=20, Friends=1),
#  Row(Id=60, Name=&#39;Geordi&#39;, Age=20, Friends=100),
#  Row(Id=73, Name=&#39;Brunt&#39;, Age=20, Friends=384),
#  Row(Id=327, Name=&#39;Julian&#39;, Age=20, Friends=63),
#  Row(Id=349, Name=&#39;Kasidy&#39;, Age=20, Friends=277),
#  Row(Id=25, Name=&#39;Ben&#39;, Age=21, Friends=445),
#  Row(Id=66, Name=&#39;Geordi&#39;, Age=21, Friends=477),
#  Row(Id=200, Name=&#39;Kasidy&#39;, Age=21, Friends=472),
#  Row(Id=206, Name=&#39;Will&#39;, Age=21, Friends=491),
#  Row(Id=244, Name=&#39;Dukat&#39;, Age=21, Friends=471),
#  Row(Id=248, Name=&#39;Dukat&#39;, Age=21, Friends=138),
#  Row(Id=281, Name=&#39;Worf&#39;, Age=21, Friends=89),
#  Row(Id=403, Name=&#39;Weyoun&#39;, Age=21, Friends=224),
#  Row(Id=16, Name=&#39;Weyoun&#39;, Age=22, Friends=323),
#  Row(Id=26, Name=&#39;Julian&#39;, Age=22, Friends=100),
#  Row(Id=72, Name=&#39;Kasidy&#39;, Age=22, Friends=179),
#  Row(Id=144, Name=&#39;Miles&#39;, Age=22, Friends=93),
#  Row(Id=215, Name=&#39;Will&#39;, Age=22, Friends=6),
#  Row(Id=390, Name=&#39;Martok&#39;, Age=22, Friends=266),
#  Row(Id=484, Name=&#39;Leeta&#39;, Age=22, Friends=478),
#  Row(Id=173, Name=&#39;Leeta&#39;, Age=23, Friends=129),
#  Row(Id=201, Name=&#39;Ezri&#39;, Age=23, Friends=174),
#  Row(Id=279, Name=&#39;Beverly&#39;, Age=23, Friends=133),
#  Row(Id=291, Name=&#39;Dukat&#39;, Age=23, Friends=373),
#  Row(Id=293, Name=&#39;Deanna&#39;, Age=23, Friends=65),
#  Row(Id=306, Name=&#39;Beverly&#39;, Age=23, Friends=323),
#  Row(Id=376, Name=&#39;Gowron&#39;, Age=23, Friends=392),
#  Row(Id=394, Name=&#39;Keiko&#39;, Age=23, Friends=230),
#  Row(Id=462, Name=&#39;Nerys&#39;, Age=23, Friends=287),
#  Row(Id=493, Name=&#39;Hugh&#39;, Age=23, Friends=357),
#  Row(Id=47, Name=&#39;Brunt&#39;, Age=24, Friends=49),
#  Row(Id=89, Name=&#39;Worf&#39;, Age=24, Friends=492),
#  Row(Id=229, Name=&#39;Gowron&#39;, Age=24, Friends=150),
#  Row(Id=399, Name=&#39;Beverly&#39;, Age=24, Friends=401),
#  Row(Id=426, Name=&#39;Worf&#39;, Age=24, Friends=77),
#  Row(Id=24, Name=&#39;Julian&#39;, Age=25, Friends=1),
#  Row(Id=46, Name=&#39;Morn&#39;, Age=25, Friends=96),
#  Row(Id=96, Name=&#39;Ezri&#39;, Age=25, Friends=233),
#  Row(Id=108, Name=&#39;Leeta&#39;, Age=25, Friends=274),
#  Row(Id=112, Name=&#39;Morn&#39;, Age=25, Friends=13),
#  Row(Id=166, Name=&#39;Lwaxana&#39;, Age=25, Friends=10),
#  Row(Id=238, Name=&#39;Deanna&#39;, Age=25, Friends=305),
#  Row(Id=242, Name=&#39;Data&#39;, Age=25, Friends=101),
#  Row(Id=271, Name=&#39;Morn&#39;, Age=25, Friends=446),
#  Row(Id=315, Name=&#39;Weyoun&#39;, Age=25, Friends=208),
#  Row(Id=464, Name=&#39;Beverly&#39;, Age=25, Friends=485),
#  Row(Id=1, Name=&#39;Jean-Luc&#39;, Age=26, Friends=2),
#  Row(Id=32, Name=&#39;Nog&#39;, Age=26, Friends=281),
#  Row(Id=126, Name=&#39;Brunt&#39;, Age=26, Friends=84),
#  Row(Id=165, Name=&#39;Leeta&#39;, Age=26, Friends=282),
#  Row(Id=178, Name=&#39;Kasidy&#39;, Age=26, Friends=381),
#  Row(Id=182, Name=&#39;Weyoun&#39;, Age=26, Friends=145),
#  Row(Id=219, Name=&#39;Lwaxana&#39;, Age=26, Friends=345),
#  Row(Id=228, Name=&#39;Martok&#39;, Age=26, Friends=293),
#  Row(Id=268, Name=&#39;Ezri&#39;, Age=26, Friends=298),
#  Row(Id=280, Name=&#39;Nerys&#39;, Age=26, Friends=492),
#  Row(Id=284, Name=&#39;Nog&#39;, Age=26, Friends=269),
#  Row(Id=343, Name=&#39;Odo&#39;, Age=26, Friends=254),
#  Row(Id=357, Name=&#39;Brunt&#39;, Age=26, Friends=7),
#  Row(Id=368, Name=&#39;Elim&#39;, Age=26, Friends=383),
#  Row(Id=398, Name=&#39;Lwaxana&#39;, Age=26, Friends=124),
#  Row(Id=420, Name=&#39;Jadzia&#39;, Age=26, Friends=391),
#  Row(Id=459, Name=&#39;Geordi&#39;, Age=26, Friends=84),
#  Row(Id=9, Name=&#39;Hugh&#39;, Age=27, Friends=181),
#  Row(Id=35, Name=&#39;Beverly&#39;, Age=27, Friends=305),
#  Row(Id=209, Name=&#39;Brunt&#39;, Age=27, Friends=174),
#  Row(Id=221, Name=&#39;Dukat&#39;, Age=27, Friends=150),
#  Row(Id=265, Name=&#39;Gowron&#39;, Age=27, Friends=471),
#  Row(Id=335, Name=&#39;Odo&#39;, Age=27, Friends=337),
#  Row(Id=352, Name=&#39;Deanna&#39;, Age=27, Friends=53),
#  Row(Id=472, Name=&#39;Nog&#39;, Age=27, Friends=154),
#  Row(Id=84, Name=&#39;Ben&#39;, Age=28, Friends=311),
#  Row(Id=118, Name=&#39;Ben&#39;, Age=28, Friends=304),
#  Row(Id=137, Name=&#39;Martok&#39;, Age=28, Friends=32),
#  Row(Id=213, Name=&#39;Worf&#39;, Age=28, Friends=312),
#  Row(Id=245, Name=&#39;Jean-Luc&#39;, Age=28, Friends=174),
#  Row(Id=301, Name=&#39;Weyoun&#39;, Age=28, Friends=108),
#  Row(Id=338, Name=&#39;Will&#39;, Age=28, Friends=180),
#  Row(Id=427, Name=&#39;Brunt&#39;, Age=28, Friends=258),
#  Row(Id=451, Name=&#39;Martok&#39;, Age=28, Friends=34),
#  Row(Id=476, Name=&#39;Jean-Luc&#39;, Age=28, Friends=378),
#  Row(Id=95, Name=&#39;Odo&#39;, Age=29, Friends=173),
#  Row(Id=119, Name=&#39;Worf&#39;, Age=29, Friends=344),
#  Row(Id=171, Name=&#39;Weyoun&#39;, Age=29, Friends=126),
#  Row(Id=217, Name=&#39;Keiko&#39;, Age=29, Friends=260),
#  Row(Id=259, Name=&#39;Kasidy&#39;, Age=29, Friends=11),
#  Row(Id=264, Name=&#39;Julian&#39;, Age=29, Friends=228),
#  Row(Id=272, Name=&#39;Quark&#39;, Age=29, Friends=367),
#  Row(Id=305, Name=&#39;Quark&#39;, Age=29, Friends=182),
#  Row(Id=323, Name=&#39;Nog&#39;, Age=29, Friends=236),
#  Row(Id=333, Name=&#39;Ben&#39;, Age=29, Friends=207),
#  Row(Id=346, Name=&#39;Hugh&#39;, Age=29, Friends=329),
#  Row(Id=400, Name=&#39;Data&#39;, Age=29, Friends=128),
#  Row(Id=22, Name=&#39;Quark&#39;, Age=30, Friends=72),
#  Row(Id=69, Name=&#39;Jean-Luc&#39;, Age=30, Friends=204),
#  Row(Id=180, Name=&#39;Kasidy&#39;, Age=30, Friends=108),
#  Row(Id=195, Name=&#39;Ben&#39;, Age=30, Friends=376),
#  Row(Id=286, Name=&#39;Lwaxana&#39;, Age=30, Friends=384),
#  Row(Id=289, Name=&#39;Ezri&#39;, Age=30, Friends=221),
#  Row(Id=319, Name=&#39;Leeta&#39;, Age=30, Friends=476),
#  Row(Id=331, Name=&#39;Martok&#39;, Age=30, Friends=17),
#  Row(Id=344, Name=&#39;Data&#39;, Age=30, Friends=487),
#  Row(Id=388, Name=&#39;Nog&#39;, Age=30, Friends=184),
#  Row(Id=415, Name=&#39;Quark&#39;, Age=30, Friends=65),
#  Row(Id=39, Name=&#39;Morn&#39;, Age=31, Friends=192),
#  Row(Id=64, Name=&#39;Elim&#39;, Age=31, Friends=15),
#  Row(Id=87, Name=&#39;Ezri&#39;, Age=31, Friends=481),
#  Row(Id=158, Name=&#39;Odo&#39;, Age=31, Friends=340),
#  Row(Id=164, Name=&#39;Will&#39;, Age=31, Friends=172),
#  Row(Id=186, Name=&#39;Miles&#39;, Age=31, Friends=109),
#  Row(Id=345, Name=&#39;Ezri&#39;, Age=31, Friends=394),
#  Row(Id=371, Name=&#39;Guinan&#39;, Age=31, Friends=435),
#  Row(Id=36, Name=&#39;Kasidy&#39;, Age=32, Friends=81),
#  Row(Id=83, Name=&#39;Geordi&#39;, Age=32, Friends=308),
#  Row(Id=104, Name=&#39;Dukat&#39;, Age=32, Friends=142),
#  Row(Id=138, Name=&#39;Dukat&#39;, Age=32, Friends=384),
#  Row(Id=214, Name=&#39;M

# %%
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- Id: integer (nullable = true)
# -- Name: string (nullable = true)
# -- Age: integer (nullable = true)
# -- Friends: integer (nullable = true)
#
# </div>

# %%
df.rdd.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[125]: [Row(Id=0, Name=&#39;Will&#39;, Age=33, Friends=385),
#  Row(Id=1, Name=&#39;Jean-Luc&#39;, Age=26, Friends=2),
#  Row(Id=2, Name=&#39;Hugh&#39;, Age=55, Friends=221),
#  Row(Id=3, Name=&#39;Deanna&#39;, Age=40, Friends=465),
#  Row(Id=4, Name=&#39;Quark&#39;, Age=68, Friends=21),
#  Row(Id=5, Name=&#39;Weyoun&#39;, Age=59, Friends=318),
#  Row(Id=6, Name=&#39;Gowron&#39;, Age=37, Friends=220),
#  Row(Id=7, Name=&#39;Will&#39;, Age=54, Friends=307),
#  Row(Id=8, Name=&#39;Jadzia&#39;, Age=38, Friends=380),
#  Row(Id=9, Name=&#39;Hugh&#39;, Age=27, Friends=181),
#  Row(Id=10, Name=&#39;Odo&#39;, Age=53, Friends=191),
#  Row(Id=11, Name=&#39;Ben&#39;, Age=57, Friends=372),
#  Row(Id=12, Name=&#39;Keiko&#39;, Age=54, Friends=253),
#  Row(Id=13, Name=&#39;Jean-Luc&#39;, Age=56, Friends=444),
#  Row(Id=14, Name=&#39;Hugh&#39;, Age=43, Friends=49),
#  Row(Id=15, Name=&#39;Rom&#39;, Age=36, Friends=49),
#  Row(Id=16, Name=&#39;Weyoun&#39;, Age=22, Friends=323),
#  Row(Id=17, Name=&#39;Odo&#39;, Age=35, Friends=13),
#  Row(Id=18, Name=&#39;Jean-Luc&#39;, Age=45, Friends=455),
#  Row(Id=19, Name=&#39;Geordi&#39;, Age=60, Friends=246),
#  Row(Id=20, Name=&#39;Odo&#39;, Age=67, Friends=220),
#  Row(Id=21, Name=&#39;Miles&#39;, Age=19, Friends=268),
#  Row(Id=22, Name=&#39;Quark&#39;, Age=30, Friends=72),
#  Row(Id=23, Name=&#39;Keiko&#39;, Age=51, Friends=271),
#  Row(Id=24, Name=&#39;Julian&#39;, Age=25, Friends=1),
#  Row(Id=25, Name=&#39;Ben&#39;, Age=21, Friends=445),
#  Row(Id=26, Name=&#39;Julian&#39;, Age=22, Friends=100),
#  Row(Id=27, Name=&#39;Leeta&#39;, Age=42, Friends=363),
#  Row(Id=28, Name=&#39;Martok&#39;, Age=49, Friends=476),
#  Row(Id=29, Name=&#39;Nog&#39;, Age=48, Friends=364),
#  Row(Id=30, Name=&#39;Keiko&#39;, Age=50, Friends=175),
#  Row(Id=31, Name=&#39;Miles&#39;, Age=39, Friends=161),
#  Row(Id=32, Name=&#39;Nog&#39;, Age=26, Friends=281),
#  Row(Id=33, Name=&#39;Dukat&#39;, Age=53, Friends=197),
#  Row(Id=34, Name=&#39;Jean-Luc&#39;, Age=43, Friends=249),
#  Row(Id=35, Name=&#39;Beverly&#39;, Age=27, Friends=305),
#  Row(Id=36, Name=&#39;Kasidy&#39;, Age=32, Friends=81),
#  Row(Id=37, Name=&#39;Geordi&#39;, Age=58, Friends=21),
#  Row(Id=38, Name=&#39;Deanna&#39;, Age=64, Friends=65),
#  Row(Id=39, Name=&#39;Morn&#39;, Age=31, Friends=192),
#  Row(Id=40, Name=&#39;Odo&#39;, Age=52, Friends=413),
#  Row(Id=41, Name=&#39;Hugh&#39;, Age=67, Friends=167),
#  Row(Id=42, Name=&#39;Brunt&#39;, Age=54, Friends=75),
#  Row(Id=43, Name=&#39;Guinan&#39;, Age=58, Friends=345),
#  Row(Id=44, Name=&#39;Nerys&#39;, Age=35, Friends=244),
#  Row(Id=45, Name=&#39;Dukat&#39;, Age=52, Friends=77),
#  Row(Id=46, Name=&#39;Morn&#39;, Age=25, Friends=96),
#  Row(Id=47, Name=&#39;Brunt&#39;, Age=24, Friends=49),
#  Row(Id=48, Name=&#39;Nog&#39;, Age=20, Friends=1),
#  Row(Id=49, Name=&#39;Ezri&#39;, Age=40, Friends=254),
#  Row(Id=50, Name=&#39;Quark&#39;, Age=51, Friends=283),
#  Row(Id=51, Name=&#39;Lwaxana&#39;, Age=36, Friends=212),
#  Row(Id=52, Name=&#39;Beverly&#39;, Age=19, Friends=269),
#  Row(Id=53, Name=&#39;Geordi&#39;, Age=62, Friends=31),
#  Row(Id=54, Name=&#39;Brunt&#39;, Age=19, Friends=5),
#  Row(Id=55, Name=&#39;Keiko&#39;, Age=41, Friends=278),
#  Row(Id=56, Name=&#39;Gowron&#39;, Age=44, Friends=194),
#  Row(Id=57, Name=&#39;Odo&#39;, Age=57, Friends=294),
#  Row(Id=58, Name=&#39;Hugh&#39;, Age=59, Friends=158),
#  Row(Id=59, Name=&#39;Morn&#39;, Age=59, Friends=284),
#  Row(Id=60, Name=&#39;Geordi&#39;, Age=20, Friends=100),
#  Row(Id=61, Name=&#39;Kasidy&#39;, Age=62, Friends=442),
#  Row(Id=62, Name=&#39;Keiko&#39;, Age=69, Friends=9),
#  Row(Id=63, Name=&#39;Jean-Luc&#39;, Age=58, Friends=54),
#  Row(Id=64, Name=&#39;Elim&#39;, Age=31, Friends=15),
#  Row(Id=65, Name=&#39;Guinan&#39;, Age=52, Friends=169),
#  Row(Id=66, Name=&#39;Geordi&#39;, Age=21, Friends=477),
#  Row(Id=67, Name=&#39;Jadzia&#39;, Age=48, Friends=135),
#  Row(Id=68, Name=&#39;Guinan&#39;, Age=33, Friends=74),
#  Row(Id=69, Name=&#39;Jean-Luc&#39;, Age=30, Friends=204),
#  Row(Id=70, Name=&#39;Brunt&#39;, Age=52, Friends=393),
#  Row(Id=71, Name=&#39;Geordi&#39;, Age=45, Friends=184),
#  Row(Id=72, Name=&#39;Kasidy&#39;, Age=22, Friends=179),
#  Row(Id=73, Name=&#39;Brunt&#39;, Age=20, Friends=384),
#  Row(Id=74, Name=&#39;Leeta&#39;, Age=65, Friends=208),
#  Row(Id=75, Name=&#39;Morn&#39;, Age=40, Friends=459),
#  Row(Id=76, Name=&#39;Will&#39;, Age=62, Friends=201),
#  Row(Id=77, Name=&#39;Weyoun&#39;, Age=40, Friends=407),
#  Row(Id=78, Name=&#39;Data&#39;, Age=61, Friends=337),
#  Row(Id=79, Name=&#39;Leeta&#39;, Age=58, Friends=348),
#  Row(Id=80, Name=&#39;Dukat&#39;, Age=67, Friends=445),
#  Row(Id=81, Name=&#39;Jadzia&#39;, Age=54, Friends=440),
#  Row(Id=82, Name=&#39;Hugh&#39;, Age=57, Friends=465),
#  Row(Id=83, Name=&#39;Geordi&#39;, Age=32, Friends=308),
#  Row(Id=84, Name=&#39;Ben&#39;, Age=28, Friends=311),
#  Row(Id=85, Name=&#39;Quark&#39;, Age=66, Friends=383),
#  Row(Id=86, Name=&#39;Hugh&#39;, Age=55, Friends=257),
#  Row(Id=87, Name=&#39;Ezri&#39;, Age=31, Friends=481),
#  Row(Id=88, Name=&#39;Ben&#39;, Age=66, Friends=188),
#  Row(Id=89, Name=&#39;Worf&#39;, Age=24, Friends=492),
#  Row(Id=90, Name=&#39;Kasidy&#39;, Age=33, Friends=471),
#  Row(Id=91, Name=&#39;Rom&#39;, Age=46, Friends=88),
#  Row(Id=92, Name=&#39;Gowron&#39;, Age=54, Friends=7),
#  Row(Id=93, Name=&#39;Elim&#39;, Age=46, Friends=63),
#  Row(Id=94, Name=&#39;Morn&#39;, Age=62, Friends=133),
#  Row(Id=95, Name=&#39;Odo&#39;, Age=29, Friends=173),
#  Row(Id=96, Name=&#39;Ezri&#39;, Age=25, Friends=233),
#  Row(Id=97, Name=&#39;Nerys&#39;, Age=69, Friends=361),
#  Row(Id=98, Name=&#39;Will&#39;, Age=44, Friends=178),
#  Row(Id=99, Name=&#39;Keiko&#39;, Age=69, Friends=491),
#  Row(Id=100, Name=&#39;Jean-Luc&#39;, Age=61, Friends=460),
#  Row(Id=101, Name=&#39;Morn&#39;, Age=67, Friends=123),
#  Row(Id=102, Name=&#39;Dukat&#39;, Age=40, Friends=18),
#  Row(Id=103, Name=&#39;Ezri&#39;, Age=61, Friends=2),
#  Row(Id=104, Name=&#39;Dukat&#39;, Age=32, Friends=142),
#  Row(Id=105, Name=&#39;Morn&#39;, Age=50, Friends=417),
#  Row(Id=106, Name=&#39;Beverly&#39;, Age=18, Friends=499),
#  Row(Id=107, Name=&#39;Will&#39;, Age=64, Friends=419),
#  Row(Id=108, Name=&#39;Leeta&#39;, Age=25, Friends=274),
#  Row(Id=109, Name=&#39;Quark&#39;, Age=53, Friends=417),
#  Row(Id=110, Name=&#39;Nog&#39;, Age=64, Friends=137),
#  Row(Id=111, Name=&#39;Nerys&#39;, Age=37, Friends=46),
#  Row(Id=112, Name=&#39;Morn&#39;, Age=25, Friends=13),
#  Row(Id=113, Name=&#39;Quark&#39;, Age=41, Friends=244),
#  Row(Id=114, Name=&#39;Worf&#39;, Age=33, Friends=275),
#  Row(Id=115, Name=&#39;Dukat&#39;, Age=18, Friends=397),
#  Row(Id=116, Name=&#39;Ben&#39;, Age=69, Friends=75),
#  Row(Id=117, Name=&#39;Rom&#39;, Age=52, Friends=487),
#  Row(Id=118, Name=&#39;Ben&#39;, Age=28, Friends=304),
#  Row(Id=119, Name=&#39;Worf&#39;, Age=29, Friends=344),
#  Row(Id=120, Name=&#39;Jean-Luc&#39;, Age=68, Friends=264),
#  Row(Id=121, Name=&#39;Deanna&#39;, Age=35, Friends=355),
#  Row(Id=122, Name=&#39;Data&#39;, Age=45, Friends=400),
#  Row(Id=123, Name=&#39;Jadzia&#39;, Age=45, Friends=439),
#  Row(Id=124, Name=&#39;Data&#39;, Age=47, Friends=429),
#  Row(Id=125, Name=&#39;Rom&#39;, Age=66, Friends=284),
#  Row(Id=126, Name=&#39;Brunt&#39;, Age=26, Friends=84),
#  Row(Id=127, Name=&#39;Miles&#39;, Age=40, Friends=284),
#  Row(Id=128, Name=&#39;Julian&#39;, Age=34, Friends=221),
#  Row(Id=129, Name=&#39;Kasidy&#39;, Age=45, Friends=252),
#  Row(Id=130, Name=&#39;Gowron&#39;, Age=67, Friends=350),
#  Row(Id=131, Name=&#39;Hugh&#39;, Age=65, Friends=309),
#  Row(Id=132, Name=&#39;Odo&#39;, Age=46, Friends=462),
#  Row(Id=133, Name=&#39;Quark&#39;, Age=19, Friends=265),
#  Row(Id=134, Name=&#39;Ben&#39;, Age=45, Friends=340),
#  Row(Id=135, Name=&#39;Rom&#39;, Age=42, Friends=427),
#  Row(Id=136, Name=&#39;Will&#39;, Age=19, Friends=335),
#  Row(Id=137, Na

# %%
df.rdd.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[127]: 1</div>

# %%
df.repartition(2).rdd.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[129]: 2</div>

# %%
df.rollup('Name',df.Age).count().orderBy('Name','Age').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+----+-----+
#    Name| Age|count|
# +-------+----+-----+
#    null|null|  500|
#     Ben|null|   17|
#     Ben|  21|    1|
#     Ben|  28|    2|
#     Ben|  29|    1|
#     Ben|  30|    1|
#     Ben|  45|    2|
#     Ben|  47|    1|
#     Ben|  48|    1|
#     Ben|  52|    1|
#     Ben|  57|    2|
#     Ben|  61|    1|
#     Ben|  64|    1|
#     Ben|  66|    1|
#     Ben|  67|    1|
#     Ben|  69|    1|
# Beverly|null|   20|
# Beverly|  18|    2|
# Beverly|  19|    1|
# Beverly|  23|    2|
# +-------+----+-----+
# only showing top 20 rows
#
# </div>

# %%
f = spark.range(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.sample(fraction = 0.5,seed=3).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[135]: 246</div>

# %%
df.schema
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[136]: StructType(List(StructField(Id,IntegerType,true),StructField(Name,StringType,true),StructField(Age,IntegerType,true),StructField(Friends,IntegerType,true)))</div>

# %%
df.select(df.Name,(df.Age+10).alias('age')).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[137]: [Row(Name=&#39;Will&#39;, age=43),
#  Row(Name=&#39;Jean-Luc&#39;, age=36),
#  Row(Name=&#39;Hugh&#39;, age=65),
#  Row(Name=&#39;Deanna&#39;, age=50),
#  Row(Name=&#39;Quark&#39;, age=78),
#  Row(Name=&#39;Weyoun&#39;, age=69),
#  Row(Name=&#39;Gowron&#39;, age=47),
#  Row(Name=&#39;Will&#39;, age=64),
#  Row(Name=&#39;Jadzia&#39;, age=48),
#  Row(Name=&#39;Hugh&#39;, age=37),
#  Row(Name=&#39;Odo&#39;, age=63),
#  Row(Name=&#39;Ben&#39;, age=67),
#  Row(Name=&#39;Keiko&#39;, age=64),
#  Row(Name=&#39;Jean-Luc&#39;, age=66),
#  Row(Name=&#39;Hugh&#39;, age=53),
#  Row(Name=&#39;Rom&#39;, age=46),
#  Row(Name=&#39;Weyoun&#39;, age=32),
#  Row(Name=&#39;Odo&#39;, age=45),
#  Row(Name=&#39;Jean-Luc&#39;, age=55),
#  Row(Name=&#39;Geordi&#39;, age=70),
#  Row(Name=&#39;Odo&#39;, age=77),
#  Row(Name=&#39;Miles&#39;, age=29),
#  Row(Name=&#39;Quark&#39;, age=40),
#  Row(Name=&#39;Keiko&#39;, age=61),
#  Row(Name=&#39;Julian&#39;, age=35),
#  Row(Name=&#39;Ben&#39;, age=31),
#  Row(Name=&#39;Julian&#39;, age=32),
#  Row(Name=&#39;Leeta&#39;, age=52),
#  Row(Name=&#39;Martok&#39;, age=59),
#  Row(Name=&#39;Nog&#39;, age=58),
#  Row(Name=&#39;Keiko&#39;, age=60),
#  Row(Name=&#39;Miles&#39;, age=49),
#  Row(Name=&#39;Nog&#39;, age=36),
#  Row(Name=&#39;Dukat&#39;, age=63),
#  Row(Name=&#39;Jean-Luc&#39;, age=53),
#  Row(Name=&#39;Beverly&#39;, age=37),
#  Row(Name=&#39;Kasidy&#39;, age=42),
#  Row(Name=&#39;Geordi&#39;, age=68),
#  Row(Name=&#39;Deanna&#39;, age=74),
#  Row(Name=&#39;Morn&#39;, age=41),
#  Row(Name=&#39;Odo&#39;, age=62),
#  Row(Name=&#39;Hugh&#39;, age=77),
#  Row(Name=&#39;Brunt&#39;, age=64),
#  Row(Name=&#39;Guinan&#39;, age=68),
#  Row(Name=&#39;Nerys&#39;, age=45),
#  Row(Name=&#39;Dukat&#39;, age=62),
#  Row(Name=&#39;Morn&#39;, age=35),
#  Row(Name=&#39;Brunt&#39;, age=34),
#  Row(Name=&#39;Nog&#39;, age=30),
#  Row(Name=&#39;Ezri&#39;, age=50),
#  Row(Name=&#39;Quark&#39;, age=61),
#  Row(Name=&#39;Lwaxana&#39;, age=46),
#  Row(Name=&#39;Beverly&#39;, age=29),
#  Row(Name=&#39;Geordi&#39;, age=72),
#  Row(Name=&#39;Brunt&#39;, age=29),
#  Row(Name=&#39;Keiko&#39;, age=51),
#  Row(Name=&#39;Gowron&#39;, age=54),
#  Row(Name=&#39;Odo&#39;, age=67),
#  Row(Name=&#39;Hugh&#39;, age=69),
#  Row(Name=&#39;Morn&#39;, age=69),
#  Row(Name=&#39;Geordi&#39;, age=30),
#  Row(Name=&#39;Kasidy&#39;, age=72),
#  Row(Name=&#39;Keiko&#39;, age=79),
#  Row(Name=&#39;Jean-Luc&#39;, age=68),
#  Row(Name=&#39;Elim&#39;, age=41),
#  Row(Name=&#39;Guinan&#39;, age=62),
#  Row(Name=&#39;Geordi&#39;, age=31),
#  Row(Name=&#39;Jadzia&#39;, age=58),
#  Row(Name=&#39;Guinan&#39;, age=43),
#  Row(Name=&#39;Jean-Luc&#39;, age=40),
#  Row(Name=&#39;Brunt&#39;, age=62),
#  Row(Name=&#39;Geordi&#39;, age=55),
#  Row(Name=&#39;Kasidy&#39;, age=32),
#  Row(Name=&#39;Brunt&#39;, age=30),
#  Row(Name=&#39;Leeta&#39;, age=75),
#  Row(Name=&#39;Morn&#39;, age=50),
#  Row(Name=&#39;Will&#39;, age=72),
#  Row(Name=&#39;Weyoun&#39;, age=50),
#  Row(Name=&#39;Data&#39;, age=71),
#  Row(Name=&#39;Leeta&#39;, age=68),
#  Row(Name=&#39;Dukat&#39;, age=77),
#  Row(Name=&#39;Jadzia&#39;, age=64),
#  Row(Name=&#39;Hugh&#39;, age=67),
#  Row(Name=&#39;Geordi&#39;, age=42),
#  Row(Name=&#39;Ben&#39;, age=38),
#  Row(Name=&#39;Quark&#39;, age=76),
#  Row(Name=&#39;Hugh&#39;, age=65),
#  Row(Name=&#39;Ezri&#39;, age=41),
#  Row(Name=&#39;Ben&#39;, age=76),
#  Row(Name=&#39;Worf&#39;, age=34),
#  Row(Name=&#39;Kasidy&#39;, age=43),
#  Row(Name=&#39;Rom&#39;, age=56),
#  Row(Name=&#39;Gowron&#39;, age=64),
#  Row(Name=&#39;Elim&#39;, age=56),
#  Row(Name=&#39;Morn&#39;, age=72),
#  Row(Name=&#39;Odo&#39;, age=39),
#  Row(Name=&#39;Ezri&#39;, age=35),
#  Row(Name=&#39;Nerys&#39;, age=79),
#  Row(Name=&#39;Will&#39;, age=54),
#  Row(Name=&#39;Keiko&#39;, age=79),
#  Row(Name=&#39;Jean-Luc&#39;, age=71),
#  Row(Name=&#39;Morn&#39;, age=77),
#  Row(Name=&#39;Dukat&#39;, age=50),
#  Row(Name=&#39;Ezri&#39;, age=71),
#  Row(Name=&#39;Dukat&#39;, age=42),
#  Row(Name=&#39;Morn&#39;, age=60),
#  Row(Name=&#39;Beverly&#39;, age=28),
#  Row(Name=&#39;Will&#39;, age=74),
#  Row(Name=&#39;Leeta&#39;, age=35),
#  Row(Name=&#39;Quark&#39;, age=63),
#  Row(Name=&#39;Nog&#39;, age=74),
#  Row(Name=&#39;Nerys&#39;, age=47),
#  Row(Name=&#39;Morn&#39;, age=35),
#  Row(Name=&#39;Quark&#39;, age=51),
#  Row(Name=&#39;Worf&#39;, age=43),
#  Row(Name=&#39;Dukat&#39;, age=28),
#  Row(Name=&#39;Ben&#39;, age=79),
#  Row(Name=&#39;Rom&#39;, age=62),
#  Row(Name=&#39;Ben&#39;, age=38),
#  Row(Name=&#39;Worf&#39;, age=39),
#  Row(Name=&#39;Jean-Luc&#39;, age=78),
#  Row(Name=&#39;Deanna&#39;, age=45),
#  Row(Name=&#39;Data&#39;, age=55),
#  Row(Name=&#39;Jadzia&#39;, age=55),
#  Row(Name=&#39;Data&#39;, age=57),
#  Row(Name=&#39;Rom&#39;, age=76),
#  Row(Name=&#39;Brunt&#39;, age=36),
#  Row(Name=&#39;Miles&#39;, age=50),
#  Row(Name=&#39;Julian&#39;, age=44),
#  Row(Name=&#39;Kasidy&#39;, age=55),
#  Row(Name=&#39;Gowron&#39;, age=77),
#  Row(Name=&#39;Hugh&#39;, age=75),
#  Row(Name=&#39;Odo&#39;, age=56),
#  Row(Name=&#39;Quark&#39;, age=29),
#  Row(Name=&#39;Ben&#39;, age=55),
#  Row(Name=&#39;Rom&#39;, age=52),
#  Row(Name=&#39;Will&#39;, age=29),
#  Row(Name=&#39;Martok&#39;, age=38),
#  Row(Name=&#39;Dukat&#39;, age=42),
#  Row(Name=&#39;Nog&#39;, age=46),
#  Row(Name=&#39;Elim&#39;, age=74),
#  Row(Name=&#39;Miles&#39;, age=46),
#  Row(Name=&#39;Guinan&#39;, age=69),
#  Row(Name=&#39;Data&#39;, age=70),
#  Row(Name=&#39;Miles&#39;, age=32),
#  Row(Name=&#39;Leeta&#39;, age=55),
#  Row(Name=&#39;Nerys&#39;, age=68),
#  Row(Name=&#39;Quark&#39;, age=71),
#  Row(Name=&#39;Nerys&#39;, age=49),
#  Row(Name=&#39;Beverly&#39;, age=59),
#  Row(Name=&#39;Nerys&#39;, age=65),
#  Row(Name=&#39;Keiko&#39;, age=64),
#  Row(Name=&#39;Kasidy&#39;, age=64),
#  Row(Name=&#39;Morn&#39;, age=73),
#  Row(Name=&#39;Geordi&#39;, age=50),
#  Row(Name=&#39;Beverly&#39;, age=60),
#  Row(Name=&#39;Deanna&#39;, age=54),
#  Row(Name=&#39;Dukat&#39;, age=44),
#  Row(Name=&#39;Odo&#39;, age=41),
#  Row(Name=&#39;Kasidy&#39;, age=77),
#  Row(Name=&#39;Beverly&#39;, age=68),
#  Row(Name=&#39;Odo&#39;, age=49),
#  Row(Name=&#39;Ezri&#39;, age=69),
#  Row(Name=&#39;Nerys&#39;, age=77),
#  Row(Name=&#39;Will&#39;, age=41),
#  Row(Name=&#39;Leeta&#39;, age=36),
#  Row(Name=&#39;Lwaxana&#39;, age=35),
#  Row(Name=&#39;Quark&#39;, age=58),
#  Row(Name=&#39;Martok&#39;, age=78),
#  Row(Name=&#39;Beverly&#39;, age=63),
#  Row(Name=&#39;Jean-Luc&#39;, age=78),
#  Row(Name=&#39;Weyoun&#39;, age=39),
#  Row(Name=&#39;Kasidy&#39;, age=65),
#  Row(Name=&#39;Leeta&#39;, age=33),
#  Row(Name=&#39;Deanna&#39;, age=57),
#  Row(Name=&#39;Will&#39;, age=48),
#  Row(Name=&#39;Worf&#39;, age=65),
#  Row(Name=&#39;Brunt&#39;, age=77),
#  Row(Name=&#39;Kasidy&#39;, age=36),
#  Row(Name=&#39;Elim&#39;, age=47),
#  Row(Name=&#39;Kasidy&#39;, age=40),
#  Row(Name=&#39;Rom&#39;, age=53),
#  Row(Name=&#39;Weyoun&#39;, age=36),
#  Row(Name=&#39;Ben&#39;, age=57),
#  Row(Name=&#39;Julian&#39;, age=54),
#  Row(Name=&#39;Weyoun&#39;, age=58),
#  Row(Name=&#39;Miles&#39;, age=41),
#  Row(Name=&#39;Nerys&#39;, age=57),
#  Row(Name=&#39;Keiko&#39;, age=64),
#  Row(Name=&#39;Quark&#39;, age=72),
#  Row(Name=&#39;Geordi&#39;, age=70),
#  Row(Name=&#39;Nog&#39;, age=50),
#  Row(Name=&#39;Jadzia&#39;, age=55),
#  Row(Name=&#39;Nerys&#39;, age=70),
#  Row(Name=&#39;Kasidy&#39;, age=48),
#  Row(Name=&#39;Ben&#39;, age=40),
#  Row(Name=&#39;Data&#39;, age=48),
#  Row(Name=&#39;Leeta&#39;, age=48),
#  Row(Name=&#39;Brunt&#39;, age=58),
#  Row(Name=&#39;Hugh&#39;, age=48),
#  Row(Name=&#39;Kasidy&#39;, age=31),
#  Row(Name=&#39;Ezri&#39;, age=33),
#  Row(Name=&#39;Lwaxana&#39;, age=73),
#  Row(Name=&#39;Ezri&#39;, age=56),
#  Row(Name=&#39;Deanna&#39;, age=74),
#  Row(Name=&#39;Morn&#39;, age=79),
#  Row(Name=&#39;Will&#39;, age=31),
#  Row(Name=&#39;Lwaxana&#39;, age=51),
#  Row(Name=&#39;Nog&#39;, age=47),
#  Row(Name=&#39;Brunt&#39;, age=37),
#  Row(Name=&#39;Data&#39;, age=43),
#  Row(Name=&#39;Ben&#39;, age=71),
#  Row(Name=&#39;Geordi&#39;, age=65),
#  Row

# %%
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+--------+---+-------+
#  Id|    Name|Age|Friends|
# +---+--------+---+-------+
#   0|    Will| 33|    385|
#   1|Jean-Luc| 26|      2|
#   2|    Hugh| 55|    221|
#   3|  Deanna| 40|    465|
#   4|   Quark| 68|     21|
#   5|  Weyoun| 59|    318|
#   6|  Gowron| 37|    220|
#   7|    Will| 54|    307|
#   8|  Jadzia| 38|    380|
#   9|    Hugh| 27|    181|
#  10|     Odo| 53|    191|
#  11|     Ben| 57|    372|
#  12|   Keiko| 54|    253|
#  13|Jean-Luc| 56|    444|
#  14|    Hugh| 43|     49|
#  15|     Rom| 36|     49|
#  16|  Weyoun| 22|    323|
#  17|     Odo| 35|     13|
#  18|Jean-Luc| 45|    455|
#  19|  Geordi| 60|    246|
# +---+--------+---+-------+
# only showing top 20 rows
#
# </div>

# %%
df.toJSON().first()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[140]: &#39;{&#34;Id&#34;:0,&#34;Name&#34;:&#34;Will&#34;,&#34;Age&#34;:33,&#34;Friends&#34;:385}&#39;</div>

# %%
 df.toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Id</th>
#       <th>Name</th>
#       <th>Age</th>
#       <th>Friends</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>Will</td>
#       <td>33</td>
#       <td>385</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>Jean-Luc</td>
#       <td>26</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>Hugh</td>
#       <td>55</td>
#       <td>221</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>Deanna</td>
#       <td>40</td>
#       <td>465</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>Quark</td>
#       <td>68</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>Weyoun</td>
#       <td>59</td>
#       <td>318</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>6</td>
#       <td>Gowron</td>
#       <td>37</td>
#       <td>220</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>7</td>
#       <td>Will</td>
#       <td>54</td>
#       <td>307</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>8</td>
#       <td>Jadzia</td>
#       <td>38</td>
#       <td>380</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>9</td>
#       <td>Hugh</td>
#       <td>27</td>
#       <td>181</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>10</td>
#       <td>Odo</td>
#       <td>53</td>
#       <td>191</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>11</td>
#       <td>Ben</td>
#       <td>57</td>
#       <td>372</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>12</td>
#       <td>Keiko</td>
#       <td>54</td>
#       <td>253</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>13</td>
#       <td>Jean-Luc</td>
#       <td>56</td>
#       <td>444</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>14</td>
#       <td>Hugh</td>
#       <td>43</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>15</td>
#       <td>Rom</td>
#       <td>36</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>16</td>
#       <td>Weyoun</td>
#       <td>22</td>
#       <td>323</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>17</td>
#       <td>Odo</td>
#       <td>35</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>18</td>
#       <td>Jean-Luc</td>
#       <td>45</td>
#       <td>455</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>19</td>
#       <td>Geordi</td>
#       <td>60</td>
#       <td>246</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>20</td>
#       <td>Odo</td>
#       <td>67</td>
#       <td>220</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>21</td>
#       <td>Miles</td>
#       <td>19</td>
#       <td>268</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>22</td>
#       <td>Quark</td>
#       <td>30</td>
#       <td>72</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>23</td>
#       <td>Keiko</td>
#       <td>51</td>
#       <td>271</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>24</td>
#       <td>Julian</td>
#       <td>25</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>25</td>
#       <td>Ben</td>
#       <td>21</td>
#       <td>445</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>26</td>
#       <td>Julian</td>
#       <td>22</td>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>27</td>
#       <td>Leeta</td>
#       <td>42</td>
#       <td>363</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>28</td>
#       <td>Martok</td>
#       <td>49</td>
#       <td>476</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>29</td>
#       <td>Nog</td>
#       <td>48</td>
#       <td>364</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>470</th>
#       <td>470</td>
#       <td>Deanna</td>
#       <td>38</td>
#       <td>160</td>
#     </tr>
#     <tr>
#       <th>471</th>
#       <td>471</td>
#       <td>Brunt</td>
#       <td>52</td>
#       <td>273</td>
#     </tr>
#     <tr>
#       <th>472</th>
#       <td>472</td>
#       <td>Nog</td>
#       <td>27</td>
#       <td>154</td>
#     </tr>
#     <tr>
#       <th>473</th>
#       <td>473</td>
#       <td>Morn</td>
#       <td>35</td>
#       <td>38</td>
#     </tr>
#     <tr>
#       <th>474</th>
#       <td>474</td>
#       <td>Keiko</td>
#       <td>34</td>
#       <td>48</td>
#     </tr>
#     <tr>
#       <th>475</th>
#       <td>475</td>
#       <td>Ben</td>
#       <td>52</td>
#       <td>446</td>
#     </tr>
#     <tr>
#       <th>476</th>
#       <td>476</td>
#       <td>Jean-Luc</td>
#       <td>28</td>
#       <td>378</td>
#     </tr>
#     <tr>
#       <th>477</th>
#       <td>477</td>
#       <td>Gowron</td>
#       <td>50</td>
#       <td>119</td>
#     </tr>
#     <tr>
#       <th>478</th>
#       <td>478</td>
#       <td>Dukat</td>
#       <td>41</td>
#       <td>62</td>
#     </tr>
#     <tr>
#       <th>479</th>
#       <td>479</td>
#       <td>Kasidy</td>
#       <td>44</td>
#       <td>320</td>
#     </tr>
#     <tr>
#       <th>480</th>
#       <td>480</td>
#       <td>Geordi</td>
#       <td>43</td>
#       <td>428</td>
#     </tr>
#     <tr>
#       <th>481</th>
#       <td>481</td>
#       <td>Elim</td>
#       <td>32</td>
#       <td>97</td>
#     </tr>
#     <tr>
#       <th>482</th>
#       <td>482</td>
#       <td>Ben</td>
#       <td>48</td>
#       <td>146</td>
#     </tr>
#     <tr>
#       <th>483</th>
#       <td>483</td>
#       <td>Hugh</td>
#       <td>57</td>
#       <td>99</td>
#     </tr>
#     <tr>
#       <th>484</th>
#       <td>484</td>
#       <td>Leeta</td>
#       <td>22</td>
#       <td>478</td>
#     </tr>
#     <tr>
#       <th>485</th>
#       <td>485</td>
#       <td>Rom</td>
#       <td>47</td>
#       <td>356</td>
#     </tr>
#     <tr>
#       <th>486</th>
#       <td>486</td>
#       <td>Elim</td>
#       <td>49</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>487</th>
#       <td>487</td>
#       <td>Brunt</td>
#       <td>69</td>
#       <td>431</td>
#     </tr>
#     <tr>
#       <th>488</th>
#       <td>488</td>
#       <td>Nog</td>
#       <td>61</td>
#       <td>103</td>
#     </tr>
#     <tr>
#       <th>489</th>
#       <td>489</td>
#       <td>Odo</td>
#       <td>33</td>
#       <td>410</td>
#     </tr>
#     <tr>
#       <th>490</th>
#       <td>490</td>
#       <td>Nerys</td>
#       <td>65</td>
#       <td>101</td>
#     </tr>
#     <tr>
#       <th>491</th>
#       <td>491</td>
#       <td>Rom</td>
#       <td>60</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>492</th>
#       <td>492</td>
#       <td>Dukat</td>
#       <td>19</td>
#       <td>36</td>
#     </tr>
#     <tr>
#       <th>493</th>
#       <td>493</td>
#       <td>Hugh</td>
#       <td>23</td>
#       <td>357</td>
#     </tr>
#     <tr>
#       <th>494</th>
#       <td>494</td>
#       <td>Kasidy</td>
#       <td>18</td>
#       <td>194</td>
#     </tr>
#     <tr>
#       <th>495</th>
#       <td>495</td>
#       <td>Data</td>
#       <td>46</td>
#       <td>155</td>
#     </tr>
#     <tr>
#       <th>496</th>
#       <td>496</td>
#       <td>Gowron</td>
#       <td>39</td>
#       <td>275</td>
#     </tr>
#     <tr>
#       <th>497</th>
#       <td>497</td>
#       <td>Lwaxana</td>
#       <td>34</td>
#       <td>423</td>
#     </tr>
#     <tr>
#       <th>498</th>
#       <td>498</td>
#       <td>Jadzia</td>
#       <td>62</td>
#       <td>36</td>
#     </tr>
#     <tr>
#       <th>499</th>
#       <td>499</td>
#       <td>Leeta</td>
#       <td>62</td>
#       <td>12</td>
#     </tr>
#   </tbody>
# </table>
# <p>500 rows × 4 columns</p>
# </div>

# %%
df.withColumn('age2',df.Age + 2).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[143]: [Row(Id=0, Name=&#39;Will&#39;, Age=33, Friends=385, age2=35),
#  Row(Id=1, Name=&#39;Jean-Luc&#39;, Age=26, Friends=2, age2=28),
#  Row(Id=2, Name=&#39;Hugh&#39;, Age=55, Friends=221, age2=57),
#  Row(Id=3, Name=&#39;Deanna&#39;, Age=40, Friends=465, age2=42),
#  Row(Id=4, Name=&#39;Quark&#39;, Age=68, Friends=21, age2=70),
#  Row(Id=5, Name=&#39;Weyoun&#39;, Age=59, Friends=318, age2=61),
#  Row(Id=6, Name=&#39;Gowron&#39;, Age=37, Friends=220, age2=39),
#  Row(Id=7, Name=&#39;Will&#39;, Age=54, Friends=307, age2=56),
#  Row(Id=8, Name=&#39;Jadzia&#39;, Age=38, Friends=380, age2=40),
#  Row(Id=9, Name=&#39;Hugh&#39;, Age=27, Friends=181, age2=29),
#  Row(Id=10, Name=&#39;Odo&#39;, Age=53, Friends=191, age2=55),
#  Row(Id=11, Name=&#39;Ben&#39;, Age=57, Friends=372, age2=59),
#  Row(Id=12, Name=&#39;Keiko&#39;, Age=54, Friends=253, age2=56),
#  Row(Id=13, Name=&#39;Jean-Luc&#39;, Age=56, Friends=444, age2=58),
#  Row(Id=14, Name=&#39;Hugh&#39;, Age=43, Friends=49, age2=45),
#  Row(Id=15, Name=&#39;Rom&#39;, Age=36, Friends=49, age2=38),
#  Row(Id=16, Name=&#39;Weyoun&#39;, Age=22, Friends=323, age2=24),
#  Row(Id=17, Name=&#39;Odo&#39;, Age=35, Friends=13, age2=37),
#  Row(Id=18, Name=&#39;Jean-Luc&#39;, Age=45, Friends=455, age2=47),
#  Row(Id=19, Name=&#39;Geordi&#39;, Age=60, Friends=246, age2=62),
#  Row(Id=20, Name=&#39;Odo&#39;, Age=67, Friends=220, age2=69),
#  Row(Id=21, Name=&#39;Miles&#39;, Age=19, Friends=268, age2=21),
#  Row(Id=22, Name=&#39;Quark&#39;, Age=30, Friends=72, age2=32),
#  Row(Id=23, Name=&#39;Keiko&#39;, Age=51, Friends=271, age2=53),
#  Row(Id=24, Name=&#39;Julian&#39;, Age=25, Friends=1, age2=27),
#  Row(Id=25, Name=&#39;Ben&#39;, Age=21, Friends=445, age2=23),
#  Row(Id=26, Name=&#39;Julian&#39;, Age=22, Friends=100, age2=24),
#  Row(Id=27, Name=&#39;Leeta&#39;, Age=42, Friends=363, age2=44),
#  Row(Id=28, Name=&#39;Martok&#39;, Age=49, Friends=476, age2=51),
#  Row(Id=29, Name=&#39;Nog&#39;, Age=48, Friends=364, age2=50),
#  Row(Id=30, Name=&#39;Keiko&#39;, Age=50, Friends=175, age2=52),
#  Row(Id=31, Name=&#39;Miles&#39;, Age=39, Friends=161, age2=41),
#  Row(Id=32, Name=&#39;Nog&#39;, Age=26, Friends=281, age2=28),
#  Row(Id=33, Name=&#39;Dukat&#39;, Age=53, Friends=197, age2=55),
#  Row(Id=34, Name=&#39;Jean-Luc&#39;, Age=43, Friends=249, age2=45),
#  Row(Id=35, Name=&#39;Beverly&#39;, Age=27, Friends=305, age2=29),
#  Row(Id=36, Name=&#39;Kasidy&#39;, Age=32, Friends=81, age2=34),
#  Row(Id=37, Name=&#39;Geordi&#39;, Age=58, Friends=21, age2=60),
#  Row(Id=38, Name=&#39;Deanna&#39;, Age=64, Friends=65, age2=66),
#  Row(Id=39, Name=&#39;Morn&#39;, Age=31, Friends=192, age2=33),
#  Row(Id=40, Name=&#39;Odo&#39;, Age=52, Friends=413, age2=54),
#  Row(Id=41, Name=&#39;Hugh&#39;, Age=67, Friends=167, age2=69),
#  Row(Id=42, Name=&#39;Brunt&#39;, Age=54, Friends=75, age2=56),
#  Row(Id=43, Name=&#39;Guinan&#39;, Age=58, Friends=345, age2=60),
#  Row(Id=44, Name=&#39;Nerys&#39;, Age=35, Friends=244, age2=37),
#  Row(Id=45, Name=&#39;Dukat&#39;, Age=52, Friends=77, age2=54),
#  Row(Id=46, Name=&#39;Morn&#39;, Age=25, Friends=96, age2=27),
#  Row(Id=47, Name=&#39;Brunt&#39;, Age=24, Friends=49, age2=26),
#  Row(Id=48, Name=&#39;Nog&#39;, Age=20, Friends=1, age2=22),
#  Row(Id=49, Name=&#39;Ezri&#39;, Age=40, Friends=254, age2=42),
#  Row(Id=50, Name=&#39;Quark&#39;, Age=51, Friends=283, age2=53),
#  Row(Id=51, Name=&#39;Lwaxana&#39;, Age=36, Friends=212, age2=38),
#  Row(Id=52, Name=&#39;Beverly&#39;, Age=19, Friends=269, age2=21),
#  Row(Id=53, Name=&#39;Geordi&#39;, Age=62, Friends=31, age2=64),
#  Row(Id=54, Name=&#39;Brunt&#39;, Age=19, Friends=5, age2=21),
#  Row(Id=55, Name=&#39;Keiko&#39;, Age=41, Friends=278, age2=43),
#  Row(Id=56, Name=&#39;Gowron&#39;, Age=44, Friends=194, age2=46),
#  Row(Id=57, Name=&#39;Odo&#39;, Age=57, Friends=294, age2=59),
#  Row(Id=58, Name=&#39;Hugh&#39;, Age=59, Friends=158, age2=61),
#  Row(Id=59, Name=&#39;Morn&#39;, Age=59, Friends=284, age2=61),
#  Row(Id=60, Name=&#39;Geordi&#39;, Age=20, Friends=100, age2=22),
#  Row(Id=61, Name=&#39;Kasidy&#39;, Age=62, Friends=442, age2=64),
#  Row(Id=62, Name=&#39;Keiko&#39;, Age=69, Friends=9, age2=71),
#  Row(Id=63, Name=&#39;Jean-Luc&#39;, Age=58, Friends=54, age2=60),
#  Row(Id=64, Name=&#39;Elim&#39;, Age=31, Friends=15, age2=33),
#  Row(Id=65, Name=&#39;Guinan&#39;, Age=52, Friends=169, age2=54),
#  Row(Id=66, Name=&#39;Geordi&#39;, Age=21, Friends=477, age2=23),
#  Row(Id=67, Name=&#39;Jadzia&#39;, Age=48, Friends=135, age2=50),
#  Row(Id=68, Name=&#39;Guinan&#39;, Age=33, Friends=74, age2=35),
#  Row(Id=69, Name=&#39;Jean-Luc&#39;, Age=30, Friends=204, age2=32),
#  Row(Id=70, Name=&#39;Brunt&#39;, Age=52, Friends=393, age2=54),
#  Row(Id=71, Name=&#39;Geordi&#39;, Age=45, Friends=184, age2=47),
#  Row(Id=72, Name=&#39;Kasidy&#39;, Age=22, Friends=179, age2=24),
#  Row(Id=73, Name=&#39;Brunt&#39;, Age=20, Friends=384, age2=22),
#  Row(Id=74, Name=&#39;Leeta&#39;, Age=65, Friends=208, age2=67),
#  Row(Id=75, Name=&#39;Morn&#39;, Age=40, Friends=459, age2=42),
#  Row(Id=76, Name=&#39;Will&#39;, Age=62, Friends=201, age2=64),
#  Row(Id=77, Name=&#39;Weyoun&#39;, Age=40, Friends=407, age2=42),
#  Row(Id=78, Name=&#39;Data&#39;, Age=61, Friends=337, age2=63),
#  Row(Id=79, Name=&#39;Leeta&#39;, Age=58, Friends=348, age2=60),
#  Row(Id=80, Name=&#39;Dukat&#39;, Age=67, Friends=445, age2=69),
#  Row(Id=81, Name=&#39;Jadzia&#39;, Age=54, Friends=440, age2=56),
#  Row(Id=82, Name=&#39;Hugh&#39;, Age=57, Friends=465, age2=59),
#  Row(Id=83, Name=&#39;Geordi&#39;, Age=32, Friends=308, age2=34),
#  Row(Id=84, Name=&#39;Ben&#39;, Age=28, Friends=311, age2=30),
#  Row(Id=85, Name=&#39;Quark&#39;, Age=66, Friends=383, age2=68),
#  Row(Id=86, Name=&#39;Hugh&#39;, Age=55, Friends=257, age2=57),
#  Row(Id=87, Name=&#39;Ezri&#39;, Age=31, Friends=481, age2=33),
#  Row(Id=88, Name=&#39;Ben&#39;, Age=66, Friends=188, age2=68),
#  Row(Id=89, Name=&#39;Worf&#39;, Age=24, Friends=492, age2=26),
#  Row(Id=90, Name=&#39;Kasidy&#39;, Age=33, Friends=471, age2=35),
#  Row(Id=91, Name=&#39;Rom&#39;, Age=46, Friends=88, age2=48),
#  Row(Id=92, Name=&#39;Gowron&#39;, Age=54, Friends=7, age2=56),
#  Row(Id=93, Name=&#39;Elim&#39;, Age=46, Friends=63, age2=48),
#  Row(Id=94, Name=&#39;Morn&#39;, Age=62, Friends=133, age2=64),
#  Row(Id=95, Name=&#39;Odo&#39;, Age=29, Friends=173, age2=31),
#  Row(Id=96, Name=&#39;Ezri&#39;, Age=25, Friends=233, age2=27),
#  Row(Id=97, Name=&#39;Nerys&#39;, Age=69, Friends=361, age2=71),
#  Row(Id=98, Name=&#39;Will&#39;, Age=44, Friends=178, age2=46),
#  Row(Id=99, Name=&#39;Keiko&#39;, Age=69, Friends=491, age2=71),
#  Row(Id=100, Name=&#39;Jean-Luc&#39;, Age=61, Friends=460, age2=63),
#  Row(Id=101, Name=&#39;Morn&#39;, Age=67, Friends=123, age2=69),
#  Row(Id=102, Name=&#39;Dukat&#39;, Age=40, Friends=18, age2=42),
#  Row(Id=103, Name=&#39;Ezri&#39;, Age=61, Friends=2, age2=63),
#  Row(Id=104, Name=&#39;Dukat&#39;, Age=32, Friends=142, age2=34),
#  Row(Id=105, Name=&#39;Morn&#39;, Age=50, Friends=417, age2=52),
#  Row(Id=106, Name=&#39;Beverly&#39;, Age=18, Friends=499, age2=20),
#  Row(Id=107, Name=&#39;Will&#39;, Age=64, Friends=419, age2=66),
#  Row(Id=108, Name=&#39;Leeta&#39;, Age=25, Friends=274, age2=27),
#  Row(Id=109, Name=&#39;Quark&#39;, Age=53, Friends=417, age2=55),
#  Row(Id=110, Name=&#39;Nog&#39;, Age=64, Friends=137, age2=66),
#  Row(Id=111, Name=&#39;Nerys&#39;, Age=37, Friends=46, age2=39),
#  Row(Id=112, Name=&#39;Morn&#39;, Age=25, Friends=13, age2=27),
#  Row(Id=113, Name=&#39;Quark&#39;, Age=41, Friends=244, age2=43),
#  Row(Id=114, Name=&#39;Worf&#39;, Age=33, Friends=275, age2=35),
#  Row(Id=115, Name=&#39;Dukat&#39;, Age=18, Friends=397, age2=20),
#  Row(Id=116, Name=&#39;Ben&#39;, Age=69, Friends=75, age2=71),
#  Row(Id=117, Name=&#39;Rom&#39;, Age=52, Friends=487, age2=54),
#  Row(Id=118, Name=&#39;Ben&#

# %%
df.select('Name', df.time.cast('timestamp')).withWatermark('time', '10 minutes')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AttributeError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1501490288573035&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>df<span class="ansi-blue-fg">.</span>select<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;Name&#39;</span><span class="ansi-blue-fg">,</span> df<span class="ansi-blue-fg">.</span>time<span class="ansi-blue-fg">.</span>cast<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;timestamp&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>withWatermark<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;time&#39;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#39;10 minutes&#39;</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/dataframe.py</span> in <span class="ansi-cyan-fg">__getattr__</span><span class="ansi-blue-fg">(self, name)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1324</span>         <span class="ansi-green-fg">if</span> name <span class="ansi-green-fg">not</span> <span class="ansi-green-fg">in</span> self<span class="ansi-blue-fg">.</span>columns<span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">   1325</span>             raise AttributeError(
# <span class="ansi-green-fg">-&gt; 1326</span><span class="ansi-red-fg">                 &#34;&#39;%s&#39; object has no attribute &#39;%s&#39;&#34; % (self.__class__.__name__, name))
# </span><span class="ansi-green-intense-fg ansi-bold">   1327</span>         jc <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>_jdf<span class="ansi-blue-fg">.</span>apply<span class="ansi-blue-fg">(</span>name<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1328</span>         <span class="ansi-green-fg">return</span> Column<span class="ansi-blue-fg">(</span>jc<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">AttributeError</span>: &#39;DataFrame&#39; object has no attribute &#39;time&#39;</div>

# %%
from pyspark.sql.functions import *
df.groupBy('Name').1avg('Age').collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[149]: [Row(Name=&#39;Data&#39;, avg(Age)=43.36),
#  Row(Name=&#39;Beverly&#39;, avg(Age)=40.55),
#  Row(Name=&#39;Hugh&#39;, avg(Age)=49.65),
#  Row(Name=&#39;Dukat&#39;, avg(Age)=41.76190476190476),
#  Row(Name=&#39;Jean-Luc&#39;, avg(Age)=48.6875),
#  Row(Name=&#39;Nog&#39;, avg(Age)=42.40909090909091),
#  Row(Name=&#39;Odo&#39;, avg(Age)=42.53333333333333),
#  Row(Name=&#39;Kasidy&#39;, avg(Age)=38.8421052631579),
#  Row(Name=&#39;Guinan&#39;, avg(Age)=46.333333333333336),
#  Row(Name=&#39;Leeta&#39;, avg(Age)=41.6),
#  Row(Name=&#39;Rom&#39;, avg(Age)=49.666666666666664),
#  Row(Name=&#39;Geordi&#39;, avg(Age)=44.35),
#  Row(Name=&#39;Brunt&#39;, avg(Age)=42.77272727272727),
#  Row(Name=&#39;Deanna&#39;, avg(Age)=44.8235294117647),
#  Row(Name=&#39;Ben&#39;, avg(Age)=47.88235294117647),
#  Row(Name=&#39;Weyoun&#39;, avg(Age)=37.8),
#  Row(Name=&#39;Miles&#39;, avg(Age)=36.9),
#  Row(Name=&#39;Will&#39;, avg(Age)=39.36842105263158),
#  Row(Name=&#39;Julian&#39;, avg(Age)=39.666666666666664),
#  Row(Name=&#39;Lwaxana&#39;, avg(Age)=41.5),
#  Row(Name=&#39;Jadzia&#39;, avg(Age)=46.916666666666664),
#  Row(Name=&#39;Ezri&#39;, avg(Age)=42.05),
#  Row(Name=&#39;Keiko&#39;, avg(Age)=45.857142857142854),
#  Row(Name=&#39;Elim&#39;, avg(Age)=40.5),
#  Row(Name=&#39;Worf&#39;, avg(Age)=44.92857142857143),
#  Row(Name=&#39;Nerys&#39;, avg(Age)=48.68421052631579),
#  Row(Name=&#39;Quark&#39;, avg(Age)=43.76190476190476),
#  Row(Name=&#39;Martok&#39;, avg(Age)=43.166666666666664),
#  Row(Name=&#39;Morn&#39;, avg(Age)=48.375),
#  Row(Name=&#39;Gowron&#39;, avg(Age)=45.416666666666664)]</div>

# %%
df5= df.repartition(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df5.rdd.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[155]: 2</div>

# %%
df5 = df5.coalesce(1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df5.rdd.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[161]: 1</div>

# %%
df5.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[154]: [Row(Id=171, Name=&#39;Weyoun&#39;, Age=29, Friends=126),
#  Row(Id=403, Name=&#39;Weyoun&#39;, Age=21, Friends=224),
#  Row(Id=282, Name=&#39;Geordi&#39;, Age=32, Friends=404),
#  Row(Id=248, Name=&#39;Dukat&#39;, Age=21, Friends=138),
#  Row(Id=300, Name=&#39;Beverly&#39;, Age=49, Friends=147),
#  Row(Id=464, Name=&#39;Beverly&#39;, Age=25, Friends=485),
#  Row(Id=447, Name=&#39;Julian&#39;, Age=38, Friends=34),
#  Row(Id=136, Name=&#39;Will&#39;, Age=19, Friends=335),
#  Row(Id=392, Name=&#39;Data&#39;, Age=64, Friends=343),
#  Row(Id=479, Name=&#39;Kasidy&#39;, Age=44, Friends=320),
#  Row(Id=69, Name=&#39;Jean-Luc&#39;, Age=30, Friends=204),
#  Row(Id=268, Name=&#39;Ezri&#39;, Age=26, Friends=298),
#  Row(Id=74, Name=&#39;Leeta&#39;, Age=65, Friends=208),
#  Row(Id=222, Name=&#39;Rom&#39;, Age=34, Friends=346),
#  Row(Id=311, Name=&#39;Martok&#39;, Age=43, Friends=48),
#  Row(Id=483, Name=&#39;Hugh&#39;, Age=57, Friends=99),
#  Row(Id=108, Name=&#39;Leeta&#39;, Age=25, Friends=274),
#  Row(Id=470, Name=&#39;Deanna&#39;, Age=38, Friends=160),
#  Row(Id=135, Name=&#39;Rom&#39;, Age=42, Friends=427),
#  Row(Id=478, Name=&#39;Dukat&#39;, Age=41, Friends=62),
#  Row(Id=303, Name=&#39;Deanna&#39;, Age=46, Friends=319),
#  Row(Id=98, Name=&#39;Will&#39;, Age=44, Friends=178),
#  Row(Id=405, Name=&#39;Nog&#39;, Age=56, Friends=371),
#  Row(Id=473, Name=&#39;Morn&#39;, Age=35, Friends=38),
#  Row(Id=177, Name=&#39;Brunt&#39;, Age=67, Friends=316),
#  Row(Id=489, Name=&#39;Odo&#39;, Age=33, Friends=410),
#  Row(Id=145, Name=&#39;Leeta&#39;, Age=45, Friends=470),
#  Row(Id=430, Name=&#39;Geordi&#39;, Age=36, Friends=493),
#  Row(Id=213, Name=&#39;Worf&#39;, Age=28, Friends=312),
#  Row(Id=260, Name=&#39;Brunt&#39;, Age=38, Friends=96),
#  Row(Id=373, Name=&#39;Quark&#39;, Age=19, Friends=272),
#  Row(Id=497, Name=&#39;Lwaxana&#39;, Age=34, Friends=423),
#  Row(Id=297, Name=&#39;Ben&#39;, Age=45, Friends=395),
#  Row(Id=25, Name=&#39;Ben&#39;, Age=21, Friends=445),
#  Row(Id=299, Name=&#39;Rom&#39;, Age=57, Friends=311),
#  Row(Id=305, Name=&#39;Quark&#39;, Age=29, Friends=182),
#  Row(Id=494, Name=&#39;Kasidy&#39;, Age=18, Friends=194),
#  Row(Id=343, Name=&#39;Odo&#39;, Age=26, Friends=254),
#  Row(Id=175, Name=&#39;Will&#39;, Age=38, Friends=459),
#  Row(Id=217, Name=&#39;Keiko&#39;, Age=29, Friends=260),
#  Row(Id=109, Name=&#39;Quark&#39;, Age=53, Friends=417),
#  Row(Id=329, Name=&#39;Dukat&#39;, Age=67, Friends=35),
#  Row(Id=154, Name=&#39;Geordi&#39;, Age=40, Friends=389),
#  Row(Id=328, Name=&#39;Deanna&#39;, Age=62, Friends=41),
#  Row(Id=133, Name=&#39;Quark&#39;, Age=19, Friends=265),
#  Row(Id=466, Name=&#39;Brunt&#39;, Age=33, Friends=228),
#  Row(Id=413, Name=&#39;Hugh&#39;, Age=45, Friends=147),
#  Row(Id=57, Name=&#39;Odo&#39;, Age=57, Friends=294),
#  Row(Id=70, Name=&#39;Brunt&#39;, Age=52, Friends=393),
#  Row(Id=203, Name=&#39;Ezri&#39;, Age=46, Friends=125),
#  Row(Id=185, Name=&#39;Weyoun&#39;, Age=48, Friends=287),
#  Row(Id=182, Name=&#39;Weyoun&#39;, Age=26, Friends=145),
#  Row(Id=312, Name=&#39;Jadzia&#39;, Age=61, Friends=421),
#  Row(Id=130, Name=&#39;Gowron&#39;, Age=67, Friends=350),
#  Row(Id=81, Name=&#39;Jadzia&#39;, Age=54, Friends=440),
#  Row(Id=270, Name=&#39;Data&#39;, Age=44, Friends=353),
#  Row(Id=161, Name=&#39;Odo&#39;, Age=39, Friends=207),
#  Row(Id=88, Name=&#39;Ben&#39;, Age=66, Friends=188),
#  Row(Id=480, Name=&#39;Geordi&#39;, Age=43, Friends=428),
#  Row(Id=215, Name=&#39;Will&#39;, Age=22, Friends=6),
#  Row(Id=162, Name=&#39;Ezri&#39;, Age=59, Friends=14),
#  Row(Id=450, Name=&#39;Weyoun&#39;, Age=37, Friends=234),
#  Row(Id=238, Name=&#39;Deanna&#39;, Age=25, Friends=305),
#  Row(Id=496, Name=&#39;Gowron&#39;, Age=39, Friends=275),
#  Row(Id=27, Name=&#39;Leeta&#39;, Age=42, Friends=363),
#  Row(Id=254, Name=&#39;Ezri&#39;, Age=67, Friends=79),
#  Row(Id=421, Name=&#39;Will&#39;, Age=40, Friends=261),
#  Row(Id=39, Name=&#39;Morn&#39;, Age=31, Friends=192),
#  Row(Id=225, Name=&#39;Elim&#39;, Age=19, Friends=106),
#  Row(Id=184, Name=&#39;Julian&#39;, Age=44, Friends=84),
#  Row(Id=169, Name=&#39;Beverly&#39;, Age=53, Friends=92),
#  Row(Id=482, Name=&#39;Ben&#39;, Age=48, Friends=146),
#  Row(Id=53, Name=&#39;Geordi&#39;, Age=62, Friends=31),
#  Row(Id=224, Name=&#39;Keiko&#39;, Age=44, Friends=277),
#  Row(Id=486, Name=&#39;Elim&#39;, Age=49, Friends=17),
#  Row(Id=322, Name=&#39;Rom&#39;, Age=58, Friends=92),
#  Row(Id=276, Name=&#39;Dukat&#39;, Age=54, Friends=462),
#  Row(Id=498, Name=&#39;Jadzia&#39;, Age=62, Friends=36),
#  Row(Id=43, Name=&#39;Guinan&#39;, Age=58, Friends=345),
#  Row(Id=302, Name=&#39;Beverly&#39;, Age=37, Friends=263),
#  Row(Id=163, Name=&#39;Nerys&#39;, Age=67, Friends=204),
#  Row(Id=457, Name=&#39;Worf&#39;, Age=51, Friends=81),
#  Row(Id=107, Name=&#39;Will&#39;, Age=64, Friends=419),
#  Row(Id=442, Name=&#39;Nog&#39;, Age=46, Friends=105),
#  Row(Id=206, Name=&#39;Will&#39;, Age=21, Friends=491),
#  Row(Id=191, Name=&#39;Nog&#39;, Age=40, Friends=349),
#  Row(Id=477, Name=&#39;Gowron&#39;, Age=50, Friends=119),
#  Row(Id=94, Name=&#39;Morn&#39;, Age=62, Friends=133),
#  Row(Id=358, Name=&#39;Will&#39;, Age=52, Friends=276),
#  Row(Id=47, Name=&#39;Brunt&#39;, Age=24, Friends=49),
#  Row(Id=355, Name=&#39;Keiko&#39;, Age=46, Friends=352),
#  Row(Id=380, Name=&#39;Brunt&#39;, Age=35, Friends=65),
#  Row(Id=138, Name=&#39;Dukat&#39;, Age=32, Friends=384),
#  Row(Id=146, Name=&#39;Nerys&#39;, Age=58, Friends=174),
#  Row(Id=427, Name=&#39;Brunt&#39;, Age=28, Friends=258),
#  Row(Id=221, Name=&#39;Dukat&#39;, Age=27, Friends=150),
#  Row(Id=431, Name=&#39;Quark&#39;, Age=36, Friends=343),
#  Row(Id=82, Name=&#39;Hugh&#39;, Age=57, Friends=465),
#  Row(Id=89, Name=&#39;Worf&#39;, Age=24, Friends=492),
#  Row(Id=180, Name=&#39;Kasidy&#39;, Age=30, Friends=108),
#  Row(Id=46, Name=&#39;Morn&#39;, Age=25, Friends=96),
#  Row(Id=84, Name=&#39;Ben&#39;, Age=28, Friends=311),
#  Row(Id=117, Name=&#39;Rom&#39;, Age=52, Friends=487),
#  Row(Id=67, Name=&#39;Jadzia&#39;, Age=48, Friends=135),
#  Row(Id=462, Name=&#39;Nerys&#39;, Age=23, Friends=287),
#  Row(Id=387, Name=&#39;Will&#39;, Age=43, Friends=335),
#  Row(Id=159, Name=&#39;Kasidy&#39;, Age=67, Friends=438),
#  Row(Id=218, Name=&#39;Gowron&#39;, Age=66, Friends=350),
#  Row(Id=65, Name=&#39;Guinan&#39;, Age=52, Friends=169),
#  Row(Id=127, Name=&#39;Miles&#39;, Age=40, Friends=284),
#  Row(Id=8, Name=&#39;Jadzia&#39;, Age=38, Friends=380),
#  Row(Id=11, Name=&#39;Ben&#39;, Age=57, Friends=372),
#  Row(Id=116, Name=&#39;Ben&#39;, Age=69, Friends=75),
#  Row(Id=134, Name=&#39;Ben&#39;, Age=45, Friends=340),
#  Row(Id=59, Name=&#39;Morn&#39;, Age=59, Friends=284),
#  Row(Id=272, Name=&#39;Quark&#39;, Age=29, Friends=367),
#  Row(Id=24, Name=&#39;Julian&#39;, Age=25, Friends=1),
#  Row(Id=111, Name=&#39;Nerys&#39;, Age=37, Friends=46),
#  Row(Id=220, Name=&#39;Jean-Luc&#39;, Age=41, Friends=394),
#  Row(Id=168, Name=&#39;Martok&#39;, Age=68, Friends=112),
#  Row(Id=285, Name=&#39;Data&#39;, Age=43, Friends=101),
#  Row(Id=36, Name=&#39;Kasidy&#39;, Age=32, Friends=81),
#  Row(Id=485, Name=&#39;Rom&#39;, Age=47, Friends=356),
#  Row(Id=262, Name=&#39;Will&#39;, Age=51, Friends=334),
#  Row(Id=495, Name=&#39;Data&#39;, Age=46, Friends=155),
#  Row(Id=209, Name=&#39;Brunt&#39;, Age=27, Friends=174),
#  Row(Id=105, Name=&#39;Morn&#39;, Age=50, Friends=417),
#  Row(Id=420, Name=&#39;Jadzia&#39;, Age=26, Friends=391),
#  Row(Id=475, Name=&#39;Ben&#39;, Age=52, Friends=446),
#  Row(Id=332, Name=&#39;Julian&#39;, Age=55, Friends=362),
#  Row(Id=445, Name=&#39;Guinan&#39;, Age=40, Friends=286),
#  Row(Id=230, Name=&#39;Beverly&#39;, Age=54, Friends=397),
#  Row(Id=434, Name=&#39;Deanna&#39;, Age=57, Friends=289),
#  Row(Id=439, Name=&#39;Data&#39;, Age=18, Friends=417),
#  Row(Id=278, Name=&#39;Data&#39;, Age=44, Friends=499),
#  Row(Id=279, Name=&#39;Beverly&#39;, Age=

# %%
type(df.select(df.Age.astype('string')))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[166]: pyspark.sql.dataframe.DataFrame</div>

# %%
type(df.Age.astype('string'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[164]: pyspark.sql.column.Column</div>

# %%
from pyspark.sql import Row 
df9 = spark.createDataFrame([Row(name='Tom', height=80), Row(name='Alice', height=None)])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df9.filter(df9.height.isNull()).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: [Row(height=None, name=&#39;Alice&#39;)]</div>

# %%
from pyspark.sql.functions import *
df.write.format('parquet').bucketBy(100, 'age', 'name').mode('overwrite').saveAsTable('firstBucket')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df2 = spark.createDataFrame([('ABC',)], ['a'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.functions import *
df2.select(sha2('a').alias('crc32')).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">TypeError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-4106622730825057&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> <span class="ansi-green-fg">from</span> pyspark<span class="ansi-blue-fg">.</span>sql<span class="ansi-blue-fg">.</span>functions <span class="ansi-green-fg">import</span> <span class="ansi-blue-fg">*</span>
# <span class="ansi-green-fg">----&gt; 2</span><span class="ansi-red-fg"> </span>df2<span class="ansi-blue-fg">.</span>select<span class="ansi-blue-fg">(</span>sha2<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;a&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>alias<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;crc32&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>collect<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">TypeError</span>: sha2() missing 1 required positional argument: &#39;numBits&#39;</div>

# %%
dfdt = spark.createDataFrame([('2015-04-08',)], ['dt'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dfdt.select(date_format('dt','MM/dd/yyyy').alias('prev_Date')).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: [Row(prev_Date=&#39;04/08/2015&#39;)]</div>

# %%
dfdt.select(date_sub(dfdt.dt,1).alias('prev_date')).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: [Row(prev_date=datetime.date(2015, 4, 7))]</div>

# %%
dft = spark.createDataFrame([('1997-02-28 05:02:11',)], ['t'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dft.select(date_trunc('quarter',dft.t).alias('month')).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[19]: [Row(month=datetime.datetime(1997, 1, 1, 0, 0))]</div>

# %%
df = spark.createDataFrame([('2015-04-08','2015-05-10')], ['d1', 'd2'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.select(dayofmonth(df.d1).alias('dif')).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: [Row(dif=8)]</div>

# %%
from pyspark.sql import Row
eDF = spark.createDataFrame([Row(a=1, intlist=[1,2,3], mapfield={"a": "b"})])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
eDF.select(explode(eDF.intlist).alias('anInt')).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[30]: [Row(anInt=1), Row(anInt=2), Row(anInt=3)]</div>

# %%
eDF.select(explode(eDF.mapfield).alias('key','value')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+-----+
# key|value|
# +---+-----+
#   a|    b|
# +---+-----+
#
# </div>

# %%
 df9 = spark.createDataFrame([(1, ["foo", "bar"], 1), (2, [], {}), (3, None, None)],("id", "an_array", "a_map"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df9.select('id','an_array', explode('a_map')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+----------+---+-----+
#  id|  an_array|key|value|
# +---+----------+---+-----+
#   1|[foo, bar]|  x|  1.0|
# +---+----------+---+-----+
#
# </div>

# %%
df6 = spark.createDataFrame([([[1, 2, 3], [4, 5], [6]],), ([None, [4, 5]],)], ['data'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
